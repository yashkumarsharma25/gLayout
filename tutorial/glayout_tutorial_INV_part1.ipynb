# %% [markdown]
# # Tutorial 1: **Notebook** - *INV*
#
# **By
# gLayout Team**
#
# __Content creators:__ Subham Pal, Saptarshi Ghosh
#
# __Content reviewers:__ Mehedi Saligne

# %% [markdown]
# ___
# # Tutorial Objectives
#
# This notebook is a tutorial on-
#
# - **Importing** and **Placement** of FETs and other macros/Pcells with relative coordinates + Placing (and connecting) Via_stack on the ports of the FETs + encircling them with padrings.
# - **Routing** between the placed *Vias* with *C_*, *L_*, *Straight_* and *smart* Routes and explaining the differences between these strategies. Particularly explaning the East/West/North/South angles, (For Example, why C has to parallel but L has to be perpendicular sides) and *Placing and connecting PINs for future LVS runs

# %% [markdown]
# ## **Target** **Block** : **Flipped Voltage Follwer Cell**
#
# The Flipped Voltage Follower (FVF) is a widely used analog building block known for its low output impedance, fast transient response, and ability to deliver large output current while maintaining voltage buffering properties. It is commonly employed in analog circuit design, particularly in output stages, gain boosting, common-mode feedback circuits, and super class-AB OTAs.
#
# (a) Conventional Voltage follower (common Drain); (b) Flipped voltage follower (FVF).
#
# ![](_images/FVF.png)
#
# ```bibtex
# Domala, N., Sasikala, G. Low power flipped voltage follower current mirror with improved input output impedances. Sādhanā 46, 142 (2021). https://doi.org/10.1007/s12046-021-01665-6
# ```

# %% [markdown]
# ## **Layout generation**
# let's go through the step by step procedure to generate LVS and DRC clean layout of a FVF cell.
#
#
# ### *Creating environment for live GDSII viewer*
# You can see the generated GDSII file immediately inside this notebook. You can also view it in Klayout for better understanding. Code for viewing it in Klayout is added but commented out.

# %%
## Activate if necessary to install following packages

# !pip install svgutils
# !pip install ipywidgets

# %%
# import os
# os.environ["PATH"] = os.environ["TOOLS"]+'/bin:'+ os.environ["PATH"]

# %%
import os
import subprocess

# Run a shell, source .bashrc, then printenv
cmd = 'bash -c "source ~/.bashrc && printenv"'
result = subprocess.run(cmd, shell=True, text=True, capture_output=True)
env_vars = {}
for line in result.stdout.splitlines():
    if '=' in line:
        key, value = line.split('=', 1)
        env_vars[key] = value

# Now, update os.environ with these
os.environ.update(env_vars)

# %%
import gdstk
import svgutils.transform as sg
import IPython.display
from IPython.display import clear_output
import ipywidgets as widgets

# Redirect all outputs here
hide = widgets.Output()

def display_gds(gds_file, path,scale = 3):
  
  # Generate an SVG image
  top_level_cell = gdstk.read_gds(gds_file).top_level()[0]
  top_level_cell.write_svg(os.path.join(path,'out.svg'))
    
  # Scale the image for displaying
  fig = sg.fromfile(os.path.join(path,'out.svg'))
  fig.set_size((str(float(fig.width) * scale), str(float(fig.height) * scale)))
  fig.save(os.path.join(path,'out.svg'))

  # Display the image
  IPython.display.display(IPython.display.SVG(os.path.join(path,'out.svg')))
  os.remove(os.path.join(path,'out.gds'))

def display_component(component,path,scale = 3):
  # Save to a GDS file
  with hide:
    component.write_gds(os.path.join(path,'out.gds'))
  display_gds(os.path.join(path,'out.gds'),path,scale)

# %%
from glayout import MappedPDK, sky130 , gf180
#from gdsfactory.cell import cell
from gdsfactory import Component
from gdsfactory.components import text_freetype, rectangle

# %%
from glayout import nmos, pmos
from glayout import via_stack
from glayout import rename_ports_by_orientation
from glayout import tapring

# %%
from glayout.util.comp_utils import evaluate_bbox, prec_center, prec_ref_center, align_comp_to_port
from glayout.util.port_utils import add_ports_perimeter,print_ports
from glayout.util.snap_to_grid import component_snap_to_grid
from glayout.spice.netlist import Netlist

# %%
from glayout.routing.straight_route import straight_route
from glayout.routing.c_route import c_route
from glayout.routing.L_route import L_route

# %% [markdown]
# FVF has two fets as shown in the schematic. We call M1 as input fet and M2 as feedback fet. Lets define arguments for the FETs

# %%
nmos_kwargs = {
    "with_tie": True,
    "with_dnwell": True,
    "sd_route_topmet": "met2",
    "gate_route_topmet": "met2",
    "sd_route_left": True,
    "rmult": None,
    "gate_rmult": 1,
    "interfinger_rmult": 1,
    "substrate_tap_layers": ("met2","met1"),
    "dummy_routes": True
}

pmos_kwargs = {
    "with_tie": True,
    "dnwell": False,
    "sd_route_topmet": "met2",
    "gate_route_topmet": "met2",
    "sd_route_left": True,
    "rmult": None,
    "gate_rmult": 1,
    "interfinger_rmult": 1,
    "substrate_tap_layers": ("met2","met1"),
    "dummy_routes": True
}

# %% [markdown]
# There is no need to manually define the kwargs for your code. This is only done for this notebook implementation.
#
#
# Now, Let's create a list for parameters which we need for our function-
#
# * pdk: pdk to use
# * device_type: either "nmos" or "pmos"
# * placement: either "horizontal" or "vertical"
# * width: (input fet, feedback fet)
# * length: (input fet, feedback fet)
# * fingers: (input fet, feedback fet)
# * multipliers: (input fet, feedback fet)
# * dummy_1: dummy for input fet
# * dummy_2: dummy for feedback fet
# * tie_layers1: tie layers for input fet
# * tie_layers2: tie layers for feedback fet
# * sd_rmult: sd_rmult for both fets

# %%
inverter_config={
        "pdk": gf180, # pdk to use
        "placement" : "vertical", # the two fets can be placed either vertically or horizontally
        "width": (3,3), # width of the input fet and feedback fet respectively.
        "length": (None,None), # length of the input fet and feedback fet respectively. None refers to the min length in the pdk.
        "fingers": (1,1), # no. of fingers of the input fet and feedback fet respectively.
        "multipliers": (1,1), #no. of multipliers of the input fet and feedback fet respectively.
        "dummy_1": (True,True), # dummy pattern for input fet (left,right)
        "dummy_2": (True,True), # dummy pattern for the feedback fet (left,right)
        "tie_layers1": ("met2","met1"), #tapring metal layers for input fet
        "tie_layers2": ("met2","met1"), #tapring metal layers for feedback fet
        "sd_rmult":1, # thickness of the sd metal layer.
}

# %% [markdown]
# ### First: We create a top level component and add a name

# %%
top_level = Component(name="inverter")

# %% [markdown]
# ### Two fets
#
# For our fvf block, we do not want deep nwell. However nmos and pmos primitives have different parameter name for deepnwell.
# For pmos it is set to false by default.We need to set it to false if the device type is given as nmos.
# We could've just set it properly in our nmos_kwargs,
# but since you will probably not code the layout for a notebook, we show a general way of solving this issue.

# %%
pdk=inverter_config["pdk"]
pdk.activate()
# Out:
# 2025-06-26 00:07:21.270 | INFO     | gdsfactory.pdk:activate:337 - 'gf180' PDK is now active

# %%
width=inverter_config["width"]
length=inverter_config["length"]
fingers=inverter_config["fingers"]
multipliers=inverter_config["multipliers"]

dummy_1=inverter_config["dummy_1"]
dummy_2=inverter_config["dummy_2"]
tie_layers1=inverter_config["tie_layers1"]
tie_layers2=inverter_config["tie_layers2"]
sd_rmult=inverter_config["sd_rmult"]

# %%
#fet_1 is the input fet
fet_1 = pmos(pdk, width=width[0], fingers=fingers[0], multipliers=multipliers[0], with_dummy=dummy_1, with_substrate_tap=False, length=length[0], tie_layers=tie_layers1, sd_rmult=sd_rmult, **pmos_kwargs )
#fet_2 is the feedback fet
nmos_kwargs["with_dnwell"] = False
fet_2 = nmos(pdk, width=width[1], fingers=fingers[1], multipliers=multipliers[1], with_dummy=dummy_2, with_substrate_tap=False, length=length[1], tie_layers=tie_layers2, sd_rmult=sd_rmult, **nmos_kwargs)

# %% [markdown]
# Adding the references of the FETs to the top level component

# %%
fet_1_ref = top_level << fet_1
fet_2_ref = top_level << fet_2

#let's take a look at our current state of layout
## To see in Klayout via Klive
#top_level.show()
display_component(top_level, scale = 5,path="../../")
## If you want to save the gds file at this stage
#primary_gds = top_level.write_gds("before_placement.gds")

# %% [markdown]
# ### Placement
#
# When a cell is referenced to the top level, the center of the cell is aligned to the (0,0) co-ordinate.
# As of now, both of our fets are centered at (0,0). We need place them properly depending on the placement parameter.

# %%
placement=inverter_config["placement"]
ref_dimensions = evaluate_bbox(fet_2)

# %% [markdown]
# evaluate_bbox returns maximum width and maximum height of the block as a tuple(width,height).
#
# So here we have `ref_dimensions=(x-dimension of fet_2, y-dimension of fet_2)`
#
# For horizontal placement , we need to move the fet_2 in rightward direction.
# We use the movex function, which moves the center of the block in x-directon upto a certain distance. We need to find out this distance.
# Remember that both fet_1 and fet_2 are centered at (0,0) co-ordinate right now.
# At first we move the center of fet_2 to rightmost point of fet_1 using the xmax function, i.e, (fet_1_ref.xmax,0).
# Now we will find that left half of fet_2 is overlapping with fet_1, so we need to move it at rightward direction again.We move it by ref_dimensionsp[0]/2 distance.
# Now we see that the rightmost point of fet_1 and leftmost point of fet_2 have no seperation between them.
# This will cause a drc error. So we move it again by max seperation needed between two metal layers for drc free layout.
# We move it by 1um again for leaving some routing space for future use.
#
# Vertical placement can be done in similar way by using movey function.

# %%
if placement == "horizontal":
    fet_2_ref.movex(fet_1_ref.xmax)
    display_component(top_level, scale = 2,path="../../")
    fet_2_ref.movex(ref_dimensions[0]/2)
    display_component(top_level, scale = 2,path="../../")
    fet_2_ref.movex(pdk.util_max_metal_seperation()+1)
if placement == "vertical":
    display_component(top_level, scale = 2,path="../../")
    fet_2_ref.movey(fet_1_ref.ymin - ref_dimensions[1]/2 - pdk.util_max_metal_seperation()-1)

# let's see how our block looks after placement
display_component(top_level, scale = 2,path="../../")
## To see in Klayout via Klive
#top_level.show()

# %% [markdown]
#  ### Routing
#
# Now that our fets are properly placed, we need to make proper connections between ports (i.e. Gates, Sources and Drains of the FETs).
# Each port has four directions- East,North,West,South which means 0,90,180,270 degrees respectively.
# You can connect directly to a fet port. For better felxibility in routing, we choose add some intermediate vias here.
#
# ![](_images/port_route.png)

# %%
viam2m3 = via_stack(pdk, "met2", "met3", centered=True) #met2 is the bottom layer. met3 is the top layer.

#we need four such vias
drain_1_via = top_level << viam2m3
source_1_via = top_level << viam2m3
gate_1_via = top_level << viam2m3

drain_2_via = top_level << viam2m3
gate_2_via = top_level << viam2m3

# %% [markdown]
# The move function moves the center of a specific cell to a specific co-ordinate.
# The co-ordinates of the center of a port can be accesed by using cell_name.ports["port_name"].center
# Using these two and other techniques previously discussed, we properly place these 4 vias.

# %%
# drain_1_via.move(fet_1_ref.ports["multiplier_0_drain_W"].center).movex(-0.5*evaluate_bbox(fet_1)[1])

drain_1_via.move(fet_1_ref.ports["multiplier_0_drain_W"].center).movex(-1.5)
drain_2_via.move(fet_2_ref.ports["multiplier_0_drain_W"].center).movex(-1.5)


source_1_via.move(fet_1_ref.ports["multiplier_0_source_E"].center).movex(1.5)



gate_1_via.move(fet_1_ref.ports["multiplier_0_gate_E"].center).movex(1)
gate_2_via.move(fet_2_ref.ports["multiplier_0_gate_E"].center).movex(1)




# let's see where those vias are now
## To see in Klayout via Klive
#top_level.show()
display_component(top_level, scale = 3,path="../../")

# %% [markdown]
# Now that the vias are placed, time to make metal routing.
# There are three basic types of routing available:
#
# - `straight_route` - the ports must be straight to each other, i.e, opposite direction and same x or y coordinate.
# - `L_route` - has a 90&deg; bend, ports must be perpendicular to each other.
# - `c_route` -  has two 90&deg; bends(c shaped), ports must have same direction.
#
# Each routing function has multiple parameters. See [here](https://github.com/idea-fasoc/OpenFASOC/tree/main/openfasoc/generators/glayout/glayout/flow/routing)
#
# ![](_images/route_direction.png)

# %% [markdown]
# Bonus: You can see all avaliable ports by `top_level.pprint_ports()`

# %% [markdown]
# From the schematic, we see that we need to connect these two nodes-
#
# 1. Source of M1 and Drain of M2, we insert two intermediate vias near each of them and connect them.
# 2. Gate of M2 and Drain of M1, we insert two intermediate vias near each of them and connect them.

# %%
#gate Short
top_level << straight_route(pdk, fet_1_ref.ports["multiplier_0_gate_E"], gate_1_via.ports["bottom_met_N"])
top_level << straight_route(pdk, fet_2_ref.ports["multiplier_0_gate_E"], gate_2_via.ports["bottom_met_W"])

#Drain Short

top_level << straight_route(pdk, fet_1_ref.ports["multiplier_0_drain_W"], drain_1_via.ports["bottom_met_E"])
top_level << straight_route(pdk, fet_2_ref.ports["multiplier_0_drain_W"], drain_2_via.ports["bottom_met_E"])

if placement == "horizontal":
    top_level << c_route(pdk, gate_1_via.ports["top_met_S"], gate_2_via.ports["top_met_S"],extension=1.2*max(width[0],width[1]), width1=0.32, width2=0.32, cwidth=0.32, e1glayer="met3", e2glayer="met3", cglayer="met2")
    top_level << c_route(pdk, drain_1_via.ports["top_met_N"], drain_2_via.ports["top_met_N"],extension=1.2*max(width[0],width[1]), width1=0.32, width2=0.32, cwidth=0.32, e1glayer="met3", e2glayer="met3", cglayer="met2")
if placement == "vertical":
    top_level << straight_route(pdk, gate_1_via.ports["top_met_S"], gate_2_via.ports["top_met_S"])
    top_level << straight_route(pdk, drain_1_via.ports["top_met_N"], drain_2_via.ports["top_met_N"])

top_level << straight_route(pdk, fet_1_ref.ports["multiplier_0_source_E"], source_1_via.ports["bottom_met_W"])

try:
    top_level << straight_route(pdk, fet_2_ref.ports["multiplier_0_source_W"], fet_2_ref.ports["tie_W_top_met_W"], glayer1=tie_layers2[1], width=0.2*sd_rmult, fullbottom=True)
except:
    pass

# let's see how those vias are now routed
#top_level.show()
display_component(top_level, scale = 3,path="../../")

# %% [markdown]
# Notice how in the above lines, ports used in straight routing has the opposite direction, e.g. (E,W) but ports used in c_route has the same direction (N,N).

# %% [markdown]
# ### Renaming Ports
#
# We need to rename ports and add them to the top level component for ease of routing in hierarchial design.
# Here we rename ports by adding appropriate prefix to the all ready existing port names.

# %%
top_level.add_ports(fet_1_ref.get_ports_list(), prefix="A_")
top_level.add_ports(fet_2_ref.get_ports_list(), prefix="B_")
top_level.add_ports(drain_1_via.get_ports_list(), prefix="A_drain_")
top_level.add_ports(source_1_via.get_ports_list(), prefix="A_source_")
top_level.add_ports(gate_1_via.get_ports_list(), prefix="A_gate_")
top_level.add_ports(drain_2_via.get_ports_list(), prefix="B_drain_")
top_level.add_ports(gate_2_via.get_ports_list(), prefix="B_gate_")

# %%
component = component_snap_to_grid(rename_ports_by_orientation(top_level))

# Now that our block is complete, let's see how it looks now!!
#component.show()
display_component(component, scale = 2,path="../../")
#component.show()
##fvf_gds = component.write_gds("fvf.gds")

# %% [markdown]
# Printing List of Ports of the Component

# %%
## To see all Ports
# component.pprint_ports()

## To see selected ports
# for s in component.get_ports_list():
#     if len(s.name.split("_")) <4:
#         if set(["A","gate"]).issubset(set(s.name.split("_"))):
#             print(s.name, s.port_type , s.orientation, s.center, s.width, s.layer)

# %% [markdown]
# ### Add Pins
# We need to add i/o pins, power supply pins and bias pins to a circuit. This will be needed later to do LVS check(Layout Vs Schematic) and parasitic extraction(PEX).
# Our flipped voltage follwer has four pins- VIN, VOUT, Ib, VBULK

# %%
psize=(0.5,0.5)
# list that will contain all port/comp info
move_info = list()
# create labels and append to info list

# %%
# gnd
gndlabel = rectangle(layer=pdk.get_glayer("met3_pin"),size=psize,centered=True).copy()
gndlabel.add_label(text="VBULK",layer=pdk.get_glayer("met3_label"))
move_info.append((gndlabel,component.ports["B_tie_N_top_met_N"],None))
#gnd_ref = top_level << gndlabel;



#currentbias
ibiaslabel = rectangle(layer=pdk.get_glayer("met3_pin"),size=psize,centered=True).copy()
ibiaslabel.add_label(text="VDD",layer=pdk.get_glayer("met3_pin"))
move_info.append((ibiaslabel,component.ports["A_source_top_met_N"],None))
#ib_ref = top_level << ibiaslabel;


# output
outputlabel = rectangle(layer=pdk.get_glayer("met3_pin"),size=psize,centered=True).copy()
outputlabel.add_label(text="VOUT",layer=pdk.get_glayer("met3_pin"))
move_info.append((outputlabel,component.ports["A_drain_top_met_N"],None))
#op_ref = top_level << outputlabel;


# input
inputlabel = rectangle(layer=pdk.get_glayer("met3_pin"),size=psize,centered=True).copy()
inputlabel.add_label(text="VIN",layer=pdk.get_glayer("met3_pin"))
move_info.append((inputlabel,component.ports["A_gate_top_met_N"], None))
#ip_ref = top_level << inputlabel;


for comp, prt, alignment in move_info:
        alignment = ('c','b') if alignment is None else alignment
        compref = align_comp_to_port(comp, prt, alignment=alignment)
        top_level.add(compref)
component = top_level.flatten()


component.show()
display_component(top_level, scale =5,path="../../")
# Out:
# /headless/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/show.py:40: UserWarning: Unnamed cells, 1 in 'Unnamed_667f42f0'
#   gdspath = component.write_gds(
# 2025-06-26 00:07:27.050 | WARNING  | gdsfactory.klive:show:48 - Could not connect to klive server. Is klayout open and klive plugin installed?

# %% [markdown]
# ## Note
# Now, lets construct the Pcell and export this code as a `.py` file. This is how your cell contributions should be structured.

# %%
fvf_code_string = """
from glayout import MappedPDK, sky130 , gf180
from gdsfactory.cell import cell
from gdsfactory import Component
from gdsfactory.components import text_freetype, rectangle

from glayout import nmos, pmos
from glayout import via_stack
from glayout import rename_ports_by_orientation
from glayout import tapring

from glayout.util.comp_utils import evaluate_bbox, prec_center, prec_ref_center, align_comp_to_port
from glayout.util.port_utils import add_ports_perimeter,print_ports
from glayout.util.snap_to_grid import component_snap_to_grid
from glayout.spice.netlist import Netlist

from glayout.routing.straight_route import straight_route
from glayout.routing.c_route import c_route
from glayout.routing.L_route import L_route

def add_fvf_labels(
    fvf_in: Component,
    pdk: MappedPDK,
    ) -> Component:
    
    fvf_in.unlock()

    psize=(0.5,0.5)
    # list that will contain all port/comp info
    move_info = list()
    # create labels and append to info list

    gndlabel = rectangle(layer=pdk.get_glayer("met3_pin"),size=psize,centered=True).copy()
    gndlabel.add_label(text="VBULK",layer=pdk.get_glayer("met3_label"))
    move_info.append((gndlabel,component.ports["B_tie_N_top_met_N"],None))
    #gnd_ref = top_level << gndlabel;
    
    
    
    #currentbias
    ibiaslabel = rectangle(layer=pdk.get_glayer("met3_pin"),size=psize,centered=True).copy()
    ibiaslabel.add_label(text="VDD",layer=pdk.get_glayer("met3_pin"))
    move_info.append((ibiaslabel,component.ports["A_source_top_met_N"],None))
    #ib_ref = top_level << ibiaslabel;
    
    
    # output
    outputlabel = rectangle(layer=pdk.get_glayer("met3_pin"),size=psize,centered=True).copy()
    outputlabel.add_label(text="VOUT",layer=pdk.get_glayer("met3_pin"))
    move_info.append((outputlabel,component.ports["A_drain_top_met_N"],None))
    #op_ref = top_level << outputlabel;
    
    
    # input
    inputlabel = rectangle(layer=pdk.get_glayer("met3_pin"),size=psize,centered=True).copy()
    inputlabel.add_label(text="VIN",layer=pdk.get_glayer("met3_pin"))
    move_info.append((inputlabel,component.ports["A_gate_top_met_N"], None))
    #ip_ref = top_level << inputlabel;


    
    # move everything to position
    for comp, prt, alignment in move_info:
        alignment = ('c','b') if alignment is None else alignment
        compref = align_comp_to_port(comp, prt, alignment=alignment)
        fvf_in.add(compref)
        
    return fvf_in.flatten() 

@cell
def  inverter(
        pdk: MappedPDK,
        placement: str = "horizontal",
        width: tuple[float,float] = (3,3),
        length: tuple[float,float] = (None,None),
        fingers: tuple[int,int] = (1,1),
        multipliers: tuple[int,int] = (1,1),
        dummy_1: tuple[bool,bool] = (True,True),
        dummy_2: tuple[bool,bool] = (True,True),
        tie_layers1: tuple[str,str] = ("met2","met1"),
        tie_layers2: tuple[str,str] = ("met2","met1"),
        sd_rmult: int=1,
        **kwargs
        ) -> Component:

    pdk.activate()
    
    #top level component
    top_level = Component(name="inverter")

    #two fets
    #fet_1 is the input fet
    fet_1 = pmos(pdk, width=width[0], fingers=fingers[0], multipliers=multipliers[0], with_dummy=dummy_1, with_substrate_tap=False, length=length[0], tie_layers=tie_layers1, sd_rmult=sd_rmult, **pmos_kwargs )
    #fet_2 is the feedback fet
    nmos_kwargs["with_dnwell"] = False
    fet_2 = nmos(pdk, width=width[1], fingers=fingers[1], multipliers=multipliers[1], with_dummy=dummy_2, with_substrate_tap=False, length=length[1], tie_layers=tie_layers2, sd_rmult=sd_rmult, **nmos_kwargs)
    
    fet_1_ref = top_level << fet_1
    fet_2_ref = top_level << fet_2 

    #Relative move
    ref_dimensions = evaluate_bbox(fet_2)
    if placement == "horizontal":
        fet_2_ref.movex(fet_1_ref.xmax + ref_dimensions[0]/2 + pdk.util_max_metal_seperation()+1)
    if placement == "vertical":
        fet_2_ref.movey(fet_1_ref.ymin - ref_dimensions[1]/2 - pdk.util_max_metal_seperation()-1)
    
    #Routing
    viam2m3 = via_stack(pdk, "met2", "met3", centered=True) #met2 is the bottom layer. met3 is the top layer.
    
    #we need four such vias
    drain_1_via = top_level << viam2m3
    source_1_via = top_level << viam2m3
    gate_1_via = top_level << viam2m3
    
    drain_2_via = top_level << viam2m3
    gate_2_via = top_level << viam2m3
    
        
    drain_1_via.move(fet_1_ref.ports["multiplier_0_drain_W"].center).movex(-1.5)
    drain_2_via.move(fet_2_ref.ports["multiplier_0_drain_W"].center).movex(-1.5)
    
    
    source_1_via.move(fet_1_ref.ports["multiplier_0_source_E"].center).movex(1.5)
    
    
    
    gate_1_via.move(fet_1_ref.ports["multiplier_0_gate_E"].center).movex(1)
    gate_2_via.move(fet_2_ref.ports["multiplier_0_gate_E"].center).movex(1)
    


    #gate Short
    top_level << straight_route(pdk, fet_1_ref.ports["multiplier_0_gate_E"], gate_1_via.ports["bottom_met_N"])
    top_level << straight_route(pdk, fet_2_ref.ports["multiplier_0_gate_E"], gate_2_via.ports["bottom_met_W"])
    
    #Drain Short
    
    top_level << straight_route(pdk, fet_1_ref.ports["multiplier_0_drain_W"], drain_1_via.ports["bottom_met_E"])
    top_level << straight_route(pdk, fet_2_ref.ports["multiplier_0_drain_W"], drain_2_via.ports["bottom_met_E"])
    
    if placement == "horizontal":
        top_level << c_route(pdk, gate_1_via.ports["top_met_S"], gate_2_via.ports["top_met_S"],extension=1.2*max(width[0],width[1]), width1=0.32, width2=0.32, cwidth=0.32, e1glayer="met3", e2glayer="met3", cglayer="met2")
        top_level << c_route(pdk, drain_1_via.ports["top_met_N"], drain_2_via.ports["top_met_N"],extension=1.2*max(width[0],width[1]), width1=0.32, width2=0.32, cwidth=0.32, e1glayer="met3", e2glayer="met3", cglayer="met2")
    if placement == "vertical":
        top_level << straight_route(pdk, gate_1_via.ports["top_met_S"], gate_2_via.ports["top_met_S"])
        top_level << straight_route(pdk, drain_1_via.ports["top_met_N"], drain_2_via.ports["top_met_N"])
    
    top_level << straight_route(pdk, fet_1_ref.ports["multiplier_0_source_E"], source_1_via.ports["bottom_met_W"])
    
    try:
        top_level << straight_route(pdk, fet_2_ref.ports["multiplier_0_source_W"], fet_2_ref.ports["tie_W_top_met_W"], glayer1=tie_layers2[1], width=0.2*sd_rmult, fullbottom=True)
    except:
        pass

    
    component = component_snap_to_grid(rename_ports_by_orientation(top_level))
    
    return component

if __name__ == "__main__":
\tcomp = flipped_voltage_follower(gf180, device_type='nmos')\n
\t# comp.pprint_ports()\n
\tcomp = add_fvf_labels(comp, gf180)\n
\tcomp.name = "FVF"\n
\tcomp.write_gds('out_FVF.gds')\n
\tcomp.show()\n
\tprint("...Running DRC...")\n
\tdrc_result = gf180.drc_magic(comp, "FVF")\n

"""

fvf_init_string = """
###Glayout FVF Cell.


from .my_FVF import flipped_voltage_follower,add_fvf_labels

__all__ = [
    'flipped_voltage_follower',
    'add_fvf_labels',
] 
"""

directory = "../../INV/"
os.makedirs(directory, exist_ok=True)

# Save to a .py file
with open(directory + "my_INV.py", "w") as file:
    file.write(fvf_code_string)

with open(directory + "__init__.py", "w") as file:
    file.write(fvf_init_string)

# %% [markdown]
# ### Run DRC
# Design Rule Check ensures that the physical layout of an integrated circuit adheres to the manufacturing constraints defined by the foundry, such as minimum spacing, width, and enclosure rules. `Magic` is the tool we use for DRC here.

# %%
component.name="inv"
drc_result = gf180.drc_magic(component, component.name)
# Out:
# 2025-06-26 00:07:27.149 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmp5uekd93q/inv.gds'
# using default pdk_root: /usr/bin/miniconda3/share/pdk/
# Defaulting to stale magic_commands.tcl
#
# Magic 8.3 revision 528 - Compiled on Wed Jun 18 09:45:25 PM CEST 2025.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Loading "/tmp/tmp5uekd93q/magic_commands.tcl" from command line.
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "inv".
# [INFO]: Loading inv
#
# Loading DRC CIF style.
# [INFO]: DONE with /tmp/tmp5uekd93q/inv.rpt
#
# Using technology "gf180mcuD", version 1.0.525-0-gf2e289d
#
# inv count:
#
# ----------------------------------------
#
# Metal2 spacing < 0.28um (M2.2a)
#
# ----------------------------------------
#
#  -0.820um -7.595um -0.320um -7.565um
#
#  -0.320um -7.595um -0.040um -7.565um
#
#  -0.820um 1.495um -0.320um 1.525um
#
#  -0.320um 1.495um -0.040um 1.525um
#
#  0.040um -7.595um 0.820um -7.565um
#
#  0.040um 1.495um 0.820um 1.525um
#
#  0.820um 1.495um 1.100um 1.525um
#
# ----------------------------------------
#
# Metal1 width < 0.23um (M1.1)
#
# ----------------------------------------
#
#  -4.130um -7.245um -0.820um -7.215um
#
# ----------------------------------------

# %% [markdown]
# ### DRC Checking Using External Tools (KLayout)
# Design Rule Check (DRC) is the process of ensuring that a particular layout does not violate the constraints or _design rules_ imposed by the PDK.
#
# [Klayout](https://klayout.de/) is a GDSII viewer and editor that also has a DRC feature. The design rules for the PDK, in this case the GF180 PDK, are described in a `.lydrc` file.
#
# The following cell runs DRC on the component generated in the previous cell. The number of DRC errors reported will be displayed at the end of the output.

# %%
drc_result = gf180.drc(component)
# Out:
# 2025-06-26 00:07:27.595 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmpju53nvqd/inv.gds'
# 2025-06-26 00:07:29 +0200: Memory Usage (646704K) : Starting running GF180MCU Klayout DRC runset on /tmp/tmpju53nvqd/inv.gds
# 2025-06-26 00:07:29 +0200: Memory Usage (646704K) : Loading database to memory is complete.
# 2025-06-26 00:07:29 +0200: Memory Usage (646704K) : GF180MCU Klayout DRC runset output at: /foss/designs/all_last2/gLayout-IHP130/tutorial/gf180inv_drcreport.lyrdb
# 2025-06-26 00:07:29 +0200: Memory Usage (646704K) : Number of threads to use 16
# 2025-06-26 00:07:29 +0200: Memory Usage (646704K) : flat  mode is enabled.
# 2025-06-26 00:07:29 +0200: Memory Usage (646704K) : Read in polygons from layers.
# 2025-06-26 00:07:29 +0200: Memory Usage (647728K) : Starting deriving base layers.
# 2025-06-26 00:07:29 +0200: Memory Usage (648016K) : Evaluate switches.
# 2025-06-26 00:07:29 +0200: Memory Usage (648016K) : FEOL is enabled.
# 2025-06-26 00:07:29 +0200: Memory Usage (648016K) : BEOL is enabled.
# 2025-06-26 00:07:29 +0200: Memory Usage (648016K) : connectivity rules are enabled.
# 2025-06-26 00:07:30 +0200: Memory Usage (648016K) : METAL_TOP Selected is 9K
# 2025-06-26 00:07:30 +0200: Memory Usage (648016K) : METAL_STACK Selected is 6LM
# 2025-06-26 00:07:30 +0200: Memory Usage (648016K) : Wedge enabled  true
# 2025-06-26 00:07:30 +0200: Memory Usage (648016K) : Ball enabled  true
# 2025-06-26 00:07:30 +0200: Memory Usage (648016K) : Gold enabled  true
# 2025-06-26 00:07:30 +0200: Memory Usage (648016K) : MIM Option selected Nan
# 2025-06-26 00:07:30 +0200: Memory Usage (648016K) : Offgrid enabled  true
# 2025-06-26 00:07:30 +0200: Memory Usage (648016K) : Construct connectivity for the design.
# 2025-06-26 00:07:30 +0200: Memory Usage (648016K) : Connectivity rules enabled, Netlist object will be generated.
# 2025-06-26 00:07:30 +0200: Memory Usage (648160K) : Total area of the design is 162.72320000000002 um^2.
# 2025-06-26 00:07:30 +0200: Memory Usage (648160K) : Total no. of polygons in the design is 703
# 2025-06-26 00:07:30 +0200: Memory Usage (648160K) : Initialization and base layers definition.
# 2025-06-26 00:07:30 +0200: Memory Usage (648160K) : Starting GF180MCU DRC rules.
# 2025-06-26 00:07:30 +0200: Memory Usage (648160K) : FEOL section
# 2025-06-26 00:07:30 +0200: Memory Usage (648160K) : Executing rule DN.1
# 2025-06-26 00:07:30 +0200: Memory Usage (648308K) : CONNECTIVITY_RULES section
# 2025-06-26 00:07:30 +0200: Memory Usage (648596K) : Executing rule DN.2a
# 2025-06-26 00:07:30 +0200: Memory Usage (648596K) : Executing rule DN.2b
# 2025-06-26 00:07:30 +0200: Memory Usage (649308K) : Executing rule DN.3
# 2025-06-26 00:07:30 +0200: Memory Usage (649308K) : Executing rule LPW.1_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (649444K) : Executing rule LPW.1_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (649732K) : CONNECTIVITY_RULES section
# 2025-06-26 00:07:30 +0200: Memory Usage (650316K) : Executing rule LPW.2a_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (650316K) : Executing rule LPW.2a_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (650460K) : Executing rule LPW.2b_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (650608K) : Executing rule LPW.2b_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (650608K) : Executing rule LPW.3_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (651040K) : Executing rule LPW.3_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (651180K) : Executing rule LPW.5_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (651180K) : Executing rule LPW.5_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule LPW.11
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule LPW.12
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule NW.1a_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule NW.1a_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule NW.1b_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule NW.1b_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : CONNECTIVITY_RULES section
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule NW.2a_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule NW.2a_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule NW.2b_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule NW.2b_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule NW.3_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule NW.3_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule NW.4_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule NW.4_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule NW.5_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule NW.5_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule NW.6
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule DF.1a_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule DF.1a_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule DF.1c_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule DF.1c_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule DF.2a_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule DF.2a_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule DF.2b_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule DF.2b_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule DF.3a_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule DF.3a_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule DF.3b_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule DF.3b_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule DF.3c_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule DF.3c_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule DF.4a_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule DF.4a_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (651468K) : Executing rule DF.4b_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (651612K) : Executing rule DF.4b_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (652048K) : Executing rule DF.4c_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (652632K) : Executing rule DF.4c_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (653068K) : Executing rule DF.4d_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (653940K) : Executing rule DF.4d_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (654520K) : Executing rule DF.4e_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (654876K) : Executing rule DF.4e_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (655168K) : Executing rule DF.5_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (655604K) : Executing rule DF.5_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (656040K) : Executing rule DF.6_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (656332K) : Executing rule DF.6_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (656768K) : Executing rule DF.7_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (656768K) : Executing rule DF.7_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (656768K) : Executing rule DF.8_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (656768K) : Executing rule DF.8_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (656768K) : Executing rule DF.9_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (656768K) : Executing rule DF.9_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (656768K) : Executing rule DF.10_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (656768K) : Executing rule DF.10_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (656768K) : Executing rule DF.11_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (656768K) : Executing rule DF.11_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (656768K) : Executing rule DF.12_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (656768K) : Executing rule DF.12_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (656768K) : Executing rule DF.13_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (656768K) : Executing rule DF.13_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (656768K) : Executing rule DF.14_3.3V
# 2025-06-26 00:07:30 +0200: Memory Usage (656768K) : Executing rule DF.14_5V
# 2025-06-26 00:07:30 +0200: Memory Usage (656768K) : Executing rule DF.16_3.3V
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule DF.16_5V
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule DF.17_3.3V
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule DF.17_5V
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule DF.18_3.3V
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule DF.18_5V
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule DF.19_3.3V
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule DF.19_5V
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule DV.1
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule DV.2
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule DV.3
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule DV.5
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule DV.6
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule DV.7
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule DV.8
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule DV.9
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule PL.1_3.3V
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule PL.1_5V
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule PL.1a_3.3V
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule PL.1a_5V
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule PL.2_3.3V
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule PL.2_5V
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule PL.3a_3.3V
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule PL.3a_5V
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule PL.4_3.3V
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule PL.4_5V
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule PL.5a_3.3V
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule PL.5a_5V
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule PL.5b_3.3V
# 2025-06-26 00:07:31 +0200: Memory Usage (656768K) : Executing rule PL.5b_5V
# 2025-06-26 00:07:31 +0200: Memory Usage (656912K) : Executing rule PL.6
# 2025-06-26 00:07:31 +0200: Memory Usage (657496K) : Executing rule PL.7_3.3V
# 2025-06-26 00:07:31 +0200: Memory Usage (657784K) : Executing rule PL.7_5V
# 2025-06-26 00:07:31 +0200: Memory Usage (657932K) : Executing rule PL.9
# 2025-06-26 00:07:31 +0200: Memory Usage (658076K) : Executing rule PL.11
# 2025-06-26 00:07:31 +0200: Memory Usage (658220K) : Executing rule PL.12
# 2025-06-26 00:07:31 +0200: Memory Usage (658368K) : Executing rule NP.1
# 2025-06-26 00:07:31 +0200: Memory Usage (658512K) : Executing rule NP.2
# 2025-06-26 00:07:31 +0200: Memory Usage (658660K) : Executing rule NP.3a
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule NP.3bi
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule NP.3bii
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule NP.3ci
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule NP.3cii
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule NP.3d
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule NP.3e
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule NP.4a
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule NP.4b
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule NP.5a
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule NP.5b
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule NP.5ci
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule NP.5cii
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule NP.5di
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule NP.5dii
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule NP.6
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule NP.7
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule NP.8a
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule NP.8b
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule NP.9
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule NP.10
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule NP.11
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule NP.12
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule PP.1
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule PP.2
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule PP.3a
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule PP.3bi
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule PP.3bii
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule PP.3ci
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule PP.3cii
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule PP.3d
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule PP.3e
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule PP.4a
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule PP.4b
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule PP.5a
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule PP.5b
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule PP.5ci
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule PP.5cii
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule PP.5di
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule PP.5dii
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule PP.6
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule PP.7
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule PP.8a
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule PP.8b
# 2025-06-26 00:07:31 +0200: Memory Usage (659076K) : Executing rule PP.9
# 2025-06-26 00:07:31 +0200: Memory Usage (659140K) : Executing rule PP.10
# 2025-06-26 00:07:31 +0200: Memory Usage (659432K) : Executing rule PP.11
# 2025-06-26 00:07:31 +0200: Memory Usage (659432K) : Executing rule PP.12
# 2025-06-26 00:07:31 +0200: Memory Usage (659432K) : Executing rule SB.1
# 2025-06-26 00:07:31 +0200: Memory Usage (659432K) : Executing rule SB.2
# 2025-06-26 00:07:31 +0200: Memory Usage (659432K) : Executing rule SB.3
# 2025-06-26 00:07:31 +0200: Memory Usage (659432K) : Executing rule SB.4
# 2025-06-26 00:07:31 +0200: Memory Usage (659432K) : Executing rule SB.5a
# 2025-06-26 00:07:31 +0200: Memory Usage (659432K) : Executing rule SB.5b
# 2025-06-26 00:07:31 +0200: Memory Usage (659432K) : Executing rule SB.6
# 2025-06-26 00:07:31 +0200: Memory Usage (659432K) : Executing rule SB.7
# 2025-06-26 00:07:31 +0200: Memory Usage (659432K) : Executing rule SB.8
# 2025-06-26 00:07:31 +0200: Memory Usage (651204K) : Executing rule SB.9
# 2025-06-26 00:07:31 +0200: Memory Usage (651204K) : Executing rule SB.10
# 2025-06-26 00:07:31 +0200: Memory Usage (651204K) : Executing rule SB.11
# 2025-06-26 00:07:31 +0200: Memory Usage (651204K) : Executing rule SB.12
# 2025-06-26 00:07:31 +0200: Memory Usage (651204K) : Executing rule SB.13
# 2025-06-26 00:07:31 +0200: Memory Usage (651204K) : Executing rule SB.14a
# 2025-06-26 00:07:31 +0200: Memory Usage (651204K) : Executing rule SB.14b
# 2025-06-26 00:07:31 +0200: Memory Usage (651204K) : Executing rule SB.15a
# 2025-06-26 00:07:31 +0200: Memory Usage (651204K) : Executing rule SB.15b
# 2025-06-26 00:07:31 +0200: Memory Usage (651204K) : Executing rule SB.16
# 2025-06-26 00:07:31 +0200: Memory Usage (651204K) : Executing rule ESD.1
# 2025-06-26 00:07:31 +0200: Memory Usage (651204K) : Executing rule ESD.2
# 2025-06-26 00:07:31 +0200: Memory Usage (651204K) : Executing rule ESD.3a
# 2025-06-26 00:07:32 +0200: Memory Usage (651204K) : Executing rule ESD.3b
# 2025-06-26 00:07:32 +0200: Memory Usage (651204K) : Executing rule ESD.4a
# 2025-06-26 00:07:32 +0200: Memory Usage (651204K) : Executing rule ESD.4b
# 2025-06-26 00:07:32 +0200: Memory Usage (651204K) : Executing rule ESD.5a
# 2025-06-26 00:07:32 +0200: Memory Usage (651204K) : Executing rule ESD.5b
# 2025-06-26 00:07:32 +0200: Memory Usage (651204K) : Executing rule ESD.6
# 2025-06-26 00:07:32 +0200: Memory Usage (651204K) : Executing rule ESD.7
# 2025-06-26 00:07:32 +0200: Memory Usage (651204K) : Executing rule ESD.8
# 2025-06-26 00:07:32 +0200: Memory Usage (651204K) : Executing rule ESD.pl
# 2025-06-26 00:07:32 +0200: Memory Usage (651204K) : Executing rule ESD.9
# 2025-06-26 00:07:32 +0200: Memory Usage (651204K) : Executing rule ESD.10
# 2025-06-26 00:07:32 +0200: Memory Usage (651204K) : Executing rule CO.1
# 2025-06-26 00:07:32 +0200: Memory Usage (651204K) : Executing rule CO.2a
# 2025-06-26 00:07:32 +0200: Memory Usage (651204K) : Executing rule CO.2b
# 2025-06-26 00:07:32 +0200: Memory Usage (651204K) : Executing rule CO.3
# 2025-06-26 00:07:32 +0200: Memory Usage (651204K) : Executing rule CO.4
# 2025-06-26 00:07:32 +0200: Memory Usage (651204K) : Executing rule CO.5a
# 2025-06-26 00:07:32 +0200: Memory Usage (651204K) : Executing rule CO.5b
# 2025-06-26 00:07:32 +0200: Memory Usage (651204K) : Executing rule CO.6
# 2025-06-26 00:07:32 +0200: Memory Usage (651932K) : Executing rule CO.6a
# 2025-06-26 00:07:32 +0200: Memory Usage (652512K) : Executing rule CO.6b
# 2025-06-26 00:07:32 +0200: Memory Usage (652948K) : Executing rule CO.7
# 2025-06-26 00:07:32 +0200: Memory Usage (653240K) : Executing rule CO.8
# 2025-06-26 00:07:32 +0200: Memory Usage (653384K) : Executing rule CO.9
# 2025-06-26 00:07:32 +0200: Memory Usage (653532K) : Executing rule CO.10
# 2025-06-26 00:07:32 +0200: Memory Usage (653676K) : Executing rule CO.11
# 2025-06-26 00:07:32 +0200: Memory Usage (653820K) : BEOL section
# 2025-06-26 00:07:32 +0200: Memory Usage (653820K) : Executing rule M1.1
# 2025-06-26 00:07:32 +0200: Memory Usage (653968K) : Executing rule M1.2a
# 2025-06-26 00:07:32 +0200: Memory Usage (654112K) : Executing rule M1.2b
# 2025-06-26 00:07:32 +0200: Memory Usage (654256K) : Executing rule M1.3
# 2025-06-26 00:07:32 +0200: Memory Usage (654404K) : Executing rule M2.1
# 2025-06-26 00:07:32 +0200: Memory Usage (654548K) : Executing rule M2.2a
# 2025-06-26 00:07:32 +0200: Memory Usage (654760K) : Executing rule M2.2b
# 2025-06-26 00:07:32 +0200: Memory Usage (654904K) : Executing rule M2.3
# 2025-06-26 00:07:32 +0200: Memory Usage (655048K) : Executing rule M3.1
# 2025-06-26 00:07:32 +0200: Memory Usage (655260K) : Executing rule M3.2a
# 2025-06-26 00:07:32 +0200: Memory Usage (655404K) : Executing rule M3.2b
# 2025-06-26 00:07:32 +0200: Memory Usage (655612K) : Executing rule M3.3
# 2025-06-26 00:07:32 +0200: Memory Usage (655760K) : Executing rule M4.1
# 2025-06-26 00:07:32 +0200: Memory Usage (655904K) : Executing rule M4.2a
# 2025-06-26 00:07:32 +0200: Memory Usage (656112K) : Executing rule M4.2b
# 2025-06-26 00:07:32 +0200: Memory Usage (656260K) : Executing rule M4.3
# 2025-06-26 00:07:32 +0200: Memory Usage (656404K) : Executing rule M5.1
# 2025-06-26 00:07:32 +0200: Memory Usage (656616K) : Executing rule M5.2a
# 2025-06-26 00:07:32 +0200: Memory Usage (656760K) : Executing rule M5.2b
# 2025-06-26 00:07:32 +0200: Memory Usage (656968K) : Executing rule M5.3
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V1.1
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V1.2a
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V1.2b
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V1.3a
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V1.3c
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V1.3d
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V1.4a
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V1.4b
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V1.4c
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V2.1
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V2.2a
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V2.2b
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V2.3b
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V2.3c
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V2.3d
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V2.4a
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V2.4b
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V2.4c
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V3.1
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V3.2a
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V3.2b
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V3.3b
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V3.3c
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V3.3d
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V3.4a
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V3.4b
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V3.4c
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V4.1
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V4.2a
# 2025-06-26 00:07:32 +0200: Memory Usage (657116K) : Executing rule V4.2b
# 2025-06-26 00:07:32 +0200: Memory Usage (657260K) : Executing rule V4.3b
# 2025-06-26 00:07:32 +0200: Memory Usage (657988K) : Executing rule V4.3c
# 2025-06-26 00:07:32 +0200: Memory Usage (658568K) : Executing rule V4.3d
# 2025-06-26 00:07:32 +0200: Memory Usage (658860K) : Executing rule V4.4a
# 2025-06-26 00:07:32 +0200: Memory Usage (659732K) : Executing rule V4.4b
# 2025-06-26 00:07:32 +0200: Memory Usage (660316K) : Executing rule V4.4c
# 2025-06-26 00:07:32 +0200: Memory Usage (660668K) : Executing rule V5.1
# 2025-06-26 00:07:32 +0200: Memory Usage (660816K) : Executing rule V5.2a
# 2025-06-26 00:07:32 +0200: Memory Usage (661396K) : Executing rule V5.2b
# 2025-06-26 00:07:32 +0200: Memory Usage (661544K) : Executing rule V5.3b
# 2025-06-26 00:07:32 +0200: Memory Usage (662400K) : Executing rule V5.3c
# 2025-06-26 00:07:32 +0200: Memory Usage (663044K) : Executing rule V5.3d
# 2025-06-26 00:07:32 +0200: Memory Usage (663336K) : Executing rule V5.4a
# 2025-06-26 00:07:32 +0200: Memory Usage (664256K) : Executing rule V5.4b
# 2025-06-26 00:07:32 +0200: Memory Usage (665108K) : Executing rule V5.4c
# 2025-06-26 00:07:32 +0200: Memory Usage (665400K) : MetalTop thickness 9k/11k section
# 2025-06-26 00:07:32 +0200: Memory Usage (665400K) : Executing rule MT.1
# 2025-06-26 00:07:32 +0200: Memory Usage (665608K) : Executing rule MT.2a
# 2025-06-26 00:07:32 +0200: Memory Usage (665756K) : Executing rule MT.4
# 2025-06-26 00:07:32 +0200: Memory Usage (665820K) : Executing rule MC.1
# 2025-06-26 00:07:32 +0200: Memory Usage (665988K) : Executing rule MC.2
# 2025-06-26 00:07:32 +0200: Memory Usage (665988K) : Executing rule MC.3
# 2025-06-26 00:07:32 +0200: Memory Usage (665988K) : Executing rule MC.4
# 2025-06-26 00:07:32 +0200: Memory Usage (665988K) : Executing rule PRES.1
# 2025-06-26 00:07:32 +0200: Memory Usage (665988K) : Executing rule PRES.2
# 2025-06-26 00:07:32 +0200: Memory Usage (665988K) : Executing rule PRES.3
# 2025-06-26 00:07:32 +0200: Memory Usage (665988K) : Executing rule PRES.4
# 2025-06-26 00:07:32 +0200: Memory Usage (665988K) : Executing rule PRES.5
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule PRES.6
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule PRES.7
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule PRES.9a
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule PRES.9b
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule LRES.1
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule LRES.2
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule LRES.3
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule LRES.4
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule LRES.5
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule LRES.6
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule LRES.7
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule LRES.9a
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule LRES.9b
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule HRES.1
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule HRES.2
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule HRES.3
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule HRES.4
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule HRES.5
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule HRES.6
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule HRES.7
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule HRES.8
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule HRES.9
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule HRES.10
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule HRES.12a
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule HRES.12b
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : No MIM Capacitor Option Selected section
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule NAT.1
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule NAT.2
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule NAT.3
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule NAT.4
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule NAT.5
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : CONNECTIVITY_RULES section
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule NAT.6
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule NAT.7
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule NAT.8
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule NAT.9
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule NAT.10
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule NAT.11
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule NAT.12
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule BJT.1
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule BJT.2
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule BJT.3
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule DE.2
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule DE.3
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule DE.4
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule LVS_BJT.1
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule O.DF.3a
# 2025-06-26 00:07:33 +0200: Memory Usage (665988K) : Executing rule O.DF.6
# 2025-06-26 00:07:33 +0200: Memory Usage (666052K) : Executing rule O.DF.9
# 2025-06-26 00:07:33 +0200: Memory Usage (666052K) : Executing rule O.PL.2
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule O.PL.3a
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule O.PL.4
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule O.SB.2
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule O.SB.3
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule O.SB.4
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule O.SB.5b_3.3V
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule O.SB.9
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule O.SB.11
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule O.SB.13_3.3V
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule O.SB.13_5V
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule O.CO.7
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule O.PL.ORT
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.01
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.02
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.03
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.04a
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.04b
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.04c
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.04d
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.05
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.06
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.07
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.08
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.09
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.10
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.11
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.12
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.13
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.14
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.15
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.16a
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.16b
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.17
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.18
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.19
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.20
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.21
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.22a
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule EF.22b
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule MDN.1
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : CONNECTIVITY_RULES section
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule MDN.2a
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule MDN.2b
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule MDN.3a
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule MDN.3b
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule MDN.4a
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule MDN.4b
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule MDN.5ai
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule MDN.5aii
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule MDN.5b
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule MDN.5c
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule MDN.6
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule MDN.6a
# 2025-06-26 00:07:33 +0200: Memory Usage (666116K) : Executing rule MDN.7
# 2025-06-26 00:07:33 +0200: Memory Usage (666180K) : Executing rule MDN.7a
# 2025-06-26 00:07:33 +0200: Memory Usage (666244K) : CONNECTIVITY_RULES section
# 2025-06-26 00:07:33 +0200: Memory Usage (666244K) : Executing rule MDN.8a
# 2025-06-26 00:07:33 +0200: Memory Usage (666308K) : Executing rule MDN.8b
# 2025-06-26 00:07:33 +0200: Memory Usage (666308K) : Executing rule MDN.9
# 2025-06-26 00:07:33 +0200: Memory Usage (666372K) : Executing rule MDN.10a
# 2025-06-26 00:07:33 +0200: Memory Usage (666372K) : Executing rule MDN.10b
# 2025-06-26 00:07:33 +0200: Memory Usage (666436K) : Executing rule MDN.10c
# 2025-06-26 00:07:33 +0200: Memory Usage (666436K) : Executing rule MDN.10d
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDN.10ei
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDN.10eii
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDN.10f
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDN.11
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDN.12
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDN.13a
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDN.13b
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDN.13c
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDN.13d
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDN.14
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDN.15a
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDN.15b
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDN.17
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.1
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.1a
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.2
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.3
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.3ai
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.3aii
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.3b
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.3c
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.3d
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.4
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.4a
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.4b
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.5
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.5a
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.6
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.6a
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.7
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.8
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.9a
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.9b
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.9c
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.9d
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.9ei
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.9eii
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.9f
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.10
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : CONNECTIVITY_RULES section
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.10a
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.10b
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.11
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.12
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.13a
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.13b
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.13c
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.15
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.16a
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.16b
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.17a
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule MDP.17c
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule Y.NW.2b_3.3V
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule Y.NW.2b_5V
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule Y.DF.6_5V
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule Y.DF.16_3.3V
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule Y.DF.16_5V
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule Y.PL.1_3.3V
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule Y.PL.1_5V
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule Y.PL.2_3.3V
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule Y.PL.2_5V
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule Y.PL.4_5V
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule Y.PL.5a_3.3V
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule Y.PL.5a_5V
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule Y.PL.5b_3.3V
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule Y.PL.5b_5V
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule S.DF.4c_MV
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule S.DF.6_MV
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule S.DF.7_MV
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule S.DF.8_MV
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule S.DF.16_MV
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule S.PL.5a_MV
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule S.PL.5b_MV
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule S.CO.4_MV
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule S.DF.4c_LV
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule S.DF.16_LV
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule S.CO.3_LV
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule S.CO.4_LV
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule S.CO.6_ii_LV
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule S.M1.1_LV
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : OFFGRID-ANGLES section
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule comp_OFFGRID
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule dnwell_OFFGRID
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule nwell_OFFGRID
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule lvpwell_OFFGRID
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule dualgate_OFFGRID
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule poly2_OFFGRID
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule nplus_OFFGRID
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule pplus_OFFGRID
# 2025-06-26 00:07:34 +0200: Memory Usage (666436K) : Executing rule sab_OFFGRID
# 2025-06-26 00:07:34 +0200: Memory Usage (666500K) : Executing rule esd_OFFGRID
# 2025-06-26 00:07:34 +0200: Memory Usage (666564K) : Executing rule contact_OFFGRID
# 2025-06-26 00:07:34 +0200: Memory Usage (666628K) : Executing rule metal1_OFFGRID
# 2025-06-26 00:07:34 +0200: Memory Usage (666756K) : Executing rule via1_OFFGRID
# 2025-06-26 00:07:34 +0200: Memory Usage (666820K) : Executing rule metal2_OFFGRID
# 2025-06-26 00:07:34 +0200: Memory Usage (666884K) : Executing rule via2_OFFGRID
# 2025-06-26 00:07:34 +0200: Memory Usage (667012K) : Executing rule metal3_OFFGRID
# 2025-06-26 00:07:34 +0200: Memory Usage (667076K) : Executing rule via3_OFFGRID
# 2025-06-26 00:07:34 +0200: Memory Usage (667140K) : Executing rule metal4_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule via4_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule metal5_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule via5_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule metaltop_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule pad_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule resistor_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule fhres_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule fusetop_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule fusewindow_d_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule polyfuse_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule mvsd_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule mvpsd_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule nat_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule comp_dummy_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule poly2_dummy_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule metal1_dummy_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule metal2_dummy_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule metal3_dummy_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule metal4_dummy_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule metal5_dummy_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule metaltop_dummy_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule comp_label_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule poly2_label_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule metal1_label_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule metal2_label_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule metal3_label_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule metal4_label_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule metal5_label_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule metaltop_label_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule metal1_slot_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule metal2_slot_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule metal3_slot_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule metal4_slot_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule metal5_slot_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule metaltop_slot_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667268K) : Executing rule ubmpperi_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667332K) : Executing rule ubmparray_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667460K) : Executing rule ubmeplate_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667524K) : Executing rule schottky_diode_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667652K) : Executing rule zener_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667716K) : Executing rule res_mk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667844K) : Executing rule opc_drc_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (667908K) : Executing rule ndmy_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668036K) : Executing rule pmndmy_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668100K) : Executing rule v5_xtor_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668228K) : Executing rule cap_mk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668292K) : Executing rule mos_cap_mk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668420K) : Executing rule ind_mk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668484K) : Executing rule diode_mk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule drc_bjt_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule lvs_bjt_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule mim_l_mk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule latchup_mk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule guard_ring_mk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule otp_mk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule mtpmark_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule neo_ee_mk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule sramcore_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule lvs_rf_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule lvs_drain_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule ind_mk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule hvpolyrs_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule lvs_io_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule probe_mk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule esd_mk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule lvs_source_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule well_diode_mk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule ldmos_xtor_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule plfuse_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule efuse_mk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule mcell_feol_mk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule ymtp_mk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule dev_wf_mk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule metal1_blk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule metal2_blk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule metal3_blk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule metal4_blk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule metal5_blk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule metalt_blk_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule pr_bndry_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule mdiode_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule metal1_res_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule metal2_res_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule metal3_res_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule metal4_res_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule metal5_res_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule metal6_res_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : Executing rule border_OFFGRID
# 2025-06-26 00:07:35 +0200: Memory Usage (668612K) : DRC Total Run time 6.122754 seconds
