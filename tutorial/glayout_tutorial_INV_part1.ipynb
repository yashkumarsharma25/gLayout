# %% [markdown]
# # Tutorial 1: **Notebook** - *INV*
#
# **By
# gLayout Team**
#
# __Content creators:__ Subham Pal, Saptarshi Ghosh
#
# __Content reviewers:__ Mehedi Saligne

# %% [markdown]
# ___
# # Tutorial Objectives
#
# This notebook is a tutorial on-
#
# - **Importing** and **Placement** of FETs and other macros/Pcells with relative coordinates + Placing (and connecting) Via_stack on the ports of the FETs + encircling them with padrings.
# - **Routing** between the placed *Vias* with *C_*, *L_*, *Straight_* and *smart* Routes and explaining the differences between these strategies. Particularly explaning the East/West/North/South angles, (For Example, why C has to parallel but L has to be perpendicular sides) and *Placing and connecting PINs for future LVS runs

# %% [markdown]
# ## **Target** **Block** : **Inverter Cell**
#
# The CMOS inverter is a fundamental digital circuit building block, widely used due to its low static power consumption, high noise immunity, and fast switching characteristics. It consists of a complementary pair of MOSFETs: one PMOS and one NMOS transistor, with their gates and drains connected together. The source of the PMOS is connected to the supply voltage (VDD), while the source of the NMOS is connected to ground (VSS).
#
# ### **Operation Principle**
# - **Input Low (Logic 0):** The PMOS transistor turns ON and the NMOS turns OFF. This connects the output (VOUT) to VDD, producing a logic high (1) at the output.
# - **Input High (Logic 1):** The NMOS transistor turns ON and the PMOS turns OFF. This connects the output to ground, producing a logic low (0) at the output.
#
# This complementary switching action ensures that the output is always the logical inverse of the input, making the CMOS inverter a true logic inverter.
#
# ![](_images/CMOS_Inverter.png)
#
# ```bibtex
# Wikimedia Commons contributors. (2010). CMOS Inverter Schematic [Diagram]. Wikimedia Commons. https://commons.wikimedia.org/wiki/File:CMOS_Inverter.svg
# ```

# %% [markdown]
# ## **Layout generation**
# let's go through the step by step procedure to generate LVS and DRC clean layout of a INV cell.
#
#
# ### *Creating environment for live GDSII viewer*
# You can see the generated GDSII file immediately inside this notebook. You can also view it in Klayout for better understanding. Code for viewing it in Klayout is added but commented out.

# %%
## Activate if necessary to install following packages

# !pip install svgutils
# !pip install ipywidgets

# %% [markdown]
# This cell only required for [IIC-OSIC Docker](https://github.com/iic-jku/IIC-OSIC-TOOLS). It imports all neceaasry environment varriable to current session

# %%
import os
import subprocess

# Run a shell, source .bashrc, then printenv
cmd = 'bash -c "source ~/.bashrc && printenv"'
result = subprocess.run(cmd, shell=True, text=True, capture_output=True)
env_vars = {}
for line in result.stdout.splitlines():
    if '=' in line:
        key, value = line.split('=', 1)
        env_vars[key] = value

# Now, update os.environ with these
os.environ.update(env_vars)

# %%
import gdstk
import svgutils.transform as sg
import IPython.display
from IPython.display import clear_output
import ipywidgets as widgets

# Redirect all outputs here
hide = widgets.Output()

def display_gds(gds_file, path,scale = 3):
  
  # Generate an SVG image
  top_level_cell = gdstk.read_gds(gds_file).top_level()[0]
  top_level_cell.write_svg(os.path.join(path,'out.svg'))
    
  # Scale the image for displaying
  fig = sg.fromfile(os.path.join(path,'out.svg'))
  fig.set_size((str(float(fig.width) * scale), str(float(fig.height) * scale)))
  fig.save(os.path.join(path,'out.svg'))

  # Display the image
  IPython.display.display(IPython.display.SVG(os.path.join(path,'out.svg')))
  os.remove(os.path.join(path,'out.gds'))

def display_component(component,path,scale = 3):
  # Save to a GDS file
  with hide:
    component.write_gds(os.path.join(path,'out.gds'))
  display_gds(os.path.join(path,'out.gds'),path,scale)

# %%
from glayout import MappedPDK, sky130 , gf180
#from gdsfactory.cell import cell
from gdsfactory import Component
from gdsfactory.components import text_freetype, rectangle

# %%
from glayout import nmos, pmos
from glayout import via_stack
from glayout import rename_ports_by_orientation
from glayout import tapring

# %%
from glayout.util.comp_utils import evaluate_bbox, prec_center, prec_ref_center, align_comp_to_port
from glayout.util.port_utils import add_ports_perimeter,print_ports
from glayout.util.snap_to_grid import component_snap_to_grid
from glayout.spice.netlist import Netlist

# %%
from glayout.routing.straight_route import straight_route
from glayout.routing.c_route import c_route
from glayout.routing.L_route import L_route

# %% [markdown]
# INV has two complimentary fets as shown in the schematic. One is PMOS and another is NMOS. Their operations in INV are explained above. Lets define arguments for the FETs

# %%
nmos_kwargs = {
    "with_tie": True,
    "with_dnwell": True,
    "sd_route_topmet": "met2",
    "gate_route_topmet": "met2",
    "sd_route_left": True,
    "rmult": None,
    "gate_rmult": 1,
    "interfinger_rmult": 1,
    "substrate_tap_layers": ("met2","met1"),
    "dummy_routes": True
}

pmos_kwargs = {
    "with_tie": True,
    "dnwell": False,
    "sd_route_topmet": "met2",
    "gate_route_topmet": "met2",
    "sd_route_left": True,
    "rmult": None,
    "gate_rmult": 1,
    "interfinger_rmult": 1,
    "substrate_tap_layers": ("met2","met1"),
    "dummy_routes": True
}

# %% [markdown]
# There is no need to manually define the kwargs for your code. This is only done for this notebook implementation.
#
#
# Now, Let's create a list for parameters which we need for our function-
#
# * pdk: pdk to use
# * placement: either "horizontal" or "vertical"
# * width: (input fet, feedback fet)
# * length: (input fet, feedback fet)
# * fingers: (input fet, feedback fet)
# * multipliers: (input fet, feedback fet)
# * dummy_1: dummy for input fet
# * dummy_2: dummy for feedback fet

# %%
inverter_config={
        "pdk": gf180, # pdk to use
        "placement" : "horizontal", # the two fets can be placed either vertically or horizontally
        "width": (3,3), # width of the input fet and feedback fet respectively.
        "length": (None,None), # length of the input fet and feedback fet respectively. None refers to the min length in the pdk.
        "fingers": (1,1), # no. of fingers of the input fet and feedback fet respectively.
        "multipliers": (1,1), #no. of multipliers of the input fet and feedback fet respectively.
        "dummy_1": (True,True), # dummy pattern for input fet (left,right)
        "dummy_2": (True,True), # dummy pattern for the feedback fet (left,right)
        "tie_layers1": ("met2","met1"), #tapring metal layers 
        "tie_layers2": ("met2","met1"), #tapring metal layers 
        "sd_rmult":1, # thickness of the sd metal layer.
}

# %% [markdown]
# ### First: We create a top level component and add a name

# %%
top_level = Component(name="inverter")

# %% [markdown]
# ### Two fets
#
# For our INV block, we do not want deep nwell. However nmos and pmos primitives have different parameter name for deepnwell.
# For pmos it is set to false by default.We need to set it to false if the device type is given as nmos.
# We could've just set it properly in our nmos_kwargs,
# but since you will probably not code the layout for a notebook, we show a general way of solving this issue.

# %%
pdk=inverter_config["pdk"]
pdk.activate()

# %%
width=inverter_config["width"]
length=inverter_config["length"]
fingers=inverter_config["fingers"]
multipliers=inverter_config["multipliers"]

dummy_1=inverter_config["dummy_1"]
dummy_2=inverter_config["dummy_2"]
tie_layers1=inverter_config["tie_layers1"]
tie_layers2=inverter_config["tie_layers2"]
sd_rmult=inverter_config["sd_rmult"]

# %%
#fet_1 is the input fet
fet_P = pmos(pdk, width=width[0], fingers=fingers[0], multipliers=multipliers[0], with_dummy=dummy_1, with_substrate_tap=False, length=length[0], tie_layers=tie_layers1, sd_rmult=sd_rmult, **pmos_kwargs )
#fet_2 is the feedback fet
nmos_kwargs["with_dnwell"] = False
fet_N = nmos(pdk, width=width[1], fingers=fingers[1], multipliers=multipliers[1], with_dummy=dummy_2, with_substrate_tap=False, length=length[1], tie_layers=tie_layers2, sd_rmult=sd_rmult, **nmos_kwargs)

# %% [markdown]
# Adding the references of the FETs to the top level component

# %%
fet_P_ref = top_level << fet_P
fet_N_ref = top_level << fet_N

fet_P_ref.name = "fet_P"
fet_N_ref.name = "fet_N"

#let's take a look at our current state of layout
## To see in Klayout via Klive
#top_level.show()
display_component(top_level, scale = 5,path="../../")
## If you want to save the gds file at this stage
#primary_gds = top_level.write_gds("before_placement.gds")

# %% [markdown]
# ### Placement
#
# When a cell is referenced to the top level, the center of the cell is aligned to the (0,0) co-ordinate.
# As of now, both of our fets are centered at (0,0). We need place them properly depending on the placement parameter.

# %%
placement=inverter_config["placement"]
ref_dimensions = evaluate_bbox(fet_N)

# %% [markdown]
# evaluate_bbox returns maximum width and maximum height of the block as a tuple(width,height).
#
# So here we have `ref_dimensions=(x-dimension of fet_2, y-dimension of fet_2)`
#
# For horizontal placement , we need to move the fet_2 in rightward direction.
# We use the movex function, which moves the center of the block in x-directon upto a certain distance. We need to find out this distance.
# Remember that both fet_1 and fet_2 are centered at (0,0) co-ordinate right now.
# At first we move the center of fet_2 to rightmost point of fet_1 using the xmax function, i.e, (fet_1_ref.xmax,0).
# Now we will find that left half of fet_2 is overlapping with fet_1, so we need to move it at rightward direction again.We move it by ref_dimensionsp[0]/2 distance.
# Now we see that the rightmost point of fet_1 and leftmost point of fet_2 have no seperation between them.
# This will cause a drc error. So we move it again by max seperation needed between two metal layers for drc free layout.
# We move it by 1um again for leaving some routing space for future use.
#
# Vertical placement can be done in similar way by using movey function.

# %%
if placement == "horizontal":
    fet_N_ref.movex(fet_P_ref.xmax)
    display_component(top_level, scale = 2,path="../../")
    fet_N_ref.movex(ref_dimensions[0]/2)
    display_component(top_level, scale = 2,path="../../")
    fet_N_ref.movex(pdk.util_max_metal_seperation()+1)
elif placement == "vertical":
    display_component(top_level, scale = 2,path="../../")
    fet_N_ref.movey(fet_P_ref.ymin - ref_dimensions[1]/2 - pdk.util_max_metal_seperation()-1)
else:
        raise ValueError("Placement must be either 'horizontal' or 'vertical'.")
    
# let's see how our block looks after placement
display_component(top_level, scale = 2,path="../../")
## To see in Klayout via Klive
#top_level.show()

# %% [markdown]
#  ### Routing
#
# Now that our fets are properly placed, we need to make proper connections between ports (i.e. Gates, Sources and Drains of the FETs).
# Each port has four directions- East,North,West,South which means 0,90,180,270 degrees respectively.
# You can connect directly to a fet port. For better felxibility in routing, we choose add some intermediate vias here.
#
# ![](_images/port_route.png)

# %%
viam2m3 = via_stack(pdk, "met2", "met3", centered=True) #met2 is the bottom layer. met3 is the top layer.

#we need four such vias
drain_P_via = top_level << viam2m3
source_P_via = top_level << viam2m3
gate_P_via = top_level << viam2m3

drain_N_via = top_level << viam2m3
gate_N_via = top_level << viam2m3

# %% [markdown]
# The move function moves the center of a specific cell to a specific co-ordinate.
# The co-ordinates of the center of a port can be accesed by using cell_name.ports["port_name"].center
# Using these two and other techniques previously discussed, we properly place these 4 vias.

# %%
drain_P_via.move(fet_P_ref.ports["multiplier_0_drain_W"].center).movex(-1.5)
drain_N_via.move(fet_N_ref.ports["multiplier_0_drain_W"].center).movex(-1.5)

source_P_via.move(fet_P_ref.ports["multiplier_0_source_E"].center).movex(1.5)

gate_P_via.move(fet_P_ref.ports["multiplier_0_gate_E"].center).movex(1)
gate_N_via.move(fet_N_ref.ports["multiplier_0_gate_E"].center).movex(1)

# let's see where those vias are now
## To see in Klayout via Klive
#top_level.show()
display_component(top_level, scale = 3,path="../../")

# %% [markdown]
# Now that the vias are placed, time to make metal routing.
# There are three basic types of routing available:
#
# - `straight_route` - the ports must be straight to each other, i.e, opposite direction and same x or y coordinate.
# - `L_route` - has a 90&deg; bend, ports must be perpendicular to each other.
# - `c_route` -  has two 90&deg; bends(c shaped), ports must have same direction.
#
# Each routing function has multiple parameters. See [here](https://github.com/idea-fasoc/OpenFASOC/tree/main/openfasoc/generators/glayout/glayout/flow/routing)
#
# ![](_images/route_direction.png)

# %% [markdown]
# Bonus: You can see all avaliable ports by `top_level.pprint_ports()`

# %% [markdown]
# From the schematic, we see that we need to connect these two nodes-
#
# 1. **Connect the Source of M1 (PMOS) to VDD:**
#    Insert an intermediate via near the source of M1 and connect it to the VDD rail using a metal trace.
#
# 2. **Connect the Source of M2 (NMOS) to GND:**
#    Insert an intermediate via near the source of M2 and connect it to the GND rail using a metal trace.
#
# 3. **Connect the Drains of M1 and M2 Together (Output Node):**
#    Insert intermediate vias near the drain of M1 (PMOS) and the drain of M2 (NMOS), then connect them together with a metal trace. This node forms the inverter output.
#
# 4. **Connect the Gates of M1 and M2 Together (Input Node):**
#    Insert intermediate vias near the gate of M1 (PMOS) and the gate of M2 (NMOS), then connect them together with a metal trace. This node forms the inverter input.

# %%
top_level << straight_route(pdk, fet_P_ref.ports["multiplier_0_gate_E"], gate_P_via.ports["bottom_met_N"])
top_level << straight_route(pdk, fet_N_ref.ports["multiplier_0_gate_E"], gate_N_via.ports["bottom_met_W"])
top_level << straight_route(pdk, fet_P_ref.ports["multiplier_0_source_E"], source_P_via.ports["bottom_met_W"])
top_level << straight_route(pdk, fet_P_ref.ports["multiplier_0_drain_W"], drain_P_via.ports["bottom_met_E"])
top_level << straight_route(pdk, fet_N_ref.ports["multiplier_0_drain_W"], drain_N_via.ports["bottom_met_E"])

if placement == "horizontal":
    top_level << c_route(pdk, gate_P_via.ports["top_met_S"], gate_N_via.ports["top_met_S"],extension=1.2*max(width[0],width[1]), width1=0.32, width2=0.32, cwidth=0.32, e1glayer="met3", e2glayer="met3", cglayer="met2")
    top_level << c_route(pdk, drain_P_via.ports["top_met_N"], drain_N_via.ports["top_met_N"],extension=1.2*max(width[0],width[1]), width1=0.32, width2=0.32, cwidth=0.32, e1glayer="met3", e2glayer="met3", cglayer="met2")
elif placement == "vertical":
    top_level << straight_route(pdk, gate_P_via.ports["top_met_S"], gate_N_via.ports["top_met_S"])
    top_level << straight_route(pdk, drain_P_via.ports["top_met_N"], drain_N_via.ports["top_met_N"])
else:
        raise ValueError("Placement must be either 'horizontal' or 'vertical'.")
    
try:
    top_level << straight_route(pdk, fet_N_ref.ports["multiplier_0_source_W"], fet_N_ref.ports["tie_W_top_met_W"], glayer1=tie_layers2[1], fullbottom=True)
except:
    pass

# let's see how those vias are now routed
#top_level.show()
display_component(top_level, scale = 3,path="../../")

# %% [markdown]
# Notice how in the above lines, ports used in straight routing has the opposite direction, e.g. (E,W) but ports used in c_route has the same direction (N,N).

# %% [markdown]
# ### Renaming Ports
#
# We need to rename ports and add them to the top level component for ease of routing in hierarchial design.
# Here we rename ports by adding appropriate prefix to the all ready existing port names.

# %%
top_level.add_ports(fet_P_ref.get_ports_list(), prefix="P_")
top_level.add_ports(fet_N_ref.get_ports_list(), prefix="N_")
top_level.add_ports(drain_P_via.get_ports_list(), prefix="P_drain_")
top_level.add_ports(source_P_via.get_ports_list(), prefix="P_source_")
top_level.add_ports(gate_P_via.get_ports_list(), prefix="P_gate_")
top_level.add_ports(drain_N_via.get_ports_list(), prefix="N_drain_")
top_level.add_ports(gate_N_via.get_ports_list(), prefix="N_gate_")

# %%
component = component_snap_to_grid(rename_ports_by_orientation(top_level))
    
# Now that our block is complete, let's see how it looks now!!
#component.show()
display_component(component, scale = 2,path="../../")
#component.show()
##inv_gds = component.write_gds("inv.gds")

# %% [markdown]
# Printing List of Ports of the Component

# %%
## To see all Ports
# component.pprint_ports()

## To see selected ports
# for s in component.get_ports_list():
#     if len(s.name.split("_")) <4:
#         if set(["P","gate"]).issubset(set(s.name.split("_"))):
#             print(s.name, s.port_type , s.orientation, s.center, s.width, s.layer)

# %% [markdown]
# ### Add Pins
# We need to add i/o pins, power supply pins and bias pins to a circuit. This will be needed later to do LVS check(Layout Vs Schematic) and parasitic extraction(PEX).
# Our inverter has four pins (Nodes) - VIN, VOUT, VDD, VBULK

# %%
psize=(0.5,0.5)
# list that will contain all port/comp info
move_info = list()
# create labels and append to info list

# %%
# gnd
gndlabel = rectangle(layer=pdk.get_glayer("met3_pin"),size=psize,centered=True).copy()
gndlabel.add_label(text="VBULK",layer=pdk.get_glayer("met3_label"))
move_info.append((gndlabel,component.ports["N_tie_N_top_met_N"],None))
#gnd_ref = top_level << gndlabel;



#suply
suplabel = rectangle(layer=pdk.get_glayer("met3_pin"),size=psize,centered=True).copy()
suplabel.add_label(text="VDD",layer=pdk.get_glayer("met3_pin"))
move_info.append((suplabel,component.ports["P_source_top_met_N"],None))
#sup_ref = top_level << suplabel;


# output
outputlabel = rectangle(layer=pdk.get_glayer("met3_pin"),size=psize,centered=True).copy()
outputlabel.add_label(text="VOUT",layer=pdk.get_glayer("met3_pin"))
move_info.append((outputlabel,component.ports["P_drain_top_met_N"],None))
#op_ref = top_level << outputlabel;


# input
inputlabel = rectangle(layer=pdk.get_glayer("met3_pin"),size=psize,centered=True).copy()
inputlabel.add_label(text="VIN",layer=pdk.get_glayer("met3_pin"))
move_info.append((inputlabel,component.ports["P_gate_top_met_N"], None))
#ip_ref = top_level << inputlabel;


for comp, prt, alignment in move_info:
        alignment = ('c','b') if alignment is None else alignment
        compref = align_comp_to_port(comp, prt, alignment=alignment)
        top_level.add(compref)
component = top_level.flatten()


component.show()
display_component(top_level, scale =5,path="../../")
# Out:
# /headless/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/show.py:40: UserWarning: Unnamed cells, 1 in 'Unnamed_c95dc8db'
#   gdspath = component.write_gds(
# 2025-06-26 11:13:16.654 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.3.3", "klayout_version": "0.30.2", "type": "open", "file": "/tmp/gdsfactory/Unnamed_c95dc8db.gds"}

# %% [markdown]
# ## Note
# Now, lets construct the Pcell and export this code as a `.py` file. This is how your cell contributions should be structured.

# %%
inv_code_string = """
from glayout import MappedPDK, sky130 , gf180
from gdsfactory.cell import cell
from gdsfactory import Component
from gdsfactory.components import text_freetype, rectangle

from glayout import nmos, pmos
from glayout import via_stack
from glayout import rename_ports_by_orientation
from glayout import tapring

from glayout.util.comp_utils import evaluate_bbox, prec_center, prec_ref_center, align_comp_to_port
from glayout.util.port_utils import add_ports_perimeter,print_ports
from glayout.util.snap_to_grid import component_snap_to_grid
from glayout.spice.netlist import Netlist

from glayout.routing.straight_route import straight_route
from glayout.routing.c_route import c_route
from glayout.routing.L_route import L_route

import os
import subprocess

# Run a shell, source .bashrc, then printenv
cmd = 'bash -c "source ~/.bashrc && printenv"'
result = subprocess.run(cmd, shell=True, text=True, capture_output=True)
env_vars = {}
for line in result.stdout.splitlines():
    if '=' in line:
        key, value = line.split('=', 1)
        env_vars[key] = value

# Now, update os.environ with these
os.environ.update(env_vars)

def add_inv_labels(
    inv_in: Component,
    pdk: MappedPDK,
    ) -> Component:
    
    inv_in.unlock()

    psize=(0.5,0.5)
    # list that will contain all port/comp info
    move_info = list()
    # create labels and append to info list

    # gnd
    gndlabel = rectangle(layer=pdk.get_glayer("met3_pin"),size=psize,centered=True).copy()
    gndlabel.add_label(text="VBULK",layer=pdk.get_glayer("met3_label"))
    move_info.append((gndlabel,inv_in.ports["N_tie_N_top_met_N"],None))
    #gnd_ref = top_level << gndlabel;



    #suply
    suplabel = rectangle(layer=pdk.get_glayer("met3_pin"),size=psize,centered=True).copy()
    suplabel.add_label(text="VDD",layer=pdk.get_glayer("met3_pin"))
    move_info.append((suplabel,inv_in.ports["P_source_top_met_N"],None))
    #sup_ref = top_level << suplabel;


    # output
    outputlabel = rectangle(layer=pdk.get_glayer("met3_pin"),size=psize,centered=True).copy()
    outputlabel.add_label(text="VOUT",layer=pdk.get_glayer("met3_pin"))
    move_info.append((outputlabel,inv_in.ports["P_drain_top_met_N"],None))
    #op_ref = top_level << outputlabel;


    # input
    inputlabel = rectangle(layer=pdk.get_glayer("met3_pin"),size=psize,centered=True).copy()
    inputlabel.add_label(text="VIN",layer=pdk.get_glayer("met3_pin"))
    move_info.append((inputlabel,inv_in.ports["P_gate_top_met_N"], None))
    #ip_ref = top_level << inputlabel;


    for comp, prt, alignment in move_info:
            alignment = ('c','b') if alignment is None else alignment
            compref = align_comp_to_port(comp, prt, alignment=alignment)
            inv_in.add(compref)
    
    return inv_in.flatten()
@cell
def inverter(
        pdk: MappedPDK,
        placement: str = "horizontal",
        width: tuple[float,float] = (3,3),
        length: tuple[float,float] = (None,None),
        fingers: tuple[int,int] = (1,1),
        multipliers: tuple[int,int] = (1,1),
        dummy_1: tuple[bool,bool] = (True,True),
        dummy_2: tuple[bool,bool] = (True,True),
        tie_layers1: tuple[str,str] = ("met2","met1"),
        tie_layers2: tuple[str,str] = ("met2","met1"),
        sd_rmult: int=1,
        **kwargs
        ) -> Component:

    pdk.activate()
    
    #top level component
    top_level = Component(name="inverter")

    #two fets
    fet_P = pmos(pdk, width=width[0], fingers=fingers[0], multipliers=multipliers[0], with_dummy=dummy_1, with_substrate_tap=False, length=length[0], tie_layers=tie_layers1, sd_rmult=sd_rmult, **kwargs )
    fet_N = nmos(pdk, width=width[1], fingers=fingers[1], multipliers=multipliers[1], with_dummy=dummy_2, with_substrate_tap=False, length=length[1], tie_layers=tie_layers2, sd_rmult=sd_rmult, with_dnwell=False, **kwargs)
    
    fet_P_ref = top_level << fet_P
    fet_N_ref = top_level << fet_N 
    fet_P_ref.name = "fet_P"
    fet_N_ref.name = "fet_N"

    #Relative move
    ref_dimensions = evaluate_bbox(fet_N)
    if placement == "horizontal":
        fet_N_ref.movex(fet_P_ref.xmax + (ref_dimensions[0]/2) + pdk.util_max_metal_seperation()+1)
    elif placement == "vertical":
        fet_N_ref.movey(fet_P_ref.ymin - ref_dimensions[1]/2 - pdk.util_max_metal_seperation()-1)
    else:
        raise ValueError("Placement must be either 'horizontal' or 'vertical'.")

    #Routing
    viam2m3 = via_stack(pdk, "met2", "met3", centered=True) #met2 is the bottom layer. met3 is the top layer.
    
    #we need four such vias
    drain_P_via = top_level << viam2m3
    source_P_via = top_level << viam2m3
    gate_P_via = top_level << viam2m3

    drain_N_via = top_level << viam2m3
    gate_N_via = top_level << viam2m3
    
        
    drain_P_via.move(fet_P_ref.ports["multiplier_0_drain_W"].center).movex(-1.5)
    drain_N_via.move(fet_N_ref.ports["multiplier_0_drain_W"].center).movex(-1.5)

    source_P_via.move(fet_P_ref.ports["multiplier_0_source_E"].center).movex(1.5)

    gate_P_via.move(fet_P_ref.ports["multiplier_0_gate_E"].center).movex(1)
    gate_N_via.move(fet_N_ref.ports["multiplier_0_gate_E"].center).movex(1)


    top_level << straight_route(pdk, fet_P_ref.ports["multiplier_0_gate_E"], gate_P_via.ports["bottom_met_N"])
    top_level << straight_route(pdk, fet_N_ref.ports["multiplier_0_gate_E"], gate_N_via.ports["bottom_met_W"])
    top_level << straight_route(pdk, fet_P_ref.ports["multiplier_0_source_E"], source_P_via.ports["bottom_met_W"])
    top_level << straight_route(pdk, fet_P_ref.ports["multiplier_0_drain_W"], drain_P_via.ports["bottom_met_E"])
    top_level << straight_route(pdk, fet_N_ref.ports["multiplier_0_drain_W"], drain_N_via.ports["bottom_met_E"])

    if placement == "horizontal":
        top_level << c_route(pdk, gate_P_via.ports["top_met_S"], gate_N_via.ports["top_met_S"],extension=1.2*max(width[0],width[1]), width1=0.32, width2=0.32, cwidth=0.32, e1glayer="met3", e2glayer="met3", cglayer="met2")
        top_level << c_route(pdk, drain_P_via.ports["top_met_N"], drain_N_via.ports["top_met_N"],extension=1.2*max(width[0],width[1]), width1=0.32, width2=0.32, cwidth=0.32, e1glayer="met3", e2glayer="met3", cglayer="met2")
    elif placement == "vertical":
        top_level << straight_route(pdk, gate_P_via.ports["top_met_S"], gate_N_via.ports["top_met_S"])
        top_level << straight_route(pdk, drain_P_via.ports["top_met_N"], drain_N_via.ports["top_met_N"])
    else:
        raise ValueError("Placement must be either 'horizontal' or 'vertical'.")

    try:
        top_level << straight_route(pdk, fet_N_ref.ports["multiplier_0_source_W"], fet_N_ref.ports["tie_W_top_met_W"], glayer1=tie_layers2[1], fullbottom=True)
    except:
        pass

    top_level.add_ports(fet_P_ref.get_ports_list(), prefix="P_")
    top_level.add_ports(fet_N_ref.get_ports_list(), prefix="N_")
    top_level.add_ports(drain_P_via.get_ports_list(), prefix="P_drain_")
    top_level.add_ports(source_P_via.get_ports_list(), prefix="P_source_")
    top_level.add_ports(gate_P_via.get_ports_list(), prefix="P_gate_")
    top_level.add_ports(drain_N_via.get_ports_list(), prefix="N_drain_")
    top_level.add_ports(gate_N_via.get_ports_list(), prefix="N_gate_")

    return component_snap_to_grid(rename_ports_by_orientation(top_level))

if __name__ == "__main__":
\tcomp = inverter(gf180)\n
\t# comp.pprint_ports()\n
\tcomp = add_inv_labels(comp, gf180)\n
\tcomp.name = "INV"\n
\tcomp.write_gds('out_INV.gds')\n
\tcomp.show()\n
\tprint("...Running DRC...")\n
\tdrc_result = gf180.drc_magic(comp, "INV")\n
\tdrc_result = gf180.drc(comp)\n
"""

inv_init_string = """
###Glayout FVF Cell.


from .my_INV import inverter,add_inv_labels

__all__ = [
    'inverter',
    'add_inv_labels',
] 
"""

directory = "../../INV/"
os.makedirs(directory, exist_ok=True)

# Save to a .py file
with open(directory + "my_INV.py", "w") as file:
    file.write(inv_code_string)

with open(directory + "__init__.py", "w") as file:
    file.write(inv_init_string)

# %% [markdown]
# ### Run DRC with Magic
# Design Rule Check ensures that the physical layout of an integrated circuit adheres to the manufacturing constraints defined by the foundry, such as minimum spacing, width, and enclosure rules. `Magic` is the tool we use for DRC here.

# %%
component.name="inv"
drc_result = gf180.drc_magic(component, component.name)
# Out:
# 2025-06-26 11:13:16.715 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmp3glh02t2/inv$3.gds'
# using default pdk_root: /usr/bin/miniconda3/share/pdk/
# Defaulting to stale magic_commands.tcl
#
# Magic 8.3 revision 528 - Compiled on Wed Jun 18 09:45:25 PM CEST 2025.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Loading "/tmp/tmp3glh02t2/magic_commands.tcl" from command line.
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "inv$3".
# [INFO]: Loading inv$3
#
# Loading DRC CIF style.
# [INFO]: DONE with /tmp/tmp3glh02t2/inv$3.rpt
#
# Using technology "gf180mcuD", version 1.0.525-0-gf2e289d
#
# inv$3 count:
#
# ----------------------------------------
#
# Metal2 spacing < 0.28um (M2.2a)
#
# ----------------------------------------
#
#  -0.820um 1.495um -0.320um 1.525um
#
#  -0.320um 1.495um -0.040um 1.525um
#
#  0.040um 1.495um 0.820um 1.525um
#
#  10.120um 1.495um 10.620um 1.525um
#
#  10.980um 1.495um 11.760um 1.525um
#
#  0.820um 1.495um 1.100um 1.525um
#
#  10.620um 1.495um 10.900um 1.525um
#
# ----------------------------------------

# %% [markdown]
# ### DRC Checking Using External Tools (KLayout)
# Design Rule Check (DRC) is the process of ensuring that a particular layout does not violate the constraints or _design rules_ imposed by the PDK.
#
# [Klayout](https://klayout.de/) is a GDSII viewer and editor that also has a DRC feature. The design rules for the PDK, in this case the GF180 PDK, are described in a `.lydrc` file.
#
# The following cell runs DRC on the component generated in the previous cell. The number of DRC errors reported will be displayed at the end of the output.

# %%
drc_result = gf180.drc(component)
# Out:
# 2025-06-26 11:13:16.960 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmpas8ybesl/inv$3.gds'
# 2025-06-26 11:13:18 +0200: Memory Usage (646632K) : Starting running GF180MCU Klayout DRC runset on /tmp/tmpas8ybesl/inv$3.gds
# 2025-06-26 11:13:18 +0200: Memory Usage (646632K) : Loading database to memory is complete.
# 2025-06-26 11:13:18 +0200: Memory Usage (646632K) : GF180MCU Klayout DRC runset output at: /foss/designs/all_last2/gLayout-IHP130/tutorial/gf180inv$3_drcreport.lyrdb
# 2025-06-26 11:13:18 +0200: Memory Usage (646696K) : Number of threads to use 16
# 2025-06-26 11:13:18 +0200: Memory Usage (646696K) : flat  mode is enabled.
# 2025-06-26 11:13:18 +0200: Memory Usage (646696K) : Read in polygons from layers.
# 2025-06-26 11:13:18 +0200: Memory Usage (647780K) : Starting deriving base layers.
# 2025-06-26 11:13:18 +0200: Memory Usage (648072K) : Evaluate switches.
# 2025-06-26 11:13:18 +0200: Memory Usage (648072K) : FEOL is enabled.
# 2025-06-26 11:13:18 +0200: Memory Usage (648072K) : BEOL is enabled.
# 2025-06-26 11:13:18 +0200: Memory Usage (648072K) : connectivity rules are enabled.
# 2025-06-26 11:13:18 +0200: Memory Usage (648072K) : METAL_TOP Selected is 9K
# 2025-06-26 11:13:18 +0200: Memory Usage (648072K) : METAL_STACK Selected is 6LM
# 2025-06-26 11:13:18 +0200: Memory Usage (648072K) : Wedge enabled  true
# 2025-06-26 11:13:18 +0200: Memory Usage (648072K) : Ball enabled  true
# 2025-06-26 11:13:18 +0200: Memory Usage (648072K) : Gold enabled  true
# 2025-06-26 11:13:18 +0200: Memory Usage (648072K) : MIM Option selected Nan
# 2025-06-26 11:13:18 +0200: Memory Usage (648072K) : Offgrid enabled  true
# 2025-06-26 11:13:18 +0200: Memory Usage (648072K) : Construct connectivity for the design.
# 2025-06-26 11:13:18 +0200: Memory Usage (648072K) : Connectivity rules enabled, Netlist object will be generated.
# 2025-06-26 11:13:18 +0200: Memory Usage (648376K) : Total area of the design is 283.7982 um^2.
# 2025-06-26 11:13:18 +0200: Memory Usage (648376K) : Total no. of polygons in the design is 727
# 2025-06-26 11:13:18 +0200: Memory Usage (648376K) : Initialization and base layers definition.
# 2025-06-26 11:13:18 +0200: Memory Usage (648376K) : Starting GF180MCU DRC rules.
# 2025-06-26 11:13:18 +0200: Memory Usage (648376K) : FEOL section
# 2025-06-26 11:13:18 +0200: Memory Usage (648376K) : Executing rule DN.1
# 2025-06-26 11:13:18 +0200: Memory Usage (648520K) : CONNECTIVITY_RULES section
# 2025-06-26 11:13:18 +0200: Memory Usage (648812K) : Executing rule DN.2a
# 2025-06-26 11:13:18 +0200: Memory Usage (648812K) : Executing rule DN.2b
# 2025-06-26 11:13:18 +0200: Memory Usage (649392K) : Executing rule DN.3
# 2025-06-26 11:13:18 +0200: Memory Usage (649392K) : Executing rule LPW.1_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (649684K) : Executing rule LPW.1_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (649828K) : CONNECTIVITY_RULES section
# 2025-06-26 11:13:18 +0200: Memory Usage (650264K) : Executing rule LPW.2a_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (650412K) : Executing rule LPW.2a_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (650556K) : Executing rule LPW.2b_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (650704K) : Executing rule LPW.2b_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (650704K) : Executing rule LPW.3_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (650992K) : Executing rule LPW.3_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (651284K) : Executing rule LPW.5_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (651576K) : Executing rule LPW.5_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (651576K) : Executing rule LPW.11
# 2025-06-26 11:13:18 +0200: Memory Usage (651712K) : Executing rule LPW.12
# 2025-06-26 11:13:18 +0200: Memory Usage (651712K) : Executing rule NW.1a_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (652004K) : Executing rule NW.1a_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (652296K) : Executing rule NW.1b_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (652440K) : Executing rule NW.1b_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (652588K) : CONNECTIVITY_RULES section
# 2025-06-26 11:13:18 +0200: Memory Usage (653236K) : Executing rule NW.2a_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (653380K) : Executing rule NW.2a_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (653524K) : Executing rule NW.2b_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (653688K) : Executing rule NW.2b_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (653832K) : Executing rule NW.3_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (653972K) : Executing rule NW.3_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (654136K) : Executing rule NW.4_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (654440K) : Executing rule NW.4_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (654440K) : Executing rule NW.5_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (654872K) : Executing rule NW.5_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (655160K) : Executing rule NW.6
# 2025-06-26 11:13:18 +0200: Memory Usage (655300K) : Executing rule DF.1a_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (655436K) : Executing rule DF.1a_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (655436K) : Executing rule DF.1c_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (655436K) : Executing rule DF.1c_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (655436K) : Executing rule DF.2a_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (655436K) : Executing rule DF.2a_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (655712K) : Executing rule DF.2b_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (655856K) : Executing rule DF.2b_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (655920K) : Executing rule DF.3a_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.3a_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.3b_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.3b_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.3c_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.3c_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.4a_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.4a_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.4b_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.4b_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.4c_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.4c_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.4d_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.4d_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.4e_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.4e_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.5_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.5_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.6_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.6_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.7_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.7_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.8_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.8_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.9_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.9_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.10_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.10_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.11_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.11_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.12_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.12_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.13_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.13_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.14_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.14_5V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.16_3.3V
# 2025-06-26 11:13:18 +0200: Memory Usage (656216K) : Executing rule DF.16_5V
# 2025-06-26 11:13:19 +0200: Memory Usage (656504K) : Executing rule DF.17_3.3V
# 2025-06-26 11:13:19 +0200: Memory Usage (656796K) : Executing rule DF.17_5V
# 2025-06-26 11:13:19 +0200: Memory Usage (656940K) : Executing rule DF.18_3.3V
# 2025-06-26 11:13:19 +0200: Memory Usage (657232K) : Executing rule DF.18_5V
# 2025-06-26 11:13:19 +0200: Memory Usage (657376K) : Executing rule DF.19_3.3V
# 2025-06-26 11:13:19 +0200: Memory Usage (657520K) : Executing rule DF.19_5V
# 2025-06-26 11:13:19 +0200: Memory Usage (657668K) : Executing rule DV.1
# 2025-06-26 11:13:19 +0200: Memory Usage (657960K) : Executing rule DV.2
# 2025-06-26 11:13:19 +0200: Memory Usage (658104K) : Executing rule DV.3
# 2025-06-26 11:13:19 +0200: Memory Usage (658248K) : Executing rule DV.5
# 2025-06-26 11:13:19 +0200: Memory Usage (658540K) : Executing rule DV.6
# 2025-06-26 11:13:19 +0200: Memory Usage (658684K) : Executing rule DV.7
# 2025-06-26 11:13:19 +0200: Memory Usage (658832K) : Executing rule DV.8
# 2025-06-26 11:13:19 +0200: Memory Usage (659120K) : Executing rule DV.9
# 2025-06-26 11:13:19 +0200: Memory Usage (659412K) : Executing rule PL.1_3.3V
# 2025-06-26 11:13:19 +0200: Memory Usage (659560K) : Executing rule PL.1_5V
# 2025-06-26 11:13:19 +0200: Memory Usage (659560K) : Executing rule PL.1a_3.3V
# 2025-06-26 11:13:19 +0200: Memory Usage (659560K) : Executing rule PL.1a_5V
# 2025-06-26 11:13:19 +0200: Memory Usage (659560K) : Executing rule PL.2_3.3V
# 2025-06-26 11:13:19 +0200: Memory Usage (659560K) : Executing rule PL.2_5V
# 2025-06-26 11:13:19 +0200: Memory Usage (659560K) : Executing rule PL.3a_3.3V
# 2025-06-26 11:13:19 +0200: Memory Usage (659560K) : Executing rule PL.3a_5V
# 2025-06-26 11:13:19 +0200: Memory Usage (660284K) : Executing rule PL.4_3.3V
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule PL.4_5V
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule PL.5a_3.3V
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule PL.5a_5V
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule PL.5b_3.3V
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule PL.5b_5V
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule PL.6
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule PL.7_3.3V
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule PL.7_5V
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule PL.9
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule PL.11
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule PL.12
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.1
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.2
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.3a
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.3bi
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.3bii
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.3ci
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.3cii
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.3d
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.3e
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.4a
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.4b
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.5a
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.5b
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.5ci
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.5cii
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.5di
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.5dii
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.6
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.7
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.8a
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.8b
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.9
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.10
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.11
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule NP.12
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule PP.1
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule PP.2
# 2025-06-26 11:13:19 +0200: Memory Usage (655464K) : Executing rule PP.3a
# 2025-06-26 11:13:19 +0200: Memory Usage (655752K) : Executing rule PP.3bi
# 2025-06-26 11:13:19 +0200: Memory Usage (656188K) : Executing rule PP.3bii
# 2025-06-26 11:13:19 +0200: Memory Usage (656476K) : Executing rule PP.3ci
# 2025-06-26 11:13:19 +0200: Memory Usage (656916K) : Executing rule PP.3cii
# 2025-06-26 11:13:19 +0200: Memory Usage (657204K) : Executing rule PP.3d
# 2025-06-26 11:13:19 +0200: Memory Usage (657204K) : Executing rule PP.3e
# 2025-06-26 11:13:19 +0200: Memory Usage (657352K) : Executing rule PP.4a
# 2025-06-26 11:13:19 +0200: Memory Usage (657932K) : Executing rule PP.4b
# 2025-06-26 11:13:19 +0200: Memory Usage (658224K) : Executing rule PP.5a
# 2025-06-26 11:13:19 +0200: Memory Usage (658368K) : Executing rule PP.5b
# 2025-06-26 11:13:19 +0200: Memory Usage (659452K) : Executing rule PP.5ci
# 2025-06-26 11:13:19 +0200: Memory Usage (660096K) : Executing rule PP.5cii
# 2025-06-26 11:13:19 +0200: Memory Usage (660680K) : Executing rule PP.5di
# 2025-06-26 11:13:19 +0200: Memory Usage (661244K) : Executing rule PP.5dii
# 2025-06-26 11:13:19 +0200: Memory Usage (661388K) : Executing rule PP.6
# 2025-06-26 11:13:19 +0200: Memory Usage (661680K) : Executing rule PP.7
# 2025-06-26 11:13:19 +0200: Memory Usage (661888K) : Executing rule PP.8a
# 2025-06-26 11:13:19 +0200: Memory Usage (661888K) : Executing rule PP.8b
# 2025-06-26 11:13:19 +0200: Memory Usage (662036K) : Executing rule PP.9
# 2025-06-26 11:13:19 +0200: Memory Usage (662600K) : Executing rule PP.10
# 2025-06-26 11:13:19 +0200: Memory Usage (663536K) : Executing rule PP.11
# 2025-06-26 11:13:19 +0200: Memory Usage (663536K) : Executing rule PP.12
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule SB.1
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule SB.2
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule SB.3
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule SB.4
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule SB.5a
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule SB.5b
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule SB.6
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule SB.7
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule SB.8
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule SB.9
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule SB.10
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule SB.11
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule SB.12
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule SB.13
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule SB.14a
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule SB.14b
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule SB.15a
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule SB.15b
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule SB.16
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule ESD.1
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule ESD.2
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule ESD.3a
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule ESD.3b
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule ESD.4a
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule ESD.4b
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule ESD.5a
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule ESD.5b
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule ESD.6
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule ESD.7
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule ESD.8
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule ESD.pl
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule ESD.9
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule ESD.10
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule CO.1
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule CO.2a
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule CO.2b
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule CO.3
# 2025-06-26 11:13:19 +0200: Memory Usage (663680K) : Executing rule CO.4
# 2025-06-26 11:13:20 +0200: Memory Usage (663680K) : Executing rule CO.5a
# 2025-06-26 11:13:20 +0200: Memory Usage (663680K) : Executing rule CO.5b
# 2025-06-26 11:13:20 +0200: Memory Usage (663680K) : Executing rule CO.6
# 2025-06-26 11:13:20 +0200: Memory Usage (663680K) : Executing rule CO.6a
# 2025-06-26 11:13:20 +0200: Memory Usage (663680K) : Executing rule CO.6b
# 2025-06-26 11:13:20 +0200: Memory Usage (663680K) : Executing rule CO.7
# 2025-06-26 11:13:20 +0200: Memory Usage (663680K) : Executing rule CO.8
# 2025-06-26 11:13:20 +0200: Memory Usage (663680K) : Executing rule CO.9
# 2025-06-26 11:13:20 +0200: Memory Usage (663680K) : Executing rule CO.10
# 2025-06-26 11:13:20 +0200: Memory Usage (663680K) : Executing rule CO.11
# 2025-06-26 11:13:20 +0200: Memory Usage (663680K) : BEOL section
# 2025-06-26 11:13:20 +0200: Memory Usage (663680K) : Executing rule M1.1
# 2025-06-26 11:13:20 +0200: Memory Usage (663680K) : Executing rule M1.2a
# 2025-06-26 11:13:20 +0200: Memory Usage (663680K) : Executing rule M1.2b
# 2025-06-26 11:13:20 +0200: Memory Usage (663680K) : Executing rule M1.3
# 2025-06-26 11:13:20 +0200: Memory Usage (663680K) : Executing rule M2.1
# 2025-06-26 11:13:20 +0200: Memory Usage (663680K) : Executing rule M2.2a
# 2025-06-26 11:13:20 +0200: Memory Usage (663680K) : Executing rule M2.2b
# 2025-06-26 11:13:20 +0200: Memory Usage (663680K) : Executing rule M2.3
# 2025-06-26 11:13:20 +0200: Memory Usage (663680K) : Executing rule M3.1
# 2025-06-26 11:13:20 +0200: Memory Usage (663680K) : Executing rule M3.2a
# 2025-06-26 11:13:20 +0200: Memory Usage (663680K) : Executing rule M3.2b
# 2025-06-26 11:13:20 +0200: Memory Usage (663744K) : Executing rule M3.3
# 2025-06-26 11:13:20 +0200: Memory Usage (663744K) : Executing rule M4.1
# 2025-06-26 11:13:20 +0200: Memory Usage (663744K) : Executing rule M4.2a
# 2025-06-26 11:13:20 +0200: Memory Usage (663808K) : Executing rule M4.2b
# 2025-06-26 11:13:20 +0200: Memory Usage (663808K) : Executing rule M4.3
# 2025-06-26 11:13:20 +0200: Memory Usage (663872K) : Executing rule M5.1
# 2025-06-26 11:13:20 +0200: Memory Usage (663872K) : Executing rule M5.2a
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule M5.2b
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule M5.3
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V1.1
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V1.2a
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V1.2b
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V1.3a
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V1.3c
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V1.3d
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V1.4a
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V1.4b
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V1.4c
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V2.1
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V2.2a
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V2.2b
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V2.3b
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V2.3c
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V2.3d
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V2.4a
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V2.4b
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V2.4c
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V3.1
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V3.2a
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V3.2b
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V3.3b
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V3.3c
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V3.3d
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V3.4a
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V3.4b
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V3.4c
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V4.1
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V4.2a
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V4.2b
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V4.3b
# 2025-06-26 11:13:20 +0200: Memory Usage (659220K) : Executing rule V4.3c
# 2025-06-26 11:13:20 +0200: Memory Usage (659364K) : Executing rule V4.3d
# 2025-06-26 11:13:20 +0200: Memory Usage (659800K) : Executing rule V4.4a
# 2025-06-26 11:13:20 +0200: Memory Usage (660528K) : Executing rule V4.4b
# 2025-06-26 11:13:20 +0200: Memory Usage (661108K) : Executing rule V4.4c
# 2025-06-26 11:13:20 +0200: Memory Usage (661400K) : Executing rule V5.1
# 2025-06-26 11:13:20 +0200: Memory Usage (661548K) : Executing rule V5.2a
# 2025-06-26 11:13:20 +0200: Memory Usage (662128K) : Executing rule V5.2b
# 2025-06-26 11:13:20 +0200: Memory Usage (662272K) : Executing rule V5.3b
# 2025-06-26 11:13:20 +0200: Memory Usage (663000K) : Executing rule V5.3c
# 2025-06-26 11:13:20 +0200: Memory Usage (663584K) : Executing rule V5.3d
# 2025-06-26 11:13:20 +0200: Memory Usage (664000K) : Executing rule V5.4a
# 2025-06-26 11:13:20 +0200: Memory Usage (665004K) : Executing rule V5.4b
# 2025-06-26 11:13:20 +0200: Memory Usage (665712K) : Executing rule V5.4c
# 2025-06-26 11:13:20 +0200: Memory Usage (665712K) : MetalTop thickness 9k/11k section
# 2025-06-26 11:13:20 +0200: Memory Usage (665712K) : Executing rule MT.1
# 2025-06-26 11:13:20 +0200: Memory Usage (665712K) : Executing rule MT.2a
# 2025-06-26 11:13:20 +0200: Memory Usage (665712K) : Executing rule MT.4
# 2025-06-26 11:13:20 +0200: Memory Usage (665712K) : Executing rule MC.1
# 2025-06-26 11:13:20 +0200: Memory Usage (665712K) : Executing rule MC.2
# 2025-06-26 11:13:20 +0200: Memory Usage (665712K) : Executing rule MC.3
# 2025-06-26 11:13:20 +0200: Memory Usage (665712K) : Executing rule MC.4
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule PRES.1
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule PRES.2
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule PRES.3
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule PRES.4
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule PRES.5
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule PRES.6
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule PRES.7
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule PRES.9a
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule PRES.9b
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule LRES.1
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule LRES.2
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule LRES.3
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule LRES.4
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule LRES.5
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule LRES.6
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule LRES.7
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule LRES.9a
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule LRES.9b
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule HRES.1
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule HRES.2
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule HRES.3
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule HRES.4
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule HRES.5
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule HRES.6
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule HRES.7
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule HRES.8
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule HRES.9
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule HRES.10
# 2025-06-26 11:13:20 +0200: Memory Usage (659584K) : Executing rule HRES.12a
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule HRES.12b
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : No MIM Capacitor Option Selected section
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule NAT.1
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule NAT.2
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule NAT.3
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule NAT.4
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule NAT.5
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : CONNECTIVITY_RULES section
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule NAT.6
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule NAT.7
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule NAT.8
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule NAT.9
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule NAT.10
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule NAT.11
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule NAT.12
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule BJT.1
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule BJT.2
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule BJT.3
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule DE.2
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule DE.3
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule DE.4
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule LVS_BJT.1
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule O.DF.3a
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule O.DF.6
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule O.DF.9
# 2025-06-26 11:13:21 +0200: Memory Usage (659584K) : Executing rule O.PL.2
# 2025-06-26 11:13:21 +0200: Memory Usage (659648K) : Executing rule O.PL.3a
# 2025-06-26 11:13:21 +0200: Memory Usage (659712K) : Executing rule O.PL.4
# 2025-06-26 11:13:21 +0200: Memory Usage (659712K) : Executing rule O.SB.2
# 2025-06-26 11:13:21 +0200: Memory Usage (659776K) : Executing rule O.SB.3
# 2025-06-26 11:13:21 +0200: Memory Usage (659776K) : Executing rule O.SB.4
# 2025-06-26 11:13:21 +0200: Memory Usage (660132K) : Executing rule O.SB.5b_3.3V
# 2025-06-26 11:13:21 +0200: Memory Usage (660612K) : Executing rule O.SB.9
# 2025-06-26 11:13:21 +0200: Memory Usage (660884K) : Executing rule O.SB.11
# 2025-06-26 11:13:21 +0200: Memory Usage (661096K) : Executing rule O.SB.13_3.3V
# 2025-06-26 11:13:21 +0200: Memory Usage (661404K) : Executing rule O.SB.13_5V
# 2025-06-26 11:13:21 +0200: Memory Usage (661748K) : Executing rule O.CO.7
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule O.PL.ORT
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.01
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.02
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.03
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.04a
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.04b
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.04c
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.04d
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.05
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.06
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.07
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.08
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.09
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.10
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.11
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.12
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.13
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.14
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.15
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.16a
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.16b
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.17
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.18
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.19
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.20
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.21
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.22a
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule EF.22b
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.1
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : CONNECTIVITY_RULES section
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.2a
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.2b
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.3a
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.3b
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.4a
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.4b
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.5ai
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.5aii
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.5b
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.5c
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.6
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.6a
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.7
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.7a
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : CONNECTIVITY_RULES section
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.8a
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.8b
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.9
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.10a
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.10b
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.10c
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.10d
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.10ei
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.10eii
# 2025-06-26 11:13:21 +0200: Memory Usage (662036K) : Executing rule MDN.10f
# 2025-06-26 11:13:21 +0200: Memory Usage (662616K) : Executing rule MDN.11
# 2025-06-26 11:13:21 +0200: Memory Usage (663388K) : Executing rule MDN.12
# 2025-06-26 11:13:21 +0200: Memory Usage (663452K) : Executing rule MDN.13a
# 2025-06-26 11:13:21 +0200: Memory Usage (664280K) : Executing rule MDN.13b
# 2025-06-26 11:13:21 +0200: Memory Usage (664920K) : Executing rule MDN.13c
# 2025-06-26 11:13:21 +0200: Memory Usage (665576K) : Executing rule MDN.13d
# 2025-06-26 11:13:21 +0200: Memory Usage (665576K) : Executing rule MDN.14
# 2025-06-26 11:13:21 +0200: Memory Usage (665576K) : Executing rule MDN.15a
# 2025-06-26 11:13:21 +0200: Memory Usage (665576K) : Executing rule MDN.15b
# 2025-06-26 11:13:21 +0200: Memory Usage (665576K) : Executing rule MDN.17
# 2025-06-26 11:13:21 +0200: Memory Usage (665576K) : Executing rule MDP.1
# 2025-06-26 11:13:21 +0200: Memory Usage (665576K) : Executing rule MDP.1a
# 2025-06-26 11:13:21 +0200: Memory Usage (665576K) : Executing rule MDP.2
# 2025-06-26 11:13:21 +0200: Memory Usage (665576K) : Executing rule MDP.3
# 2025-06-26 11:13:21 +0200: Memory Usage (665576K) : Executing rule MDP.3ai
# 2025-06-26 11:13:21 +0200: Memory Usage (665576K) : Executing rule MDP.3aii
# 2025-06-26 11:13:21 +0200: Memory Usage (665576K) : Executing rule MDP.3b
# 2025-06-26 11:13:21 +0200: Memory Usage (665576K) : Executing rule MDP.3c
# 2025-06-26 11:13:21 +0200: Memory Usage (665576K) : Executing rule MDP.3d
# 2025-06-26 11:13:21 +0200: Memory Usage (665576K) : Executing rule MDP.4
# 2025-06-26 11:13:21 +0200: Memory Usage (665576K) : Executing rule MDP.4a
# 2025-06-26 11:13:21 +0200: Memory Usage (665576K) : Executing rule MDP.4b
# 2025-06-26 11:13:21 +0200: Memory Usage (665576K) : Executing rule MDP.5
# 2025-06-26 11:13:21 +0200: Memory Usage (665576K) : Executing rule MDP.5a
# 2025-06-26 11:13:21 +0200: Memory Usage (665576K) : Executing rule MDP.6
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.6a
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.7
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.8
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.9a
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.9b
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.9c
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.9d
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.9ei
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.9eii
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.9f
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.10
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : CONNECTIVITY_RULES section
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.10a
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.10b
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.11
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.12
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.13a
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.13b
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.13c
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.15
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.16a
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.16b
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.17a
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule MDP.17c
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule Y.NW.2b_3.3V
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule Y.NW.2b_5V
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule Y.DF.6_5V
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule Y.DF.16_3.3V
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule Y.DF.16_5V
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule Y.PL.1_3.3V
# 2025-06-26 11:13:22 +0200: Memory Usage (665576K) : Executing rule Y.PL.1_5V
# 2025-06-26 11:13:22 +0200: Memory Usage (665724K) : Executing rule Y.PL.2_3.3V
# 2025-06-26 11:13:22 +0200: Memory Usage (666160K) : Executing rule Y.PL.2_5V
# 2025-06-26 11:13:22 +0200: Memory Usage (666660K) : Executing rule Y.PL.4_5V
# 2025-06-26 11:13:22 +0200: Memory Usage (667008K) : Executing rule Y.PL.5a_3.3V
# 2025-06-26 11:13:22 +0200: Memory Usage (667284K) : Executing rule Y.PL.5a_5V
# 2025-06-26 11:13:22 +0200: Memory Usage (667672K) : Executing rule Y.PL.5b_3.3V
# 2025-06-26 11:13:22 +0200: Memory Usage (668188K) : Executing rule Y.PL.5b_5V
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule S.DF.4c_MV
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule S.DF.6_MV
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule S.DF.7_MV
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule S.DF.8_MV
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule S.DF.16_MV
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule S.PL.5a_MV
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule S.PL.5b_MV
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule S.CO.4_MV
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule S.DF.4c_LV
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule S.DF.16_LV
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule S.CO.3_LV
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule S.CO.4_LV
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule S.CO.6_ii_LV
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule S.M1.1_LV
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : OFFGRID-ANGLES section
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule comp_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule dnwell_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule nwell_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule lvpwell_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule dualgate_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule poly2_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule nplus_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule pplus_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule sab_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule esd_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule contact_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule metal1_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule via1_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule metal2_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule via2_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule metal3_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule via3_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule metal4_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule via4_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule metal5_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule via5_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule metaltop_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule pad_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668332K) : Executing rule resistor_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668396K) : Executing rule fhres_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668460K) : Executing rule fusetop_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668588K) : Executing rule fusewindow_d_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668652K) : Executing rule polyfuse_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668716K) : Executing rule mvsd_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668844K) : Executing rule mvpsd_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (668908K) : Executing rule nat_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (669036K) : Executing rule comp_dummy_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (669100K) : Executing rule poly2_dummy_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (669164K) : Executing rule metal1_dummy_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (669292K) : Executing rule metal2_dummy_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (669356K) : Executing rule metal3_dummy_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (669484K) : Executing rule metal4_dummy_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (669548K) : Executing rule metal5_dummy_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (669612K) : Executing rule metaltop_dummy_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (669740K) : Executing rule comp_label_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (669804K) : Executing rule poly2_label_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (669932K) : Executing rule metal1_label_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (669996K) : Executing rule metal2_label_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670124K) : Executing rule metal3_label_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670188K) : Executing rule metal4_label_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670316K) : Executing rule metal5_label_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670380K) : Executing rule metaltop_label_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670444K) : Executing rule metal1_slot_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670572K) : Executing rule metal2_slot_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670636K) : Executing rule metal3_slot_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670636K) : Executing rule metal4_slot_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670636K) : Executing rule metal5_slot_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670636K) : Executing rule metaltop_slot_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670636K) : Executing rule ubmpperi_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670636K) : Executing rule ubmparray_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670636K) : Executing rule ubmeplate_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670636K) : Executing rule schottky_diode_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670636K) : Executing rule zener_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670636K) : Executing rule res_mk_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670636K) : Executing rule opc_drc_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670636K) : Executing rule ndmy_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670636K) : Executing rule pmndmy_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670636K) : Executing rule v5_xtor_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670636K) : Executing rule cap_mk_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670636K) : Executing rule mos_cap_mk_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670636K) : Executing rule ind_mk_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670636K) : Executing rule diode_mk_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670636K) : Executing rule drc_bjt_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670636K) : Executing rule lvs_bjt_OFFGRID
# 2025-06-26 11:13:22 +0200: Memory Usage (670636K) : Executing rule mim_l_mk_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule latchup_mk_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule guard_ring_mk_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule otp_mk_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule mtpmark_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule neo_ee_mk_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule sramcore_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule lvs_rf_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule lvs_drain_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule ind_mk_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule hvpolyrs_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule lvs_io_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule probe_mk_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule esd_mk_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule lvs_source_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule well_diode_mk_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule ldmos_xtor_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule plfuse_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule efuse_mk_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule mcell_feol_mk_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule ymtp_mk_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule dev_wf_mk_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule metal1_blk_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule metal2_blk_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule metal3_blk_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule metal4_blk_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule metal5_blk_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule metalt_blk_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule pr_bndry_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule mdiode_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule metal1_res_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule metal2_res_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670636K) : Executing rule metal3_res_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670764K) : Executing rule metal4_res_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670764K) : Executing rule metal5_res_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670764K) : Executing rule metal6_res_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670764K) : Executing rule border_OFFGRID
# 2025-06-26 11:13:23 +0200: Memory Usage (670764K) : DRC Total Run time 5.069120 seconds
