# %% [markdown]
# # Tutorial 2: **Notebook** - *FVF*
#
# > 🚧 **Under Construction**
#
# **By
# gLayout Team**
#
# __Content creators:__ Subham Pal, Saptarshi Ghosh
#
# __Content reviewers:__ Mehedi Saligne

# %% [markdown]
# ___
# # Tutorial Objectives
#
# This notebook is a tutorial on-
#
# - **LVS (Layout Versus Schematic):**
#   You will learn how to compare your physical layout with the original schematic to ensure they are functionally identical. This process helps catch connectivity or device mismatches before fabrication.
#
# - **Extraction and Simulation:**
#   The tutorial will guide you through extracting parasitic elements from your layout, such as capacitance and resistance, to create a more accurate circuit model. You will then simulate the extracted netlist to analyze and verify the real-world performance of your design.

# %% [markdown]
# ## **Target** **Block** : **Inverter Cell**
#
# The CMOS inverter is a fundamental digital circuit building block, widely used due to its low static power consumption, high noise immunity, and fast switching characteristics. It consists of a complementary pair of MOSFETs: one PMOS and one NMOS transistor, with their gates and drains connected together. The source of the PMOS is connected to the supply voltage (VDD), while the source of the NMOS is connected to ground (VSS).
#
# ### **Operation Principle**
# - **Input Low (Logic 0):** The PMOS transistor turns ON and the NMOS turns OFF. This connects the output (VOUT) to VDD, producing a logic high (1) at the output.
# - **Input High (Logic 1):** The NMOS transistor turns ON and the PMOS turns OFF. This connects the output to ground, producing a logic low (0) at the output.
#
# This complementary switching action ensures that the output is always the logical inverse of the input, making the CMOS inverter a true logic inverter.
#
# ![](_images/CMOS_Inverter.png)
#
# ```bibtex
# Wikimedia Commons contributors. (2010). CMOS Inverter Schematic [Diagram]. Wikimedia Commons. https://commons.wikimedia.org/wiki/File:CMOS_Inverter.svg
# ```

# %% [markdown]
# ## **NetList generation and LVS**
# let's go through the step by step procedure to generate LVS and DRC clean layout of a FVF cell.

# %%
import os
import subprocess

# Run a shell, source .bashrc, then printenv
cmd = 'bash -c "source ~/.bashrc && printenv"'
result = subprocess.run(cmd, shell=True, text=True, capture_output=True)
env_vars = {}
for line in result.stdout.splitlines():
    if '=' in line:
        key, value = line.split('=', 1)
        env_vars[key] = value

# Now, update os.environ with these
os.environ.update(env_vars)

# %%
from glayout import MappedPDK, sky130 , gf180
#from gdsfactory.cell import cell
from gdsfactory import Component
from gdsfactory.components import text_freetype, rectangle

# %%
from glayout import nmos, pmos
from glayout import via_stack
from glayout import rename_ports_by_orientation
from glayout import tapring

# %%
from glayout.util.comp_utils import evaluate_bbox, prec_center, prec_ref_center, align_comp_to_port
from glayout.util.port_utils import add_ports_perimeter,print_ports
from glayout.util.snap_to_grid import component_snap_to_grid
from glayout.spice.netlist import Netlist

# %%
from glayout.routing.straight_route import straight_route
from glayout.routing.c_route import c_route
from glayout.routing.L_route import L_route

# %% [markdown]
# FVF has two fets as shown in the schematic. We call M1 as input fet and M2 as feedback fet. Lets define arguments for the FETs

# %% [markdown]
# ### 2. Basic Usage of the GLayout Framework
# Each generator is a Python function that takes a `MappedPDK` object as a parameter and generates a DRC clean layout for the given PDK. The generator may also accept a set of optional layout parameters such as the width or length of a MOSFET. All parameters are normal Python function arguments.
#
# The generator returns a `GDSFactory.Component` object that can be written to a `.gds` file and viewed using a tool such as Klayout. In this example, the `gdstk` library is used to convert the `.gds` file to an SVG image for viewing.
#
# The pre-PEX SPICE netlist for the component can be viewed using `component.info['netlist'].generate_netlist()`.
#
# In the following example the FET generator `glayout.primitives.fet` is imported and run with both the [Skywater 130](https://skywater-pdk.readthedocs.io/en/main/) and [GF180](https://gf180mcu-pdk.readthedocs.io/en/latest/) PDKs.

# %% [markdown]
# #### Demonstration of Basic Layout / Netlist Generation in SKY130 & GF180

# %%
# from glayout import nmos,sky130,gf180

# import gdstk
# import svgutils.transform as sg
# import IPython.display
# from IPython.display import clear_output
# import ipywidgets as widgets

# # Used to display the results in a grid (notebook only)
# left = widgets.Output()
# leftSPICE = widgets.Output()
# right = widgets.Output()
# rightSPICE = widgets.Output()
# hide = widgets.Output()

# grid = widgets.GridspecLayout(1, 4)
# grid[0, 0] = left
# grid[0, 1] = leftSPICE
# grid[0, 2] = right
# grid[0, 3] = rightSPICE
# display(grid)

# def display_gds(gds_file, scale = 3):
#   # Generate an SVG image
#   top_level_cell = gdstk.read_gds(gds_file).top_level()[0]
#   top_level_cell.write_svg('../../out.svg')

#   # Scale the image for displaying
#   fig = sg.fromfile('../../out.svg')
#   fig.set_size((str(float(fig.width) * scale), str(float(fig.height) * scale)))
#   fig.save('../../out.svg')

#   # Display the image
#   IPython.display.display(IPython.display.SVG('../../out.svg'))

# def display_component(component, scale = 3):
#   # Save to a GDS file
#   with hide:
#     component.write_gds("../../out.gds")

#   display_gds('../../out.gds', scale)

# with hide:
#   # Generate the sky130 component
#   component_sky130 = nmos(pdk = sky130, fingers=5)
#   # Generate the gf180 component
#   component_gf180 = nmos(pdk = gf180, fingers=5)

# # Display the components' GDS and SPICE netlists
# with left:
#   print('Skywater 130nm N-MOSFET (fingers = 5)')
#   display_component(component_sky130, scale=2)
# with leftSPICE:
#   print('Skywater 130nm SPICE Netlist')
#   print(component_sky130.info['netlist'].generate_netlist())

# with right:
#   print('GF 180nm N-MOSFET (fingers = 5)')
#   display_component(component_gf180, scale=2)
# with rightSPICE:
#   print('GF 180nm SPICE Netlist')
#   print(component_gf180.info['netlist'].generate_netlist())

# %%
import sys
import os
sys.path.append(os.path.abspath("../../INV"))

from my_INV import inverter,add_inv_labels

# %%
comp = inverter(gf180)
# fet_P_ref_extracted = next(ref for ref in comp.references if ref.name == "fet_PMOS")
# fet_N_ref_extracted = next(ref for ref in comp.references if ref.name == "fet_NMOS")
comp
# Out:
# 2025-06-26 10:49:47.661 | WARNING  | gdsfactory.pdk:get_active_pdk:733 - No active PDK. Activating generic PDK.
#
# 2025-06-26 10:49:47.889 | INFO     | gdsfactory.technology.layer_views:__init__:790 - Importing LayerViews from YAML file: '/headless/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/generic_tech/layer_views.yaml'.
# 2025-06-26 10:49:47.891 | INFO     | gdsfactory.pdk:activate:337 - 'generic' PDK is now active
# 2025-06-26 10:49:47.900 | INFO     | gdsfactory.pdk:activate:337 - 'gf180' PDK is now active
# 2025-06-26 10:49:51.657 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.3.3", "klayout_version": "0.30.2", "type": "reload", "file": "/tmp/gdsfactory/inverter_d4f7f27b.gds"}
# You need to install kweb with `pip install gdsfactory[cad]`
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/component.py:1556, in Component.plot_kweb(self)
#    1555 try:
# -> 1556     import kweb.server_jupyter as kj
#    1557 except Exception:
#
# ModuleNotFoundError: No module named 'kweb'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/IPython/core/formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File ~/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/component.py:1455, in Component._repr_html_(self)
#    1453 """Show geometry in KLayout and in matplotlib for Jupyter Notebooks."""
#    1454 self.show(show_ports=True)  # show in klayout
# -> 1455 fig = self.plot()
#    1456 if fig and hasattr(fig, "_repr_html_"):
#    1457     return fig._repr_html_()
#
# File ~/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/component.py:1643, in Component.plot(self, plotter, **kwargs)
#    1641     return
#    1642 elif plotter == "kweb":
# -> 1643     return self.plot_kweb()
#    1645 elif plotter == "matplotlib":
#    1646     from gdsfactory.quickplotter import quickplot
#
# File ~/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/component.py:1559, in Component.plot_kweb(self)
#    1557 except Exception:
#    1558     print("You need to install kweb with `pip install gdsfactory[cad]`")
# -> 1559     return self.plot_klayout()
#    1561 from html import escape
#    1563 from IPython.display import IFrame
#
# File ~/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/component.py:1513, in Component.plot_klayout(self, show_ports, port_marker_layer, show_labels)
#    1510 gdspath = component.write_gds(logging=False)
#    1511 lyp_path = gdspath.with_suffix(".lyp")
# -> 1513 layer_views = get_layer_views()
#    1514 layer_views.to_lyp(filepath=lyp_path)
#    1516 layout_view = lay.LayoutView()
#
# File ~/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/pdk.py:763, in get_layer_views()
#     762 def get_layer_views() -> LayerViews:
# --> 763     return get_active_pdk().get_layer_views()
#
# File ~/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/pdk.py:605, in Pdk.get_layer_views(self)
#     603 def get_layer_views(self) -> LayerViews:
#     604     if self.layer_views is None:
# --> 605         raise ValueError(f"layer_views for Pdk {self.name!r} is None")
#     606     return self.layer_views
#
# ValueError: layer_views for Pdk 'gf180' is None
# inverter_d4f7f27b: uid c27ff298, ports ['P_tie_S_array_row0_col0_bottom_layer_W', 'P_tie_S_array_row0_col0_bottom_via_W', 'P_tie_S_array_row0_col0_bottom_met_W', 'P_tie_S_array_row0_col0_top_met_W', 'P_tie_S_array_row0_col1_bottom_layer_W', 'P_tie_S_array_row0_col1_bottom_via_W', 'P_tie_S_array_row0_col1_bottom_met_W', 'P_tie_S_array_row0_col1_top_met_W', 'P_tie_S_array_row0_col2_bottom_layer_W', 'P_tie_S_array_row0_col2_bottom_via_W', 'P_tie_S_array_row0_col2_bottom_met_W', 'P_tie_S_array_row0_col2_top_met_W', 'P_tie_S_array_row0_col3_bottom_layer_W', 'P_tie_S_array_row0_col3_bottom_via_W', 'P_tie_S_array_row0_col3_bottom_met_W', 'P_tie_S_array_row0_col3_top_met_W', 'P_tie_S_array_row0_col4_bottom_layer_W', 'P_tie_S_array_row0_col4_bottom_via_W', 'P_tie_S_array_row0_col4_bottom_met_W', 'P_tie_S_array_row0_col4_top_met_W', 'P_tie_S_array_row0_col5_bottom_layer_W', 'P_tie_S_array_row0_col5_bottom_via_W', 'P_tie_S_array_row0_col5_bottom_met_W', 'P_tie_S_array_row0_col5_top_met_W', 'P_tie_S_array_row0_col6_bottom_layer_W', 'P_tie_S_array_row0_col6_bottom_via_W', 'P_tie_S_array_row0_col6_bottom_met_W', 'P_tie_S_array_row0_col6_top_met_W', 'P_tie_S_array_row0_col7_bottom_layer_W', 'P_tie_S_array_row0_col7_bottom_via_W', 'P_tie_S_array_row0_col7_bottom_met_W', 'P_tie_S_array_row0_col7_top_met_W', 'P_tie_S_array_row0_col8_bottom_layer_W', 'P_tie_S_array_row0_col8_bottom_via_W', 'P_tie_S_array_row0_col8_bottom_met_W', 'P_tie_S_array_row0_col8_top_met_W', 'P_tie_S_bottom_lay_W', 'P_tie_S_top_met_W', 'P_tie_bl_bottom_layer_W', 'P_tie_bl_bottom_via_W', 'P_tie_bl_bottom_met_W', 'P_tie_bl_top_met_W', 'P_tie_br_bottom_layer_W', 'P_tie_br_bottom_via_W', 'P_tie_br_bottom_met_W', 'P_tie_br_top_met_W', 'P_tie_E_array_row0_col0_bottom_layer_W', 'P_tie_E_array_row0_col0_bottom_via_W', 'P_tie_E_array_row0_col0_bottom_met_W', 'P_tie_E_array_row0_col0_top_met_W', 'P_tie_W_array_row0_col0_bottom_layer_W', 'P_tie_W_array_row0_col0_bottom_via_W', 'P_tie_W_array_row0_col0_bottom_met_W', 'P_tie_W_array_row0_col0_top_met_W', 'P_multiplier_0_gate_W', 'P_gate_W', 'P_tie_E_array_row1_col0_bottom_layer_W', 'P_tie_E_array_row1_col0_bottom_via_W', 'P_tie_E_array_row1_col0_bottom_met_W', 'P_tie_E_array_row1_col0_top_met_W', 'P_tie_W_array_row1_col0_bottom_layer_W', 'P_tie_W_array_row1_col0_bottom_via_W', 'P_tie_W_array_row1_col0_bottom_met_W', 'P_tie_W_array_row1_col0_top_met_W', 'P_multiplier_0_dummy_L_gsdcon_bottom_layer_W', 'P_multiplier_0_dummy_L_gsdcon_bottom_via_W', 'P_multiplier_0_dummy_L_gsdcon_bottom_met_W', 'P_multiplier_0_dummy_L_gsdcon_top_met_W', 'P_multiplier_0_dummy_R_gsdcon_bottom_layer_W', 'P_multiplier_0_dummy_R_gsdcon_bottom_via_W', 'P_multiplier_0_dummy_R_gsdcon_bottom_met_W', 'P_multiplier_0_dummy_R_gsdcon_top_met_W', 'P_tie_E_array_row2_col0_bottom_layer_W', 'P_tie_E_array_row2_col0_bottom_via_W', 'P_tie_E_array_row2_col0_bottom_met_W', 'P_tie_E_array_row2_col0_top_met_W', 'P_tie_W_array_row2_col0_bottom_layer_W', 'P_tie_W_array_row2_col0_bottom_via_W', 'P_tie_W_array_row2_col0_bottom_met_W', 'P_tie_W_array_row2_col0_top_met_W', 'P_multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_layer_W', 'P_multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_via_W', 'P_multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_met_W', 'P_multiplier_0_row0_col0_rightsd_array_row0_col0_top_met_W', 'P_multiplier_0_leftsd_array_row0_col0_bottom_layer_W', 'P_multiplier_0_leftsd_array_row0_col0_bottom_via_W', 'P_multiplier_0_leftsd_array_row0_col0_bottom_met_W', 'P_multiplier_0_leftsd_array_row0_col0_top_met_W', 'P_multiplier_0_dummy_L_row0_col0_rightsd_array_row0_col0_bottom_layer_W', 'P_multiplier_0_dummy_L_row0_col0_rightsd_array_row0_col0_bottom_via_W', 'P_multiplier_0_dummy_L_row0_col0_rightsd_array_row0_col0_bottom_met_W', 'P_multiplier_0_dummy_L_row0_col0_rightsd_array_row0_col0_top_met_W', 'P_multiplier_0_dummy_L_leftsd_array_row0_col0_bottom_layer_W', 'P_multiplier_0_dummy_L_leftsd_array_row0_col0_bottom_via_W', 'P_multiplier_0_dummy_L_leftsd_array_r ...

# %%
comp = add_inv_labels(comp, gf180)
comp.name = "INV"
#comp.write_gds('out_INV.gds')
comp.show()
#print("...Running DRC...")
drc_result = gf180.drc_magic(comp, "INV")
# Out:
# 2025-06-26 10:47:52.614 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.3.3", "klayout_version": "0.30.2", "type": "reload", "file": "/tmp/gdsfactory/INV.gds"}
# 2025-06-26 10:47:52.617 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmpksj3xkk2/INV.gds'
# using default pdk_root: /usr/bin/miniconda3/share/pdk/
# Defaulting to stale magic_commands.tcl
#
# Magic 8.3 revision 528 - Compiled on Wed Jun 18 09:45:25 PM CEST 2025.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Loading "/tmp/tmpksj3xkk2/magic_commands.tcl" from command line.
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "INV".
# [INFO]: Loading INV
#
# Loading DRC CIF style.
# [INFO]: DONE with /tmp/tmpksj3xkk2/INV.rpt
#
# Using technology "gf180mcuD", version 1.0.525-0-gf2e289d
#
# INV count:
#
# ----------------------------------------
#
# Metal2 spacing < 0.28um (M2.2a)
#
# ----------------------------------------
#
#  -0.820um 1.495um -0.320um 1.525um
#
#  -0.320um 1.495um -0.040um 1.525um
#
#  0.040um 1.495um 0.820um 1.525um
#
#  10.120um 1.495um 10.620um 1.525um
#
#  10.980um 1.495um 11.760um 1.525um
#
#  0.820um 1.495um 1.100um 1.525um
#
#  10.620um 1.495um 10.900um 1.525um
#
# ----------------------------------------

# %%
def inv_netlist(fet_1: Component, fet_2: Component) -> Netlist:

    netlist = Netlist(circuit_name='INVERTER', nodes=['VIN', 'VBULK', 'VOUT', 'VDD'])
    
    netlist.connect_netlist(fet_1.info['netlist'], [('D', 'VOUT'), ('G', 'VIN'), ('S', 'VDD'), ('B', 'VBULK')])
    netlist.connect_netlist(fet_2.info['netlist'], [('D', 'VOUT'), ('G', 'VIN'), ('S', 'VBULK'), ('B', 'VBULK')])
    
    return netlist



comp.info['netlist'] = fvf_netlist(fet_1, fet_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 12
#       6     netlist.connect_netlist(fet_2.info['netlist'], [('D', 'VOUT'), ('G', 'VIN'), ('S', 'VBULK'), ('B', 'VBULK')])
#       8     return netlist
# ---> 12 comp.info['netlist'] = fvf_netlist(fet_1, fet_2)
#
# NameError: name 'fvf_netlist' is not defined

# %%
comp

# %% [markdown]
# ### Run LVS
# Design Rule Check ensures that the physical layout of an integrated circuit adheres to the manufacturing constraints defined by the foundry, such as minimum spacing, width, and enclosure rules. `Magic` is the tool we use for DRC here.

# %% [markdown]
# ## Extraction and Post-Pex Simulation
