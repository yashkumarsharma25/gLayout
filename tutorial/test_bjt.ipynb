# %%
from glayout import MappedPDK, sky130 , gf180
#from gdsfactory.cell import cell
from gdsfactory import Component
from gdsfactory.geometry import boolean
from gdsfactory.components import text_freetype, rectangle, array, rectangular_ring

# %%
top_level=Component(name="BJT")
pdk=gf180
pdk.activate()
# Out:
# 2025-08-24 22:30:33.990 | INFO     | gdsfactory.pdk:activate:337 - 'gf180' PDK is now active

# %%
pdk.__dict__
# Out:
# {'name': 'gf180',
#  'cross_sections': {},
#  'cells': {},
#  'symbols': {},
#  'default_symbol_factory': functools.partial(<function floorplan_with_block_letters at 0x7bce86818b80>, prefix='SYMBOL_floorplan_with_block_letters'),
#  'base_pdk': None,
#  'default_decorator': None,
#  'layers': {'metal5': (81, 0),
#   'via4': (41, 0),
#   'metal4': (46, 0),
#   'via3': (40, 0),
#   'metal3': (42, 0),
#   'via2': (38, 0),
#   'metal2': (36, 0),
#   'via1': (35, 0),
#   'metal1': (34, 0),
#   'contact': (33, 0),
#   'poly2': (30, 0),
#   'comp': (22, 0),
#   'nplus': (32, 0),
#   'pplus': (31, 0),
#   'nwell': (21, 0),
#   'lvpwell': (204, 0),
#   'dnwell': (12, 0),
#   'CAP_MK': (117, 5),
#   'metal5_label': (81, 10),
#   'metal4_label': (46, 10),
#   'metal3_label': (42, 10),
#   'metal2_label': (36, 10),
#   'metal1_label': (34, 10),
#   'poly2_label': (30, 10),
#   'comp_label': (22, 10)},
#  'layer_stack': None,
#  'layer_views': None,
#  'layer_transitions': {},
#  'sparameters_path': None,
#  'modes_path': None,
#  'interconnect_cml_path': None,
#  'warn_off_grid_ports': False,
#  'constants': {'fiber_array_spacing': 127.0,
#   'fiber_spacing': 50.0,
#   'fiber_input_to_output_spacing': 200.0,
#   'metal_spacing': 10.0,
#   'pad_spacing': 100.0,
#   'pad_size': (80, 80)},
#  'materials_index': {},
#  'routing_strategies': None,
#  'gds_write_settings': GdsWriteSettings(on_uncached_component='ignore', lib_name='library', unit=1e-06, precision=5e-09, on_duplicate_cell='warn', flatten_invalid_refs=False, max_points=4000),
#  'oasis_settings': OasisWriteSettings(compression_level=6, detect_rectangles=True, detect_trapezoids=True, circle_tolerance=0, validation=None, standard_properties=False),
#  'cell_decorator_settings': CellDecoratorSettings(with_hash=False, autoname=True, name=None, cache=False, flatten=False, info={}, prefix=None, max_name_length=99, include_module=False, naming_style='default', assert_ports_on_grid=True),
#  'bend_points_distance': 0.02,
#  'models': {'nfet': 'nfet_03v3',
#   'pfet': 'pfet_03v3',
#   'mimcap': 'mimcap_1p0fF'},
#  'glayers': {'met5': 'metal5',
#   'via4': 'via4',
#   'met4': 'metal4',
#   'via3': 'via3',
#   'met3': 'metal3',
#   'via2': 'via2',
#   'met2': 'metal2',
#   'via1': 'via1',
#   'met1': 'metal1',
#   'mcon': 'contact',
#   'poly': 'poly2',
#   'active_diff': 'comp',
#   'active_tap': 'comp',
#   'n+s/d': 'nplus',
#   'p+s/d': 'pplus',
#   'nwell': 'nwell',
#   'pwell': 'lvpwell',
#   'dnwell': 'dnwell',
#   'capmet': 'CAP_MK',
#   'met5_pin': 'metal5_label',
#   'met4_pin': 'metal4_label',
#   'met3_pin': 'metal3_label',
#   'met2_pin': 'metal2_label',
#   'met1_pin': 'metal1_label',
#   'poly_pin': 'poly2_label',
#   'active_diff_pin': 'comp_label',
#   'met5_label': 'metal5_label',
#   'met4_label': 'metal4_label',
#   'met3_label': 'metal3_label',
#   'met2_label': 'metal2_label',
#   'met1_label': 'metal1_label',
#   'poly_label': 'poly2_label',
#   'active_diff_label': 'comp_label'},
#  'grules': {'dnwell': {'dnwell': {'min_width': 1.7, 'min_separation': 5.42},
#    'pwell': {'min_enclosure': 2.5},
#    'nwell': {'min_separation': 3.1, 'min_enclosure': 0.5},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {'min_enclosure': 0.93},
#    'active_tap': {'min_enclosure': 0.62, 'min_separation': 2.5},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'pwell': {'dnwell': {},
#    'pwell': {'min_width': 0.6, 'min_separation': 1.4},
#    'nwell': {'min_separation': 0.0},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {'min_enclosure': 0.43},
#    'active_tap': {'min_enclosure': 0.12},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'nwell': {'dnwell': {},
#    'pwell': {},
#    'nwell': {'min_width': 0.86, 'min_separation': 1.4},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {'min_enclosure': 0.43},
#    'active_tap': {'min_enclosure': 0.12},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'p+s/d': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {'min_width': 0.4, 'min_separation': 0.4},
#    'n+s/d': {},
#    'active_diff': {'min_enclosure': 0.23},
#    'active_tap': {'min_enclosure': 0.16},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'n+s/d': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {'min_width': 0.4, 'min_separation': 0.4},
#    'active_diff': {'min_enclosure': 0.23},
#    'active_tap': {'min_enclosure': 0.16},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'active_diff': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {'min_width': 0.22, 'min_separation': 0.28},
#    'active_tap': {'min_separation': 0.28, 'max_separation': 20.0},
#    'poly': {'overhang': 0.24, 'min_separation': 0.1},
#    'mcon': {'min_enclosure': 0.07},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'active_tap': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {'min_width': 0.22, 'min_separation': 0.28},
#    'poly': {'min_separation': 0.1},
#    'mcon': {'min_enclosure': 0.07},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'poly': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {'min_width': 0.28},
#    'mcon': {'min_enclosure': 0.07, 'min_separation': 0.17},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'mcon': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {},
#    'mcon': {'min_separation': 0.28, 'width': 0.22},
#    'met1': {'min_enclosure': 0.12},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met1': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {},
#    'mcon': {},
#    'met1': {'min_width': 0.23, 'min_separation': 0.3},
#    'via1': {'min_enclosure': 0.12},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'via1': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {'width': 0.26, 'min_separation': 0.36},
#    'met2': {'min_enclosure': 0.12},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met2': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {'min_width': 0.28, 'min_separation': 0.3},
#    'via2': {'min_enclosure': 0.12},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {'min_enclosure': 0.6},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'via2': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {'width': 0.26, 'min_separation': 0.36},
#    'met3': {'min_enclosure': 0.12},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met3': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {'min_width': 0.28, 'min_separation': 0.3},
#    'via3': {'min_enclosure': 0.12},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'via3': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {'width': 0.26, 'min_separation': 0.36},
#    'met4': {'min_enclosure': 0.12},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met4': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {'min_width': 0.28, 'min_separation': 0.3},
#    'via4': {'min_enclosure': 0.12},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'via4': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {'width': 0.26, 'min_separation': 0.36},
#    'met5': {'min_enclosure': 0.12},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met5': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {'min_width': 0.28, 'min_separation': 0.3},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'capmet': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {'capmettop': (42, 0),
#     'capmetbottom': (36, 0),
#     'min_separation': 1.2},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met5_pin': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met4_pin': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met3_pin': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met2_pin': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met1_pin': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'poly_pin': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'active_diff_pin': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met5_label': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met4_label': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met3_label': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met2_label': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met1_label': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'poly_label': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'active_diff_label': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None}},
#  'pdk_files': {'pdk_root': PosixPath('/foss/pdks'),
#   'klayout_drc_file': PosixPath('/headless/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/glayout/pdk/gf180_mapped/gf180mcu_drc.lydrc'),
#   'lvs_schematic_ref_file': PosixPath('/headless/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/glayout/pdk/gf180_mapped/gf180mcu_osu_sc_9T.spice'),
#   'lvs_setup_tcl_file': PosixPath('/foss/pdks/gf180mcuD/libs.tech/netgen/gf180mcuD_setup.tcl'),
#   'magic_drc_file': PosixPath('/foss/pdks/gf180mcuD/libs.tech/magic/gf180mcuD.magicrc'),
#   'temp_dir': None,
#   'pdk': 'gf180'}}

# %%
cdims=(8.28, 8.28)
bdims=(6.8,6.8)
edims=(5.32,5.32)
bjt_layers=("p+s/d","n+s/d","p+s/d")
bjt_dims=(edims,bdims,cdims)

# %%
e_diff= rectangle(size=bjt_dims[0],layer=pdk.get_glayer(bjt_layers[0]),centered=True)
bt_diff= rectangle(size=bjt_dims[1],layer=pdk.get_glayer(bjt_layers[1]),centered=True)
ct_diff= rectangle(size=bjt_dims[2],layer=pdk.get_glayer(bjt_layers[2]),centered=True)
b_diff= boolean(A=bt_diff, B=e_diff, operation="not", 
                layer=pdk.get_glayer(bjt_layers[1]))
c_diff= boolean(A=ct_diff, B=bt_diff, operation="not",
                layer=pdk.get_glayer(bjt_layers[2]))
top_level.add_ref(e_diff)
top_level.add_ref(b_diff)
top_level.add_ref(c_diff)
# Out:
# ComponentReference (parent Component "boolean_a37f36cf", ports [], origin (0.0, 0.0), rotation 0.0, x_reflection False)

# %%
## Adding nwell
nw = rectangle(size=bjt_dims[1],layer=pdk.get_glayer("nwell"),centered=True)
top_level.add_ref(nw)
# Out:
# ComponentReference (parent Component "rectangle_854c7477", ports ['e1', 'e2', 'e3', 'e4'], origin (0.0, 0.0), rotation 0.0, x_reflection False)

# %%
comp_min_sep=0.16
contact_dims=(0.22, 0.22)
contact_inner_sep=0.25
contact_comp_sep=0.1

# %%
import numpy as np

# %%
## Adding comp
comp_layer_name="active_diff"
comp_e= rectangle(size=tuple(np.asarray(bjt_dims[0])-2*comp_min_sep),
                  layer=pdk.get_glayer(comp_layer_name),centered=True)
comp_out_b= rectangle(size=tuple(np.asarray(bjt_dims[1])-2*comp_min_sep),
                      layer=pdk.get_glayer(comp_layer_name),centered=True)
comp_inn_b= rectangle(size=tuple(np.asarray(bjt_dims[0])+2*comp_min_sep),
                      layer=pdk.get_glayer(comp_layer_name),centered=True)
comp_out_c= rectangle(size=tuple(np.asarray(bjt_dims[2])-2*comp_min_sep),
                      layer=pdk.get_glayer(comp_layer_name),centered=True)
comp_inn_c= rectangle(size=tuple(np.asarray(bjt_dims[1])+2*comp_min_sep),
                      layer=pdk.get_glayer(comp_layer_name),centered=True)

comp_b= boolean(A=comp_out_b, B=comp_inn_b, operation="not", 
                layer=pdk.get_glayer(comp_layer_name))
comp_c= boolean(A=comp_out_c, B=comp_inn_c, operation="not",
                layer=pdk.get_glayer(comp_layer_name))
top_level.add_ref(comp_e)
top_level.add_ref(comp_b)
top_level.add_ref(comp_c)
# Out:
# ComponentReference (parent Component "boolean_52fbfc61", ports [], origin (0.0, 0.0), rotation 0.0, x_reflection False)

# %%
#top_level.show()

# %%
# Adding contacts
comp_min_sep=0.16
contact_dims=(0.22, 0.22)
contact_inner_sep=0.25
contact_array_sep=0.28
contact_comp_sep=0.1

contact_layer_name="mcon"
contact= rectangle(size=contact_dims,
                  layer=pdk.get_glayer(contact_layer_name),centered=True)

n_contacts_e=np.floor((np.asarray(edims)-
              2*comp_min_sep-
              2*contact_comp_sep-
              np.asarray(contact_dims)
             )/(np.asarray(contact_dims)+contact_array_sep)+
                      np.asarray((1,1)))

# %%
n_contacts_b=np.floor((np.asarray(bdims)-
              2*comp_min_sep-
              2*contact_comp_sep-
              np.asarray(contact_dims)-
              np.asarray((1,0))*(np.asarray(bdims)-np.asarray(edims)-2*comp_min_sep)
             )/(np.asarray(contact_dims)+contact_inner_sep)+
                      np.asarray((1,1)))

n_contacts_c=np.floor((np.asarray(cdims)-
              2*comp_min_sep-
              2*contact_comp_sep-
              np.asarray(contact_dims)-
              np.asarray((1,0))*(np.asarray(cdims)-np.asarray(bdims)-2*comp_min_sep)
             )/(np.asarray(contact_dims)+contact_inner_sep)+
                      np.asarray((1,1)))

# %%
from decimal import Decimal, ROUND_HALF_UP
def round(x):
    return float(Decimal(x).quantize(Decimal("0.001"), 
                                 rounding=ROUND_HALF_UP)) 

def get_half_contact_array_size_m1(n_contacts,contact_inner_sep,contact_dims):
    return (n_contacts-1)*(contact_inner_sep +np.asarray(contact_dims))/2

def get_mid_ring(adims, bdims):
    return (np.asarray(adims)+np.asarray(bdims))/2 

def get_shift(position, n_contacts,contact_inner_sep, contact_dims, mid_ring):
    half_array_contact_size =  get_half_contact_array_size_m1(n_contacts,contact_inner_sep,contact_dims)
    
    if position=="top":
        hshift=(-1,0)*half_array_contact_size
        vshift=(0,1)*mid_ring/2
    elif position=="left":
        hshift=(-1,0)*mid_ring/2
        vshift=(0,-1)*half_array_contact_size
    elif position=="right":
        hshift=(1, 0)*mid_ring/2
        vshift=(0,-1)*half_array_contact_size
    elif position=="bottom":
        hshift=(-1, 0)*half_array_contact_size
        vshift=(0,-1)*mid_ring/2
    else:
        raise ValueError(f"Not a valid position: {position}")
    return hshift+vshift

# %%
mid_ring_b_e=get_mid_ring(edims, bdims)
mid_ring_c_b=get_mid_ring(bdims, cdims)
get_shift("bottom", n_contacts_b,contact_inner_sep, contact_dims, mid_ring_b_e)
# Out:
# array([-2.35, -3.03])

# %%
def add_ring_contacts(parent, reference,n_contacts, mid_ring, contact_inner_sep,contact_dims):
    positions=["top", "bottom", "left", "right"]
    columns=[int(n_contacts[0]),int(n_contacts[0]),1,1]
    rows=[1, 1, int(n_contacts[1]),int(n_contacts[1])]
    
    refs=[]
    for position,n_column,n_row in list(zip(positions,columns,rows)):
    
        cref=parent.add_ref(reference, 
                         columns=n_column, 
                         rows=n_row, 
                         spacing=tuple(contact_inner_sep +np.asarray(contact_dims))
                        )
        cref.move(tuple([round(x)
               for x in get_shift(position, n_contacts,contact_inner_sep, contact_dims, mid_ring)]))
        refs.append(cref)
    return refs

def add_fill_contacts(parent, reference,n_contacts, contact_array_sep,contact_dims):

    ref=parent.add_ref(reference, 
                     columns=int(n_contacts[0]), 
                     rows=int(n_contacts[1]), 
                     spacing=tuple(contact_array_sep +np.asarray(contact_dims))
                    )
    ref.move(tuple(np.asarray((-1,-1))*(n_contacts-1)*(contact_array_sep +np.asarray(contact_dims))/2))
    return ref

# %%
ccontacts=Component()
refs_e=add_fill_contacts(ccontacts,contact,n_contacts_e,contact_array_sep,contact_dims)
refs_b=add_ring_contacts(ccontacts,contact,n_contacts_b,mid_ring_b_e,contact_inner_sep,contact_dims)
refs_c=add_ring_contacts(ccontacts,contact,n_contacts_c,mid_ring_c_b,contact_inner_sep,contact_dims)

# %%
ccontacts.show()
# Out:
# /headless/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/show.py:40: UserWarning: Unnamed cells, 1 in 'Unnamed_75727628'
#   gdspath = component.write_gds(
# 2025-08-24 22:30:37.261 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.3.3", "klayout_version": "0.30.2", "type": "open", "file": "/tmp/gdsfactory/Unnamed_75727628.gds"}

# %%
top_level.add_ref(ccontacts)
# Out:
# ComponentReference (parent Component "Unnamed_75727628", ports [], origin (0.0, 0.0), rotation 0.0, x_reflection False)

# %%
top_level.show()
# Out:
# /headless/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/show.py:40: UserWarning: Unnamed cells, 1 in 'BJT'
#   gdspath = component.write_gds(
# 2025-08-24 22:30:37.738 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.3.3", "klayout_version": "0.30.2", "type": "open", "file": "/tmp/gdsfactory/BJT.gds"}

# %%
import gdsfactory as gf

# %%
rd=gf.components.rectangular_ring(enclosed_size=edims,layer=pdk.get_glayer(contact_layer_name), width=0.74, centered=True)

# %%
## Adding metal connection
metal_layer_name="met1"
metal_contacts=Component()
m1_e= rectangle(size=tuple(np.asarray(bjt_dims[0])-2*comp_min_sep),
                  layer=pdk.get_glayer(metal_layer_name),centered=True)

m1_b=rectangular_ring(enclosed_size=tuple(np.asarray(bjt_dims[0])+2*comp_min_sep),
                      layer=pdk.get_glayer(metal_layer_name), 
                      width=round((np.asarray(bjt_dims[1][0])-np.asarray(bjt_dims[0][0])-4*comp_min_sep)/2), 
                      centered=True)
m1_c=rectangular_ring(enclosed_size=tuple(np.asarray(bjt_dims[1])+2*comp_min_sep),
                      layer=pdk.get_glayer(metal_layer_name), 
                      width=round((np.asarray(bjt_dims[2][0])-np.asarray(bjt_dims[1][0])-4*comp_min_sep)/2), 
                      centered=True)
metal_contacts.add_ref(m1_e)
metal_contacts.add_ref(m1_b)
metal_contacts.add_ref(m1_c)
# Out:
# ComponentReference (parent Component "rectangular_ring_7e769340$2", ports [], origin (0.0, 0.0), rotation 0.0, x_reflection False)

# %%
metal_contacts.show()
# Out:
# /headless/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/show.py:40: UserWarning: Unnamed cells, 1 in 'Unnamed_70310716'
#   gdspath = component.write_gds(
# 2025-08-25 05:11:18.167 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.3.3", "klayout_version": "0.30.2", "type": "open", "file": "/tmp/gdsfactory/Unnamed_70310716.gds"}

# %%
metal_contacts.add_label("E", position=(0,0),layer=pdk.get_glayer(metal_layer_name))

directions=((1,0),(0,1),(-1,0),(0,-1))
for direction in directions:
    metal_contacts.add_label("B", position=tuple(np.asarray(direction)*get_mid_ring(bdims,edims)/2),
                        layer=pdk.get_glayer(metal_layer_name))
    metal_contacts.add_label("C", position=tuple(np.asarray(direction)*get_mid_ring(cdims,bdims)/2),
                        layer=pdk.get_glayer(metal_layer_name))

# %%
metal_contacts.show()
# Out:
# 2025-08-25 05:11:50.555 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.3.3", "klayout_version": "0.30.2", "type": "reload", "file": "/tmp/gdsfactory/Unnamed_70310716.gds"}

# %%
top_level.add_ref(metal_contacts)
# Out:
# ComponentReference (parent Component "Unnamed_70310716", ports [], origin (0.0, 0.0), rotation 0.0, x_reflection False)

# %%
top_level.show()
# Out:
# /headless/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/show.py:40: UserWarning: Unnamed cells, 2 in 'BJT'
#   gdspath = component.write_gds(
# 2025-08-25 05:12:43.423 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.3.3", "klayout_version": "0.30.2", "type": "reload", "file": "/tmp/gdsfactory/BJT.gds"}

# %%
drc_bjt= rectangle(size=tuple(np.asarray(bjt_dims[2])),
                  layer=(127,5),centered=True)
lvs_bjt= rectangle(size=tuple(np.asarray(bjt_dims[0])-2*comp_min_sep),
                  layer=(118,5),centered=True)

# %%
drc_bjt.show()
# Out:
# 2025-08-25 05:20:28.026 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.3.3", "klayout_version": "0.30.2", "type": "open", "file": "/tmp/gdsfactory/rectangle_f36c0b6e.gds"}

# %%
lvs_bjt.show()
# Out:
# 2025-08-25 05:20:35.509 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.3.3", "klayout_version": "0.30.2", "type": "open", "file": "/tmp/gdsfactory/rectangle_f41950f2.gds"}

# %%
top_level.add_ref(drc_bjt)
top_level.add_ref(lvs_bjt)
# Out:
# ComponentReference (parent Component "rectangle_f41950f2", ports ['e1', 'e2', 'e3', 'e4'], origin (0.0, 0.0), rotation 0.0, x_reflection False)

# %%
top_level.show()
# Out:
# 2025-08-25 05:21:39.589 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.3.3", "klayout_version": "0.30.2", "type": "reload", "file": "/tmp/gdsfactory/BJT.gds"}

# %%
top_level.pprint_ports()

# %%
bjt=top_level.flatten()

# %%
bjt.show()
# Out:
# 2025-08-25 06:08:59.918 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.3.3", "klayout_version": "0.30.2", "type": "reload", "file": "/tmp/gdsfactory/Unnamed_3a001304.gds"}

# %%
bjt.pprint_ports()

# %%
from pathlib import Path
import os
import subprocess
import tempfile
magicrc_file = Path(os.environ['PDKPATH']) / "libs.tech" / "magic" / f"{os.environ['PDK']}.magicrc"
magicrc_file
# Out:
# PosixPath('/foss/pdks/gf180mcuD/libs.tech/magic/gf180mcuD.magicrc')

# %%
design_name=bjt.name
path_to_dir = Path("/foss/designs/gLayout/tutorial").resolve() / "ext" / design_name
if not path_to_dir.exists():
    path_to_dir.mkdir(parents=True, exist_ok=False)

pex_path = path_to_dir / f"{design_name}_pex.spice"
gds_path = path_to_dir / f"{design_name}.gds"


bjt.write_gds(str(gds_path))
    
magic_script_content = f"""
drc off            
gds flatglob *\\$\\$*
gds read {gds_path}

flatten {design_name}
load {design_name}
select top cell
extract do local
extract all
ext2sim labels on
ext2sim
extresist tolerance 10
extresist
ext2spice lvs
ext2spice cthresh 0
ext2spice extresist on
ext2spice -o {str(pex_path)}
exit
"""

with tempfile.NamedTemporaryFile(mode='w', delete=False) as magic_script_file:
    magic_script_file.write(magic_script_content)
    magic_script_path = magic_script_file.name
    
magic_cmd = f"bash -c 'magic -rcfile {magicrc_file} -noconsole -dnull < {magic_script_path}'",
magic_subproc = subprocess.run(
    magic_cmd, 
    shell=True,
    check=True,
    capture_output=True
)

magic_subproc_code = magic_subproc.returncode
magic_subproc_out = magic_subproc.stdout.decode('utf-8')
print(magic_subproc_out)
# Out:
# /tmp/ipykernel_1681/3492962226.py:10: UserWarning: Unnamed cells, 1 in 'Unnamed_3a001304'
#   bjt.write_gds(str(gds_path))
# 2025-08-25 06:09:51.936 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/foss/designs/gLayout/tutorial/ext/Unnamed_3a001304/Unnamed_3a001304.gds'
# Magic 8.3 revision 528 - Compiled on Wed Jun 18 09:45:25 PM CEST 2025.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=4096]
# Using NULL graphics device.
# Processing system .magicrc file
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Using technology "gf180mcuD", version 1.0.525-0-gf2e289d
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "Unnamed_3a001304".
# Moving label "E" from metal1 to pdiffc in cell Unnamed_3a001304.
# Moving label "E" from metal1 to pdiffc in cell Unnamed_3a001304.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_3a001304.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_3a001304.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_3a001304.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_3a001304.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_3a001304.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_3a001304.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_3a001304.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_3a001304.
# Extracting Unnamed_3a001304 into Unnamed_3a001304.ext:
# exttosim finished.
# Total Nets: 5
# Nets extracted: 1 (0.200000)
# Nets output: 0 (0.000000)
# exttospice finished.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from glayout.primitives.bjt import draw_bjt
from glayout import MappedPDK, sky130 , gf180
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
pdk=gf180
pdk.activate()
# Out:
# 2025-08-28 05:11:16.269 | INFO     | gdsfactory.pdk:activate:337 - 'gf180' PDK is now active

# %%
bjt=draw_bjt(pdk,(5,5),"pnp")
# Out:
# {'N': {'size': (5.340000000000001, 0.42000000000000004)}, 'S': {'size': (5.340000000000001, 0.42000000000000004)}, 'E': {'size': (0.42000000000000004, 6.48)}, 'W': {'size': (0.42000000000000004, 6.48)}}
# {'size': (5.340000000000001, 0.42000000000000004)}
# {'size': (5.340000000000001, 0.42000000000000004)}
# {'size': (0.42000000000000004, 6.48)}
# {'size': (0.42000000000000004, 6.48)}
# {'N': {'size': (6.820000000000001, 0.42000000000000004)}, 'S': {'size': (6.820000000000001, 0.42000000000000004)}, 'E': {'size': (0.42000000000000004, 7.960000000000001)}, 'W': {'size': (0.42000000000000004, 7.960000000000001)}}
# {'size': (6.820000000000001, 0.42000000000000004)}
# {'size': (6.820000000000001, 0.42000000000000004)}
# {'size': (0.42000000000000004, 7.960000000000001)}
# {'size': (0.42000000000000004, 7.960000000000001)}

# %%
bjt.show()
# Out:
# /headless/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/show.py:40: UserWarning: Unnamed cells, 23 in 'Unnamed_a991c8bc'
#   gdspath = component.write_gds(
# 2025-08-28 08:07:47.551 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.3.3", "klayout_version": "0.30.2", "type": "open", "file": "/tmp/gdsfactory/Unnamed_a991c8bc.gds"}

# %%
pdk.get_glayer("drc_bjt")
# Out:
# (127, 5)

# %%
pdk.__dict__
# Out:
# {'name': 'gf180',
#  'cross_sections': {},
#  'cells': {},
#  'symbols': {},
#  'default_symbol_factory': functools.partial(<function floorplan_with_block_letters at 0x7f14d095b7f0>, prefix='SYMBOL_floorplan_with_block_letters'),
#  'base_pdk': None,
#  'default_decorator': None,
#  'layers': {'metal5': (81, 0),
#   'via4': (41, 0),
#   'metal4': (46, 0),
#   'via3': (40, 0),
#   'metal3': (42, 0),
#   'via2': (38, 0),
#   'metal2': (36, 0),
#   'via1': (35, 0),
#   'metal1': (34, 0),
#   'contact': (33, 0),
#   'poly2': (30, 0),
#   'comp': (22, 0),
#   'nplus': (32, 0),
#   'pplus': (31, 0),
#   'nwell': (21, 0),
#   'lvpwell': (204, 0),
#   'dnwell': (12, 0),
#   'CAP_MK': (117, 5),
#   'metal5_label': (81, 10),
#   'metal4_label': (46, 10),
#   'metal3_label': (42, 10),
#   'metal2_label': (36, 10),
#   'metal1_label': (34, 10),
#   'poly2_label': (30, 10),
#   'comp_label': (22, 10)},
#  'layer_stack': None,
#  'layer_views': None,
#  'layer_transitions': {},
#  'sparameters_path': None,
#  'modes_path': None,
#  'interconnect_cml_path': None,
#  'warn_off_grid_ports': False,
#  'constants': {'fiber_array_spacing': 127.0,
#   'fiber_spacing': 50.0,
#   'fiber_input_to_output_spacing': 200.0,
#   'metal_spacing': 10.0,
#   'pad_spacing': 100.0,
#   'pad_size': (80, 80)},
#  'materials_index': {},
#  'routing_strategies': None,
#  'gds_write_settings': GdsWriteSettings(on_uncached_component='ignore', lib_name='library', unit=1e-06, precision=5e-09, on_duplicate_cell='warn', flatten_invalid_refs=False, max_points=4000),
#  'oasis_settings': OasisWriteSettings(compression_level=6, detect_rectangles=True, detect_trapezoids=True, circle_tolerance=0, validation=None, standard_properties=False),
#  'cell_decorator_settings': CellDecoratorSettings(with_hash=False, autoname=True, name=None, cache=False, flatten=False, info={}, prefix=None, max_name_length=99, include_module=False, naming_style='default', assert_ports_on_grid=True),
#  'bend_points_distance': 0.02,
#  'models': {'nfet': 'nfet_03v3',
#   'pfet': 'pfet_03v3',
#   'mimcap': 'mimcap_1p0fF'},
#  'glayers': {'met5': 'metal5',
#   'via4': 'via4',
#   'met4': 'metal4',
#   'via3': 'via3',
#   'met3': 'metal3',
#   'via2': 'via2',
#   'met2': 'metal2',
#   'via1': 'via1',
#   'met1': 'metal1',
#   'mcon': 'contact',
#   'poly': 'poly2',
#   'active_diff': 'comp',
#   'active_tap': 'comp',
#   'n+s/d': 'nplus',
#   'p+s/d': 'pplus',
#   'nwell': 'nwell',
#   'pwell': 'lvpwell',
#   'dnwell': 'dnwell',
#   'capmet': 'CAP_MK',
#   'met5_pin': 'metal5_label',
#   'met4_pin': 'metal4_label',
#   'met3_pin': 'metal3_label',
#   'met2_pin': 'metal2_label',
#   'met1_pin': 'metal1_label',
#   'poly_pin': 'poly2_label',
#   'active_diff_pin': 'comp_label',
#   'met5_label': 'metal5_label',
#   'met4_label': 'metal4_label',
#   'met3_label': 'metal3_label',
#   'met2_label': 'metal2_label',
#   'met1_label': 'metal1_label',
#   'poly_label': 'poly2_label',
#   'active_diff_label': 'comp_label'},
#  'grules': {'dnwell': {'dnwell': {'min_width': 1.7, 'min_separation': 5.42},
#    'pwell': {'min_enclosure': 2.5},
#    'nwell': {'min_separation': 3.1, 'min_enclosure': 0.5},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {'min_enclosure': 0.93},
#    'active_tap': {'min_enclosure': 0.62, 'min_separation': 2.5},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'pwell': {'dnwell': {},
#    'pwell': {'min_width': 0.6, 'min_separation': 1.4},
#    'nwell': {'min_separation': 0.0},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {'min_enclosure': 0.43},
#    'active_tap': {'min_enclosure': 0.12},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'nwell': {'dnwell': {},
#    'pwell': {},
#    'nwell': {'min_width': 0.86, 'min_separation': 1.4},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {'min_enclosure': 0.43},
#    'active_tap': {'min_enclosure': 0.12},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'p+s/d': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {'min_width': 0.4, 'min_separation': 0.4},
#    'n+s/d': {},
#    'active_diff': {'min_enclosure': 0.23},
#    'active_tap': {'min_enclosure': 0.16},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'n+s/d': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {'min_width': 0.4, 'min_separation': 0.4},
#    'active_diff': {'min_enclosure': 0.23},
#    'active_tap': {'min_enclosure': 0.16},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'active_diff': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {'min_width': 0.22, 'min_separation': 0.28},
#    'active_tap': {'min_separation': 0.28, 'max_separation': 20.0},
#    'poly': {'overhang': 0.24, 'min_separation': 0.1},
#    'mcon': {'min_enclosure': 0.07},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'active_tap': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {'min_width': 0.22, 'min_separation': 0.28},
#    'poly': {'min_separation': 0.1},
#    'mcon': {'min_enclosure': 0.07},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'poly': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {'min_width': 0.28},
#    'mcon': {'min_enclosure': 0.07, 'min_separation': 0.17},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'mcon': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {},
#    'mcon': {'min_separation': 0.28, 'width': 0.22},
#    'met1': {'min_enclosure': 0.12},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met1': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {},
#    'mcon': {},
#    'met1': {'min_width': 0.23, 'min_separation': 0.3},
#    'via1': {'min_enclosure': 0.12},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'via1': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {'width': 0.26, 'min_separation': 0.36},
#    'met2': {'min_enclosure': 0.12},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met2': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {'min_width': 0.28, 'min_separation': 0.3},
#    'via2': {'min_enclosure': 0.12},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {'min_enclosure': 0.6},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'via2': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {'width': 0.26, 'min_separation': 0.36},
#    'met3': {'min_enclosure': 0.12},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met3': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {'min_width': 0.28, 'min_separation': 0.3},
#    'via3': {'min_enclosure': 0.12},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'via3': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {'width': 0.26, 'min_separation': 0.36},
#    'met4': {'min_enclosure': 0.12},
#    'via4': {},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met4': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {'min_width': 0.28, 'min_separation': 0.3},
#    'via4': {'min_enclosure': 0.12},
#    'met5': {},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'via4': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {'width': 0.26, 'min_separation': 0.36},
#    'met5': {'min_enclosure': 0.12},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met5': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {'min_width': 0.28, 'min_separation': 0.3},
#    'capmet': {},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'capmet': {'dnwell': {},
#    'pwell': {},
#    'nwell': {},
#    'p+s/d': {},
#    'n+s/d': {},
#    'active_diff': {},
#    'active_tap': {},
#    'poly': {},
#    'mcon': {},
#    'met1': {},
#    'via1': {},
#    'met2': {},
#    'via2': {},
#    'met3': {},
#    'via3': {},
#    'met4': {},
#    'via4': {},
#    'met5': {},
#    'capmet': {'capmettop': (42, 0),
#     'capmetbottom': (36, 0),
#     'min_separation': 1.2},
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met5_pin': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met4_pin': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met3_pin': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met2_pin': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met1_pin': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'poly_pin': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'active_diff_pin': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met5_label': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met4_label': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met3_label': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met2_label': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'met1_label': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'poly_label': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None},
#   'active_diff_label': {'dnwell': None,
#    'pwell': None,
#    'nwell': None,
#    'p+s/d': None,
#    'n+s/d': None,
#    'active_diff': None,
#    'active_tap': None,
#    'poly': None,
#    'mcon': None,
#    'met1': None,
#    'via1': None,
#    'met2': None,
#    'via2': None,
#    'met3': None,
#    'via3': None,
#    'met4': None,
#    'via4': None,
#    'met5': None,
#    'capmet': None,
#    'met5_pin': None,
#    'met4_pin': None,
#    'met3_pin': None,
#    'met2_pin': None,
#    'met1_pin': None,
#    'poly_pin': None,
#    'active_diff_pin': None,
#    'met5_label': None,
#    'met4_label': None,
#    'met3_label': None,
#    'met2_label': None,
#    'met1_label': None,
#    'poly_label': None,
#    'active_diff_label': None}},
#  'pdk_files': {'pdk_root': PosixPath('/foss/pdks'),
#   'klayout_drc_file': PosixPath('/foss/designs/gLayout/src/glayout/pdk/gf180_mapped/gf180mcu_drc.lydrc'),
#   'lvs_schematic_ref_file': PosixPath('/foss/designs/gLayout/src/glayout/pdk/gf180_mapped/gf180mcu_osu_sc_9T.spice'),
#   'lvs_setup_tcl_file': PosixPath('/foss/pdks/gf180mcuD/libs.tech/netgen/gf180mcuD_setup.tcl'),
#   'magic_drc_file': PosixPath('/foss/pdks/gf180mcuD/libs.tech/magic/gf180mcuD.magicrc'),
#   'temp_dir': None,
#   'pdk': 'gf180'},
#  'valid_bjt_sizes': {'npn': [(0.54, 2.0),
#    (0.54, 4.0),
#    (0.54, 8.0),
#    (0.54, 16.0),
#    (5.0, 5.0),
#    (10.0, 10.0)],
#   'pnp': [(5.0, 0.42), (5.0, 5.0), (10.0, 0.42), (10.0, 10.0)]}}

# %%
bjt.ref().__dict__
# Out:
# {'_reference': <gdstk.Reference at 0x717a24675250>,
#  '_ref_cell': Unnamed_2d21d571: uid 2d21d571, ports ['diff_e_e1', 'diff_e_e2', 'diff_e_e3', 'diff_e_e4', 'tap_e_e1', 'tap_e_e2', 'tap_e_e3', 'tap_e_e4', 'well_e1', 'well_e2', 'well_e3', 'well_e4', 'dnwell_e1', 'dnwell_e2', 'dnwell_e3', 'dnwell_e4', 'lvs_e1', 'lvs_e2', 'lvs_e3', 'lvs_e4', 'drc_e1', 'drc_e2', 'drc_e3', 'drc_e4'], references ['rectangle_1', 'rectangular_ring_1', 'rectangular_ring_2', 'rectangle_2', 'rectangular_ring_3', 'rectangular_ring_4', 'rectangle_3', 'rectangle_4', 'rectangle_5', 'rectangle_6'], 0 polygons,
#  '_owner': None,
#  '_name': None,
#  '_local_ports': {'diff_e_e1': {'name': 'diff_e_e1', 'width': 5.32, 'center': [-2.66, 0.0], 'orientation': 180.0, 'layer': [32, 0], 'port_type': 'electrical'},
#   'diff_e_e2': {'name': 'diff_e_e2', 'width': 5.32, 'center': [0.0, 2.66], 'orientation': 90.0, 'layer': [32, 0], 'port_type': 'electrical'},
#   'diff_e_e3': {'name': 'diff_e_e3', 'width': 5.32, 'center': [2.66, 0.0], 'orientation': 0.0, 'layer': [32, 0], 'port_type': 'electrical'},
#   'diff_e_e4': {'name': 'diff_e_e4', 'width': 5.32, 'center': [0.0, -2.66], 'orientation': 270.0, 'layer': [32, 0], 'port_type': 'electrical'},
#   'tap_e_e1': {'name': 'tap_e_e1', 'width': 5.0, 'center': [-2.5, 0.0], 'orientation': 180.0, 'layer': [22, 0], 'port_type': 'electrical'},
#   'tap_e_e2': {'name': 'tap_e_e2', 'width': 5.0, 'center': [0.0, 2.5], 'orientation': 90.0, 'layer': [22, 0], 'port_type': 'electrical'},
#   'tap_e_e3': {'name': 'tap_e_e3', 'width': 5.0, 'center': [2.5, 0.0], 'orientation': 0.0, 'layer': [22, 0], 'port_type': 'electrical'},
#   'tap_e_e4': {'name': 'tap_e_e4', 'width': 5.0, 'center': [0.0, -2.5], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#   'well_e1': {'name': 'well_e1', 'width': 6.8, 'center': [-3.4, 0.0], 'orientation': 180.0, 'layer': [204, 0], 'port_type': 'electrical'},
#   'well_e2': {'name': 'well_e2', 'width': 6.8, 'center': [0.0, 3.4], 'orientation': 90.0, 'layer': [204, 0], 'port_type': 'electrical'},
#   'well_e3': {'name': 'well_e3', 'width': 6.8, 'center': [3.4, 0.0], 'orientation': 0.0, 'layer': [204, 0], 'port_type': 'electrical'},
#   'well_e4': {'name': 'well_e4', 'width': 6.8, 'center': [0.0, -3.4], 'orientation': 270.0, 'layer': [204, 0], 'port_type': 'electrical'},
#   'dnwell_e1': {'name': 'dnwell_e1', 'width': 11.8, 'center': [-5.9, 0.0], 'orientation': 180.0, 'layer': [12, 0], 'port_type': 'electrical'},
#   'dnwell_e2': {'name': 'dnwell_e2', 'width': 11.8, 'center': [0.0, 5.9], 'orientation': 90.0, 'layer': [12, 0], 'port_type': 'electrical'},
#   'dnwell_e3': {'name': 'dnwell_e3', 'width': 11.8, 'center': [5.9, 0.0], 'orientation': 0.0, 'layer': [12, 0], 'port_type': 'electrical'},
#   'dnwell_e4': {'name': 'dnwell_e4', 'width': 11.8, 'center': [0.0, -5.9], 'orientation': 270.0, 'layer': [12, 0], 'port_type': 'electrical'},
#   'lvs_e1': {'name': 'lvs_e1', 'width': 5.0, 'center': [-2.5, 0.0], 'orientation': 180.0, 'layer': [118, 5], 'port_type': 'electrical'},
#   'lvs_e2': {'name': 'lvs_e2', 'width': 5.0, 'center': [0.0, 2.5], 'orientation': 90.0, 'layer': [118, 5], 'port_type': 'electrical'},
#   'lvs_e3': {'name': 'lvs_e3', 'width': 5.0, 'center': [2.5, 0.0], 'orientation': 0.0, 'layer': [118, 5], 'port_type': 'electrical'},
#   'lvs_e4': {'name': 'lvs_e4', 'width': 5.0, 'center': [0.0, -2.5], 'orientation': 270.0, 'layer': [118, 5], 'port_type': 'electrical'},
#   'drc_e1': {'name': 'drc_e1', 'width': 11.8, 'center': [-5.9, 0.0], 'orientation': 180.0, 'layer': [127, 5], 'port_type': 'electrical'},
#   'drc_e2': {'name': 'drc_e2', 'width': 11.8, 'center': [0.0, 5.9], 'orientation': 90.0, 'layer': [127, 5], 'port_type': 'electrical'},
#   'drc_e3': {'name': 'drc_e3', 'width': 11.8, 'center': [5.9, 0.0], 'orientation': 0.0, 'layer': [127, 5], 'port_type': 'electrical'},
#   'drc_e4': {'name': 'drc_e4', 'width': 11.8, 'center': [0.0, -5.9], 'orientation': 270.0, 'layer': [127, 5], 'port_type': 'electrical'}},
#  'visual_label': '',
#  '_bb_valid': False}

# %%
bjt.__dict__
# Out:
# {'uid': '2d21d571',
#  '_cell': <gdstk.Cell at 0x717a24fed0f0>,
#  'info': {},
#  'settings': {},
#  '_locked': False,
#  '_get_child_name': False,
#  '_reference_names_counter': Counter({'rectangle': 6, 'rectangular_ring': 4}),
#  '_reference_names_used': set(),
#  '_named_references': {'rectangle_1': ComponentReference (parent Component "rectangle_bbf0178c$1", ports ['e1', 'e2', 'e3', 'e4'], origin (0.0, 0.0), rotation 0.0, x_reflection False),
#   'rectangular_ring_1': ComponentReference (parent Component "rectangular_ring_dfa18963", ports [], origin (0.0, 0.0), rotation 0.0, x_reflection False),
#   'rectangular_ring_2': ComponentReference (parent Component "rectangular_ring_7e08e2e4", ports [], origin (0.0, 0.0), rotation 0.0, x_reflection False),
#   'rectangle_2': ComponentReference (parent Component "rectangle_b48284b0$1", ports ['e1', 'e2', 'e3', 'e4'], origin (0.0, 0.0), rotation 0.0, x_reflection False),
#   'rectangular_ring_3': ComponentReference (parent Component "rectangular_ring_cc230cb4$1", ports [], origin (0.0, 0.0), rotation 0.0, x_reflection False),
#   'rectangular_ring_4': ComponentReference (parent Component "rectangular_ring_11024275$1", ports [], origin (0.0, 0.0), rotation 0.0, x_reflection False),
#   'rectangle_3': ComponentReference (parent Component "rectangle_3b18275e", ports ['e1', 'e2', 'e3', 'e4'], origin (0.0, 0.0), rotation 0.0, x_reflection False),
#   'rectangle_4': ComponentReference (parent Component "rectangle_fef6e026", ports ['e1', 'e2', 'e3', 'e4'], origin (0.0, 0.0), rotation 0.0, x_reflection False),
#   'rectangle_5': ComponentReference (parent Component "rectangle_7d63ee09$1", ports ['e1', 'e2', 'e3', 'e4'], origin (0.0, 0.0), rotation 0.0, x_reflection False),
#   'rectangle_6': ComponentReference (parent Component "rectangle_f1833b15", ports ['e1', 'e2', 'e3', 'e4'], origin (0.0, 0.0), rotation 0.0, x_reflection False)},
#  '_references': [ComponentReference (parent Component "rectangle_bbf0178c$1", ports ['e1', 'e2', 'e3', 'e4'], origin (0.0, 0.0), rotation 0.0, x_reflection False),
#   ComponentReference (parent Component "rectangular_ring_dfa18963", ports [], origin (0.0, 0.0), rotation 0.0, x_reflection False),
#   ComponentReference (parent Component "rectangular_ring_7e08e2e4", ports [], origin (0.0, 0.0), rotation 0.0, x_reflection False),
#   ComponentReference (parent Component "rectangle_b48284b0$1", ports ['e1', 'e2', 'e3', 'e4'], origin (0.0, 0.0), rotation 0.0, x_reflection False),
#   ComponentReference (parent Component "rectangular_ring_cc230cb4$1", ports [], origin (0.0, 0.0), rotation 0.0, x_reflection False),
#   ComponentReference (parent Component "rectangular_ring_11024275$1", ports [], origin (0.0, 0.0), rotation 0.0, x_reflection False),
#   ComponentReference (parent Component "rectangle_3b18275e", ports ['e1', 'e2', 'e3', 'e4'], origin (0.0, 0.0), rotation 0.0, x_reflection False),
#   ComponentReference (parent Component "rectangle_fef6e026", ports ['e1', 'e2', 'e3', 'e4'], origin (0.0, 0.0), rotation 0.0, x_reflection False),
#   ComponentReference (parent Component "rectangle_7d63ee09$1", ports ['e1', 'e2', 'e3', 'e4'], origin (0.0, 0.0), rotation 0.0, x_reflection False),
#   ComponentReference (parent Component "rectangle_f1833b15", ports ['e1', 'e2', 'e3', 'e4'], origin (0.0, 0.0), rotation 0.0, x_reflection False)],
#  'ports': {'diff_e_e1': {'name': 'diff_e_e1', 'width': 5.32, 'center': [-2.66, 0.0], 'orientation': 180.0, 'layer': [32, 0], 'port_type': 'electrical'},
#   'diff_e_e2': {'name': 'diff_e_e2', 'width': 5.32, 'center': [0.0, 2.66], 'orientation': 90.0, 'layer': [32, 0], 'port_type': 'electrical'},
#   'diff_e_e3': {'name': 'diff_e_e3', 'width': 5.32, 'center': [2.66, 0.0], 'orientation': 0.0, 'layer': [32, 0], 'port_type': 'electrical'},
#   'diff_e_e4': {'name': 'diff_e_e4', 'width': 5.32, 'center': [0.0, -2.66], 'orientation': 270.0, 'layer': [32, 0], 'port_type': 'electrical'},
#   'tap_e_e1': {'name': 'tap_e_e1', 'width': 5.0, 'center': [-2.5, 0.0], 'orientation': 180.0, 'layer': [22, 0], 'port_type': 'electrical'},
#   'tap_e_e2': {'name': 'tap_e_e2', 'width': 5.0, 'center': [0.0, 2.5], 'orientation': 90.0, 'layer': [22, 0], 'port_type': 'electrical'},
#   'tap_e_e3': {'name': 'tap_e_e3', 'width': 5.0, 'center': [2.5, 0.0], 'orientation': 0.0, 'layer': [22, 0], 'port_type': 'electrical'},
#   'tap_e_e4': {'name': 'tap_e_e4', 'width': 5.0, 'center': [0.0, -2.5], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#   'well_e1': {'name': 'well_e1', 'width': 6.8, 'center': [-3.4, 0.0], 'orientation': 180.0, 'layer': [204, 0], 'port_type': 'electrical'},
#   'well_e2': {'name': 'well_e2', 'width': 6.8, 'center': [0.0, 3.4], 'orientation': 90.0, 'layer': [204, 0], 'port_type': 'electrical'},
#   'well_e3': {'name': 'well_e3', 'width': 6.8, 'center': [3.4, 0.0], 'orientation': 0.0, 'layer': [204, 0], 'port_type': 'electrical'},
#   'well_e4': {'name': 'well_e4', 'width': 6.8, 'center': [0.0, -3.4], 'orientation': 270.0, 'layer': [204, 0], 'port_type': 'electrical'},
#   'dnwell_e1': {'name': 'dnwell_e1', 'width': 11.8, 'center': [-5.9, 0.0], 'orientation': 180.0, 'layer': [12, 0], 'port_type': 'electrical'},
#   'dnwell_e2': {'name': 'dnwell_e2', 'width': 11.8, 'center': [0.0, 5.9], 'orientation': 90.0, 'layer': [12, 0], 'port_type': 'electrical'},
#   'dnwell_e3': {'name': 'dnwell_e3', 'width': 11.8, 'center': [5.9, 0.0], 'orientation': 0.0, 'layer': [12, 0], 'port_type': 'electrical'},
#   'dnwell_e4': {'name': 'dnwell_e4', 'width': 11.8, 'center': [0.0, -5.9], 'orientation': 270.0, 'layer': [12, 0], 'port_type': 'electrical'},
#   'lvs_e1': {'name': 'lvs_e1', 'width': 5.0, 'center': [-2.5, 0.0], 'orientation': 180.0, 'layer': [118, 5], 'port_type': 'electrical'},
#   'lvs_e2': {'name': 'lvs_e2', 'width': 5.0, 'center': [0.0, 2.5], 'orientation': 90.0, 'layer': [118, 5], 'port_type': 'electrical'},
#   'lvs_e3': {'name': 'lvs_e3', 'width': 5.0, 'center': [2.5, 0.0], 'orientation': 0.0, 'layer': [118, 5], 'port_type': 'electrical'},
#   'lvs_e4': {'name': 'lvs_e4', 'width': 5.0, 'center': [0.0, -2.5], 'orientation': 270.0, 'layer': [118, 5], 'port_type': 'electrical'},
#   'drc_e1': {'name': 'drc_e1', 'width': 11.8, 'center': [-5.9, 0.0], 'orientation': 180.0, 'layer': [127, 5], 'port_type': 'electrical'},
#   'drc_e2': {'name': 'drc_e2', 'width': 11.8, 'center': [0.0, 5.9], 'orientation': 90.0, 'layer': [127, 5], 'port_type': 'electrical'},
#   'drc_e3': {'name': 'drc_e3', 'width': 11.8, 'center': [5.9, 0.0], 'orientation': 0.0, 'layer': [127, 5], 'port_type': 'electrical'},
#   'drc_e4': {'name': 'drc_e4', 'width': 11.8, 'center': [0.0, -5.9], 'orientation': 270.0, 'layer': [127, 5], 'port_type': 'electrical'}}}

# %%
bjt.center
# Out:
# array([0., 0.])

# %%
from glayout import prec_center

# %%
prec_center(bjt)
# Out:
# [0.0, 0.0]

# %%
bjt.ymax
# Out:
# 5.9
