# %% [markdown]
# ## Using the BJT models from glayout

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from glayout.primitives.bjt import draw_bjt
from glayout import MappedPDK, sky130 , gf180
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
pdk=gf180
pdk.activate()
# Out:
# 2025-09-02 07:07:29.904 | INFO     | gdsfactory.pdk:activate:337 - 'gf180' PDK is now active

# %%
bjt=draw_bjt(pdk,(5,5),"pnp")

# %%
bjt.show()
# Out:
# /headless/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/show.py:40: UserWarning: Unnamed cells, 23 in 'Unnamed_60701cab'
#   gdspath = component.write_gds(
# 2025-09-02 07:07:33.887 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.3.3", "klayout_version": "0.30.2", "type": "open", "file": "/tmp/gdsfactory/Unnamed_60701cab.gds"}

# %%
bjt.ports
# Out:
# {'diff_e_W': {'name': 'diff_e_W', 'width': 5.32, 'center': [-2.66, 0.0], 'orientation': 180.0, 'layer': [31, 0], 'port_type': 'electrical'},
#  'diff_e_N': {'name': 'diff_e_N', 'width': 5.32, 'center': [0.0, 2.66], 'orientation': 90.0, 'layer': [31, 0], 'port_type': 'electrical'},
#  'diff_e_E': {'name': 'diff_e_E', 'width': 5.32, 'center': [2.66, 0.0], 'orientation': 0.0, 'layer': [31, 0], 'port_type': 'electrical'},
#  'diff_e_S': {'name': 'diff_e_S', 'width': 5.32, 'center': [0.0, -2.66], 'orientation': 270.0, 'layer': [31, 0], 'port_type': 'electrical'},
#  'tap_e_W': {'name': 'tap_e_W', 'width': 5.0, 'center': [-2.5, 0.0], 'orientation': 180.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'tap_e_N': {'name': 'tap_e_N', 'width': 5.0, 'center': [0.0, 2.5], 'orientation': 90.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'tap_e_E': {'name': 'tap_e_E', 'width': 5.0, 'center': [2.5, 0.0], 'orientation': 0.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'tap_e_S': {'name': 'tap_e_S', 'width': 5.0, 'center': [0.0, -2.5], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'well_W': {'name': 'well_W', 'width': 6.8, 'center': [-3.4, 0.0], 'orientation': 180.0, 'layer': [21, 0], 'port_type': 'electrical'},
#  'well_N': {'name': 'well_N', 'width': 6.8, 'center': [0.0, 3.4], 'orientation': 90.0, 'layer': [21, 0], 'port_type': 'electrical'},
#  'well_E': {'name': 'well_E', 'width': 6.8, 'center': [3.4, 0.0], 'orientation': 0.0, 'layer': [21, 0], 'port_type': 'electrical'},
#  'well_S': {'name': 'well_S', 'width': 6.8, 'center': [0.0, -3.4], 'orientation': 270.0, 'layer': [21, 0], 'port_type': 'electrical'},
#  'lvs_W': {'name': 'lvs_W', 'width': 5.0, 'center': [-2.5, 0.0], 'orientation': 180.0, 'layer': [118, 5], 'port_type': 'electrical'},
#  'lvs_N': {'name': 'lvs_N', 'width': 5.0, 'center': [0.0, 2.5], 'orientation': 90.0, 'layer': [118, 5], 'port_type': 'electrical'},
#  'lvs_E': {'name': 'lvs_E', 'width': 5.0, 'center': [2.5, 0.0], 'orientation': 0.0, 'layer': [118, 5], 'port_type': 'electrical'},
#  'lvs_S': {'name': 'lvs_S', 'width': 5.0, 'center': [0.0, -2.5], 'orientation': 270.0, 'layer': [118, 5], 'port_type': 'electrical'},
#  'drc_W': {'name': 'drc_W', 'width': 8.28, 'center': [-4.14, 0.0], 'orientation': 180.0, 'layer': [127, 5], 'port_type': 'electrical'},
#  'drc_N': {'name': 'drc_N', 'width': 8.28, 'center': [0.0, 4.14], 'orientation': 90.0, 'layer': [127, 5], 'port_type': 'electrical'},
#  'drc_E': {'name': 'drc_E', 'width': 8.28, 'center': [4.14, 0.0], 'orientation': 0.0, 'layer': [127, 5], 'port_type': 'electrical'},
#  'drc_S': {'name': 'drc_S', 'width': 8.28, 'center': [0.0, -4.14], 'orientation': 270.0, 'layer': [127, 5], 'port_type': 'electrical'},
#  'E_W': {'name': 'E_W', 'width': 5.0, 'center': [-2.5, 0.0], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'E_N': {'name': 'E_N', 'width': 5.0, 'center': [0.0, 2.5], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'E_E': {'name': 'E_E', 'width': 5.0, 'center': [2.5, 0.0], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'E_S': {'name': 'E_S', 'width': 5.0, 'center': [0.0, -2.5], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'B_metal_S_W': {'name': 'B_metal_S_W', 'width': 0.42, 'center': [-3.24, -3.03], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'B_metal_E_W': {'name': 'B_metal_E_W', 'width': 6.48, 'center': [2.82, 0.0], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'B_metal_W_W': {'name': 'B_metal_W_W', 'width': 6.48, 'center': [-3.24, 0.0], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'B_metal_N_W': {'name': 'B_metal_N_W', 'width': 0.42, 'center': [-3.24, 3.03], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'B_metal_W_N': {'name': 'B_metal_W_N', 'width': 0.42, 'center': [-3.03, 3.24], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'B_metal_N_N': {'name': 'B_metal_N_N', 'width': 6.48, 'center': [0.0, 3.24], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'B_metal_S_N': {'name': 'B_metal_S_N', 'width': 6.48, 'center': [0.0, -2.82], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'B_metal_E_N': {'name': 'B_metal_E_N', 'width': 0.42, 'center': [3.03, 3.24], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'B_metal_N_E': {'name': 'B_metal_N_E', 'width': 0.42, 'center': [3.24, 3.03], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'B_metal_E_E': {'name': 'B_metal_E_E', 'width': 6.48, 'center': [3.24, 0.0], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'B_metal_W_E': {'name': 'B_metal_W_E', 'width': 6.48, 'center': [-2.82, 0.0], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'B_metal_S_E': {'name': 'B_metal_S_E', 'width': 0.42, 'center': [3.24, -3.03], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'B_metal_E_S': {'name': 'B_metal_E_S', 'width': 0.42, 'center': [3.03, -3.24], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'B_metal_N_S': {'name': 'B_metal_N_S', 'width': 6.48, 'center': [0.0, 2.82], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'B_metal_S_S': {'name': 'B_metal_S_S', 'width': 6.48, 'center': [0.0, -3.24], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'B_metal_W_S': {'name': 'B_metal_W_S', 'width': 0.42, 'center': [-3.03, -3.24], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'C_metal_S_W': {'name': 'C_metal_S_W', 'width': 0.42, 'center': [-3.98, -3.77], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'C_metal_E_W': {'name': 'C_metal_E_W', 'width': 7.96, 'center': [3.56, 0.0], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'C_metal_W_W': {'name': 'C_metal_W_W', 'width': 7.96, 'center': [-3.98, 0.0], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'C_metal_N_W': {'name': 'C_metal_N_W', 'width': 0.42, 'center': [-3.98, 3.77], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'C_metal_W_N': {'name': 'C_metal_W_N', 'width': 0.42, 'center': [-3.77, 3.98], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'C_metal_N_N': {'name': 'C_metal_N_N', 'width': 7.96, 'center': [0.0, 3.98], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'C_metal_S_N': {'name': 'C_metal_S_N', 'width': 7.96, 'center': [0.0, -3.56], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'C_metal_E_N': {'name': 'C_metal_E_N', 'width': 0.42, 'center': [3.77, 3.98], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'C_metal_N_E': {'name': 'C_metal_N_E', 'width': 0.42, 'center': [3.98, 3.77], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'C_metal_E_E': {'name': 'C_metal_E_E', 'width': 7.96, 'center': [3.98, 0.0], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'C_metal_W_E': {'name': 'C_metal_W_E', 'width': 7.96, 'center': [-3.56, 0.0], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'C_metal_S_E': {'name': 'C_metal_S_E', 'width': 0.42, 'center': [3.98, -3.77], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'C_metal_E_S': {'name': 'C_metal_E_S', 'width': 0.42, 'center': [3.77, -3.98], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'C_metal_N_S': {'name': 'C_metal_N_S', 'width': 7.96, 'center': [0.0, 3.56], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'C_metal_S_S': {'name': 'C_metal_S_S', 'width': 7.96, 'center': [0.0, -3.98], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'C_metal_W_S': {'name': 'C_metal_W_S', 'width': 0.42, 'center': [-3.77, -3.98], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'contacts_e_row0_col0_W': {'name': 'contacts_e_row0_col0_W', 'width': 0.22, 'center': [-2.36, -2.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row0_col1_W': {'name': 'contacts_e_row0_col1_W', 'width': 0.22, 'center': [-1.86, -2.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row0_col2_W': {'name': 'contacts_e_row0_col2_W', 'width': 0.22, 'center': [-1.36, -2.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row0_col3_W': {'name': 'contacts_e_row0_col3_W', 'width': 0.22, 'center': [-0.86, -2.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row0_col4_W': {'name': 'contacts_e_row0_col4_W', 'width': 0.22, 'center': [-0.36, -2.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row0_col5_W': {'name': 'contacts_e_row0_col5_W', 'width': 0.22, 'center': [0.14, -2.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row0_col6_W': {'name': 'contacts_e_row0_col6_W', 'width': 0.22, 'center': [0.64, -2.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row0_col7_W': {'name': 'contacts_e_row0_col7_W', 'width': 0.22, 'center': [1.14, -2.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row0_col8_W': {'name': 'contacts_e_row0_col8_W', 'width': 0.22, 'center': [1.64, -2.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row0_col9_W': {'name': 'contacts_e_row0_col9_W', 'width': 0.22, 'center': [2.14, -2.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row1_col0_W': {'name': 'contacts_e_row1_col0_W', 'width': 0.22, 'center': [-2.36, -1.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row1_col1_W': {'name': 'contacts_e_row1_col1_W', 'width': 0.22, 'center': [-1.86, -1.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row1_col2_W': {'name': 'contacts_e_row1_col2_W', 'width': 0.22, 'center': [-1.36, -1.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row1_col3_W': {'name': 'contacts_e_row1_col3_W', 'width': 0.22, 'center': [-0.86, -1.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row1_col4_W': {'name': 'contacts_e_row1_col4_W', 'width': 0.22, 'center': [-0.36, -1.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row1_col5_W': {'name': 'contacts_e_row1_col5_W', 'width': 0.22, 'center': [0.14, -1.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row1_col6_W': {'name': 'contacts_e_row1_col6_W', 'width': 0.22, 'center': [0.64, -1.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row1_col7_W': {'name': 'contacts_e_row1_col7_W', 'width': 0.22, 'center': [1.14, -1.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row1_col8_W': {'name': 'contacts_e_row1_col8_W', 'width': 0.22, 'center': [1.64, -1.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row1_col9_W': {'name': 'contacts_e_row1_col9_W', 'width': 0.22, 'center': [2.14, -1.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row2_col0_W': {'name': 'contacts_e_row2_col0_W', 'width': 0.22, 'center': [-2.36, -1.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row2_col1_W': {'name': 'contacts_e_row2_col1_W', 'width': 0.22, 'center': [-1.86, -1.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row2_col2_W': {'name': 'contacts_e_row2_col2_W', 'width': 0.22, 'center': [-1.36, -1.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row2_col3_W': {'name': 'contacts_e_row2_col3_W', 'width': 0.22, 'center': [-0.86, -1.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row2_col4_W': {'name': 'contacts_e_row2_col4_W', 'width': 0.22, 'center': [-0.36, -1.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row2_col5_W': {'name': 'contacts_e_row2_col5_W', 'width': 0.22, 'center': [0.14, -1.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row2_col6_W': {'name': 'contacts_e_row2_col6_W', 'width': 0.22, 'center': [0.64, -1.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row2_col7_W': {'name': 'contacts_e_row2_col7_W', 'width': 0.22, 'center': [1.14, -1.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row2_col8_W': {'name': 'contacts_e_row2_col8_W', 'width': 0.22, 'center': [1.64, -1.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row2_col9_W': {'name': 'contacts_e_row2_col9_W', 'width': 0.22, 'center': [2.14, -1.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row3_col0_W': {'name': 'contacts_e_row3_col0_W', 'width': 0.22, 'center': [-2.36, -0.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row3_col1_W': {'name': 'contacts_e_row3_col1_W', 'width': 0.22, 'center': [-1.86, -0.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row3_col2_W': {'name': 'contacts_e_row3_col2_W', 'width': 0.22, 'center': [-1.36, -0.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row3_col3_W': {'name': 'contacts_e_row3_col3_W', 'width': 0.22, 'center': [-0.86, -0.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row3_col4_W': {'name': 'contacts_e_row3_col4_W', 'width': 0.22, 'center': [-0.36, -0.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row3_col5_W': {'name': 'contacts_e_row3_col5_W', 'width': 0.22, 'center': [0.14, -0.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row3_col6_W': {'name': 'contacts_e_row3_col6_W', 'width': 0.22, 'center': [0.64, -0.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row3_col7_W': {'name': 'contacts_e_row3_col7_W', 'width': 0.22, 'center': [1.14, -0.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row3_col8_W': {'name': 'contacts_e_row3_col8_W', 'width': 0.22, 'center': [1.64, -0.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row3_col9_W': {'name': 'contacts_e_row3_col9_W', 'width': 0.22, 'center': [2.14, -0.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row4_col0_W': {'name': 'contacts_e_row4_col0_W', 'width': 0.22, 'center': [-2.36, -0.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row4_col1_W': {'name': 'contacts_e_row4_col1_W', 'width': 0.22, 'center': [-1.86, -0.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row4_col2_W': {'name': 'contacts_e_row4_col2_W', 'width': 0.22, 'center': [-1.36, -0.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row4_col3_W': {'name': 'contacts_e_row4_col3_W', 'width': 0.22, 'center': [-0.86, -0.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row4_col4_W': {'name': 'contacts_e_row4_col4_W', 'width': 0.22, 'center': [-0.36, -0.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row4_col5_W': {'name': 'contacts_e_row4_col5_W', 'width': 0.22, 'center': [0.14, -0.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row4_col6_W': {'name': 'contacts_e_row4_col6_W', 'width': 0.22, 'center': [0.64, -0.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row4_col7_W': {'name': 'contacts_e_row4_col7_W', 'width': 0.22, 'center': [1.14, -0.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row4_col8_W': {'name': 'contacts_e_row4_col8_W', 'width': 0.22, 'center': [1.64, -0.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row4_col9_W': {'name': 'contacts_e_row4_col9_W', 'width': 0.22, 'center': [2.14, -0.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row5_col0_W': {'name': 'contacts_e_row5_col0_W', 'width': 0.22, 'center': [-2.36, 0.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row5_col1_W': {'name': 'contacts_e_row5_col1_W', 'width': 0.22, 'center': [-1.86, 0.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row5_col2_W': {'name': 'contacts_e_row5_col2_W', 'width': 0.22, 'center': [-1.36, 0.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row5_col3_W': {'name': 'contacts_e_row5_col3_W', 'width': 0.22, 'center': [-0.86, 0.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row5_col4_W': {'name': 'contacts_e_row5_col4_W', 'width': 0.22, 'center': [-0.36, 0.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row5_col5_W': {'name': 'contacts_e_row5_col5_W', 'width': 0.22, 'center': [0.14, 0.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row5_col6_W': {'name': 'contacts_e_row5_col6_W', 'width': 0.22, 'center': [0.64, 0.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row5_col7_W': {'name': 'contacts_e_row5_col7_W', 'width': 0.22, 'center': [1.14, 0.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row5_col8_W': {'name': 'contacts_e_row5_col8_W', 'width': 0.22, 'center': [1.64, 0.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row5_col9_W': {'name': 'contacts_e_row5_col9_W', 'width': 0.22, 'center': [2.14, 0.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col0_W': {'name': 'contacts_e_row6_col0_W', 'width': 0.22, 'center': [-2.36, 0.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col1_W': {'name': 'contacts_e_row6_col1_W', 'width': 0.22, 'center': [-1.86, 0.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col2_W': {'name': 'contacts_e_row6_col2_W', 'width': 0.22, 'center': [-1.36, 0.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col3_W': {'name': 'contacts_e_row6_col3_W', 'width': 0.22, 'center': [-0.86, 0.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col4_W': {'name': 'contacts_e_row6_col4_W', 'width': 0.22, 'center': [-0.36, 0.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col5_W': {'name': 'contacts_e_row6_col5_W', 'width': 0.22, 'center': [0.14, 0.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col6_W': {'name': 'contacts_e_row6_col6_W', 'width': 0.22, 'center': [0.64, 0.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col7_W': {'name': 'contacts_e_row6_col7_W', 'width': 0.22, 'center': [1.14, 0.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col8_W': {'name': 'contacts_e_row6_col8_W', 'width': 0.22, 'center': [1.64, 0.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col9_W': {'name': 'contacts_e_row6_col9_W', 'width': 0.22, 'center': [2.14, 0.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col0_W': {'name': 'contacts_e_row7_col0_W', 'width': 0.22, 'center': [-2.36, 1.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col1_W': {'name': 'contacts_e_row7_col1_W', 'width': 0.22, 'center': [-1.86, 1.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col2_W': {'name': 'contacts_e_row7_col2_W', 'width': 0.22, 'center': [-1.36, 1.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col3_W': {'name': 'contacts_e_row7_col3_W', 'width': 0.22, 'center': [-0.86, 1.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col4_W': {'name': 'contacts_e_row7_col4_W', 'width': 0.22, 'center': [-0.36, 1.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col5_W': {'name': 'contacts_e_row7_col5_W', 'width': 0.22, 'center': [0.14, 1.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col6_W': {'name': 'contacts_e_row7_col6_W', 'width': 0.22, 'center': [0.64, 1.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col7_W': {'name': 'contacts_e_row7_col7_W', 'width': 0.22, 'center': [1.14, 1.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col8_W': {'name': 'contacts_e_row7_col8_W', 'width': 0.22, 'center': [1.64, 1.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col9_W': {'name': 'contacts_e_row7_col9_W', 'width': 0.22, 'center': [2.14, 1.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col0_W': {'name': 'contacts_e_row8_col0_W', 'width': 0.22, 'center': [-2.36, 1.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col1_W': {'name': 'contacts_e_row8_col1_W', 'width': 0.22, 'center': [-1.86, 1.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col2_W': {'name': 'contacts_e_row8_col2_W', 'width': 0.22, 'center': [-1.36, 1.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col3_W': {'name': 'contacts_e_row8_col3_W', 'width': 0.22, 'center': [-0.86, 1.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col4_W': {'name': 'contacts_e_row8_col4_W', 'width': 0.22, 'center': [-0.36, 1.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col5_W': {'name': 'contacts_e_row8_col5_W', 'width': 0.22, 'center': [0.14, 1.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col6_W': {'name': 'contacts_e_row8_col6_W', 'width': 0.22, 'center': [0.64, 1.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col7_W': {'name': 'contacts_e_row8_col7_W', 'width': 0.22, 'center': [1.14, 1.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col8_W': {'name': 'contacts_e_row8_col8_W', 'width': 0.22, 'center': [1.64, 1.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col9_W': {'name': 'contacts_e_row8_col9_W', 'width': 0.22, 'center': [2.14, 1.75], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col0_W': {'name': 'contacts_e_row9_col0_W', 'width': 0.22, 'center': [-2.36, 2.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col1_W': {'name': 'contacts_e_row9_col1_W', 'width': 0.22, 'center': [-1.86, 2.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col2_W': {'name': 'contacts_e_row9_col2_W', 'width': 0.22, 'center': [-1.36, 2.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col3_W': {'name': 'contacts_e_row9_col3_W', 'width': 0.22, 'center': [-0.86, 2.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col4_W': {'name': 'contacts_e_row9_col4_W', 'width': 0.22, 'center': [-0.36, 2.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col5_W': {'name': 'contacts_e_row9_col5_W', 'width': 0.22, 'center': [0.14, 2.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col6_W': {'name': 'contacts_e_row9_col6_W', 'width': 0.22, 'center': [0.64, 2.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col7_W': {'name': 'contacts_e_row9_col7_W', 'width': 0.22, 'center': [1.14, 2.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col8_W': {'name': 'contacts_e_row9_col8_W', 'width': 0.22, 'center': [1.64, 2.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col9_W': {'name': 'contacts_e_row9_col9_W', 'width': 0.22, 'center': [2.14, 2.25], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row0_col0_N': {'name': 'contacts_e_row0_col0_N', 'width': 0.22, 'center': [-2.25, -2.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row1_col0_N': {'name': 'contacts_e_row1_col0_N', 'width': 0.22, 'center': [-2.25, -1.64], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row2_col0_N': {'name': 'contacts_e_row2_col0_N', 'width': 0.22, 'center': [-2.25, -1.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row3_col0_N': {'name': 'contacts_e_row3_col0_N', 'width': 0.22, 'center': [-2.25, -0.64], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row4_col0_N': {'name': 'contacts_e_row4_col0_N', 'width': 0.22, 'center': [-2.25, -0.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row5_col0_N': {'name': 'contacts_e_row5_col0_N', 'width': 0.22, 'center': [-2.25, 0.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col0_N': {'name': 'contacts_e_row6_col0_N', 'width': 0.22, 'center': [-2.25, 0.86], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col0_N': {'name': 'contacts_e_row7_col0_N', 'width': 0.22, 'center': [-2.25, 1.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col0_N': {'name': 'contacts_e_row8_col0_N', 'width': 0.22, 'center': [-2.25, 1.86], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col0_N': {'name': 'contacts_e_row9_col0_N', 'width': 0.22, 'center': [-2.25, 2.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row0_col1_N': {'name': 'contacts_e_row0_col1_N', 'width': 0.22, 'center': [-1.75, -2.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row1_col1_N': {'name': 'contacts_e_row1_col1_N', 'width': 0.22, 'center': [-1.75, -1.64], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row2_col1_N': {'name': 'contacts_e_row2_col1_N', 'width': 0.22, 'center': [-1.75, -1.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row3_col1_N': {'name': 'contacts_e_row3_col1_N', 'width': 0.22, 'center': [-1.75, -0.64], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row4_col1_N': {'name': 'contacts_e_row4_col1_N', 'width': 0.22, 'center': [-1.75, -0.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row5_col1_N': {'name': 'contacts_e_row5_col1_N', 'width': 0.22, 'center': [-1.75, 0.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col1_N': {'name': 'contacts_e_row6_col1_N', 'width': 0.22, 'center': [-1.75, 0.86], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col1_N': {'name': 'contacts_e_row7_col1_N', 'width': 0.22, 'center': [-1.75, 1.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col1_N': {'name': 'contacts_e_row8_col1_N', 'width': 0.22, 'center': [-1.75, 1.86], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col1_N': {'name': 'contacts_e_row9_col1_N', 'width': 0.22, 'center': [-1.75, 2.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row0_col2_N': {'name': 'contacts_e_row0_col2_N', 'width': 0.22, 'center': [-1.25, -2.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row1_col2_N': {'name': 'contacts_e_row1_col2_N', 'width': 0.22, 'center': [-1.25, -1.64], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row2_col2_N': {'name': 'contacts_e_row2_col2_N', 'width': 0.22, 'center': [-1.25, -1.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row3_col2_N': {'name': 'contacts_e_row3_col2_N', 'width': 0.22, 'center': [-1.25, -0.64], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row4_col2_N': {'name': 'contacts_e_row4_col2_N', 'width': 0.22, 'center': [-1.25, -0.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row5_col2_N': {'name': 'contacts_e_row5_col2_N', 'width': 0.22, 'center': [-1.25, 0.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col2_N': {'name': 'contacts_e_row6_col2_N', 'width': 0.22, 'center': [-1.25, 0.86], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col2_N': {'name': 'contacts_e_row7_col2_N', 'width': 0.22, 'center': [-1.25, 1.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col2_N': {'name': 'contacts_e_row8_col2_N', 'width': 0.22, 'center': [-1.25, 1.86], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col2_N': {'name': 'contacts_e_row9_col2_N', 'width': 0.22, 'center': [-1.25, 2.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row0_col3_N': {'name': 'contacts_e_row0_col3_N', 'width': 0.22, 'center': [-0.75, -2.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row1_col3_N': {'name': 'contacts_e_row1_col3_N', 'width': 0.22, 'center': [-0.75, -1.64], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row2_col3_N': {'name': 'contacts_e_row2_col3_N', 'width': 0.22, 'center': [-0.75, -1.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row3_col3_N': {'name': 'contacts_e_row3_col3_N', 'width': 0.22, 'center': [-0.75, -0.64], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row4_col3_N': {'name': 'contacts_e_row4_col3_N', 'width': 0.22, 'center': [-0.75, -0.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row5_col3_N': {'name': 'contacts_e_row5_col3_N', 'width': 0.22, 'center': [-0.75, 0.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col3_N': {'name': 'contacts_e_row6_col3_N', 'width': 0.22, 'center': [-0.75, 0.86], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col3_N': {'name': 'contacts_e_row7_col3_N', 'width': 0.22, 'center': [-0.75, 1.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col3_N': {'name': 'contacts_e_row8_col3_N', 'width': 0.22, 'center': [-0.75, 1.86], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col3_N': {'name': 'contacts_e_row9_col3_N', 'width': 0.22, 'center': [-0.75, 2.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row0_col4_N': {'name': 'contacts_e_row0_col4_N', 'width': 0.22, 'center': [-0.25, -2.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row1_col4_N': {'name': 'contacts_e_row1_col4_N', 'width': 0.22, 'center': [-0.25, -1.64], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row2_col4_N': {'name': 'contacts_e_row2_col4_N', 'width': 0.22, 'center': [-0.25, -1.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row3_col4_N': {'name': 'contacts_e_row3_col4_N', 'width': 0.22, 'center': [-0.25, -0.64], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row4_col4_N': {'name': 'contacts_e_row4_col4_N', 'width': 0.22, 'center': [-0.25, -0.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row5_col4_N': {'name': 'contacts_e_row5_col4_N', 'width': 0.22, 'center': [-0.25, 0.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col4_N': {'name': 'contacts_e_row6_col4_N', 'width': 0.22, 'center': [-0.25, 0.86], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col4_N': {'name': 'contacts_e_row7_col4_N', 'width': 0.22, 'center': [-0.25, 1.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col4_N': {'name': 'contacts_e_row8_col4_N', 'width': 0.22, 'center': [-0.25, 1.86], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col4_N': {'name': 'contacts_e_row9_col4_N', 'width': 0.22, 'center': [-0.25, 2.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row0_col5_N': {'name': 'contacts_e_row0_col5_N', 'width': 0.22, 'center': [0.25, -2.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row1_col5_N': {'name': 'contacts_e_row1_col5_N', 'width': 0.22, 'center': [0.25, -1.64], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row2_col5_N': {'name': 'contacts_e_row2_col5_N', 'width': 0.22, 'center': [0.25, -1.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row3_col5_N': {'name': 'contacts_e_row3_col5_N', 'width': 0.22, 'center': [0.25, -0.64], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row4_col5_N': {'name': 'contacts_e_row4_col5_N', 'width': 0.22, 'center': [0.25, -0.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row5_col5_N': {'name': 'contacts_e_row5_col5_N', 'width': 0.22, 'center': [0.25, 0.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col5_N': {'name': 'contacts_e_row6_col5_N', 'width': 0.22, 'center': [0.25, 0.86], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col5_N': {'name': 'contacts_e_row7_col5_N', 'width': 0.22, 'center': [0.25, 1.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col5_N': {'name': 'contacts_e_row8_col5_N', 'width': 0.22, 'center': [0.25, 1.86], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col5_N': {'name': 'contacts_e_row9_col5_N', 'width': 0.22, 'center': [0.25, 2.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row0_col6_N': {'name': 'contacts_e_row0_col6_N', 'width': 0.22, 'center': [0.75, -2.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row1_col6_N': {'name': 'contacts_e_row1_col6_N', 'width': 0.22, 'center': [0.75, -1.64], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row2_col6_N': {'name': 'contacts_e_row2_col6_N', 'width': 0.22, 'center': [0.75, -1.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row3_col6_N': {'name': 'contacts_e_row3_col6_N', 'width': 0.22, 'center': [0.75, -0.64], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row4_col6_N': {'name': 'contacts_e_row4_col6_N', 'width': 0.22, 'center': [0.75, -0.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row5_col6_N': {'name': 'contacts_e_row5_col6_N', 'width': 0.22, 'center': [0.75, 0.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col6_N': {'name': 'contacts_e_row6_col6_N', 'width': 0.22, 'center': [0.75, 0.86], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col6_N': {'name': 'contacts_e_row7_col6_N', 'width': 0.22, 'center': [0.75, 1.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col6_N': {'name': 'contacts_e_row8_col6_N', 'width': 0.22, 'center': [0.75, 1.86], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col6_N': {'name': 'contacts_e_row9_col6_N', 'width': 0.22, 'center': [0.75, 2.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row0_col7_N': {'name': 'contacts_e_row0_col7_N', 'width': 0.22, 'center': [1.25, -2.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row1_col7_N': {'name': 'contacts_e_row1_col7_N', 'width': 0.22, 'center': [1.25, -1.64], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row2_col7_N': {'name': 'contacts_e_row2_col7_N', 'width': 0.22, 'center': [1.25, -1.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row3_col7_N': {'name': 'contacts_e_row3_col7_N', 'width': 0.22, 'center': [1.25, -0.64], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row4_col7_N': {'name': 'contacts_e_row4_col7_N', 'width': 0.22, 'center': [1.25, -0.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row5_col7_N': {'name': 'contacts_e_row5_col7_N', 'width': 0.22, 'center': [1.25, 0.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col7_N': {'name': 'contacts_e_row6_col7_N', 'width': 0.22, 'center': [1.25, 0.86], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col7_N': {'name': 'contacts_e_row7_col7_N', 'width': 0.22, 'center': [1.25, 1.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col7_N': {'name': 'contacts_e_row8_col7_N', 'width': 0.22, 'center': [1.25, 1.86], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col7_N': {'name': 'contacts_e_row9_col7_N', 'width': 0.22, 'center': [1.25, 2.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row0_col8_N': {'name': 'contacts_e_row0_col8_N', 'width': 0.22, 'center': [1.75, -2.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row1_col8_N': {'name': 'contacts_e_row1_col8_N', 'width': 0.22, 'center': [1.75, -1.64], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row2_col8_N': {'name': 'contacts_e_row2_col8_N', 'width': 0.22, 'center': [1.75, -1.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row3_col8_N': {'name': 'contacts_e_row3_col8_N', 'width': 0.22, 'center': [1.75, -0.64], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row4_col8_N': {'name': 'contacts_e_row4_col8_N', 'width': 0.22, 'center': [1.75, -0.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row5_col8_N': {'name': 'contacts_e_row5_col8_N', 'width': 0.22, 'center': [1.75, 0.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col8_N': {'name': 'contacts_e_row6_col8_N', 'width': 0.22, 'center': [1.75, 0.86], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col8_N': {'name': 'contacts_e_row7_col8_N', 'width': 0.22, 'center': [1.75, 1.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col8_N': {'name': 'contacts_e_row8_col8_N', 'width': 0.22, 'center': [1.75, 1.86], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col8_N': {'name': 'contacts_e_row9_col8_N', 'width': 0.22, 'center': [1.75, 2.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row0_col9_N': {'name': 'contacts_e_row0_col9_N', 'width': 0.22, 'center': [2.25, -2.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row1_col9_N': {'name': 'contacts_e_row1_col9_N', 'width': 0.22, 'center': [2.25, -1.64], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row2_col9_N': {'name': 'contacts_e_row2_col9_N', 'width': 0.22, 'center': [2.25, -1.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row3_col9_N': {'name': 'contacts_e_row3_col9_N', 'width': 0.22, 'center': [2.25, -0.64], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row4_col9_N': {'name': 'contacts_e_row4_col9_N', 'width': 0.22, 'center': [2.25, -0.14], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row5_col9_N': {'name': 'contacts_e_row5_col9_N', 'width': 0.22, 'center': [2.25, 0.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col9_N': {'name': 'contacts_e_row6_col9_N', 'width': 0.22, 'center': [2.25, 0.86], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col9_N': {'name': 'contacts_e_row7_col9_N', 'width': 0.22, 'center': [2.25, 1.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col9_N': {'name': 'contacts_e_row8_col9_N', 'width': 0.22, 'center': [2.25, 1.86], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col9_N': {'name': 'contacts_e_row9_col9_N', 'width': 0.22, 'center': [2.25, 2.36], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col0_E': {'name': 'contacts_e_row9_col0_E', 'width': 0.22, 'center': [-2.14, 2.25], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col1_E': {'name': 'contacts_e_row9_col1_E', 'width': 0.22, 'center': [-1.64, 2.25], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col2_E': {'name': 'contacts_e_row9_col2_E', 'width': 0.22, 'center': [-1.14, 2.25], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col3_E': {'name': 'contacts_e_row9_col3_E', 'width': 0.22, 'center': [-0.64, 2.25], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col4_E': {'name': 'contacts_e_row9_col4_E', 'width': 0.22, 'center': [-0.14, 2.25], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col5_E': {'name': 'contacts_e_row9_col5_E', 'width': 0.22, 'center': [0.36, 2.25], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col6_E': {'name': 'contacts_e_row9_col6_E', 'width': 0.22, 'center': [0.86, 2.25], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col7_E': {'name': 'contacts_e_row9_col7_E', 'width': 0.22, 'center': [1.36, 2.25], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col8_E': {'name': 'contacts_e_row9_col8_E', 'width': 0.22, 'center': [1.86, 2.25], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row9_col9_E': {'name': 'contacts_e_row9_col9_E', 'width': 0.22, 'center': [2.36, 2.25], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col0_E': {'name': 'contacts_e_row8_col0_E', 'width': 0.22, 'center': [-2.14, 1.75], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col1_E': {'name': 'contacts_e_row8_col1_E', 'width': 0.22, 'center': [-1.64, 1.75], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col2_E': {'name': 'contacts_e_row8_col2_E', 'width': 0.22, 'center': [-1.14, 1.75], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col3_E': {'name': 'contacts_e_row8_col3_E', 'width': 0.22, 'center': [-0.64, 1.75], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col4_E': {'name': 'contacts_e_row8_col4_E', 'width': 0.22, 'center': [-0.14, 1.75], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col5_E': {'name': 'contacts_e_row8_col5_E', 'width': 0.22, 'center': [0.36, 1.75], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col6_E': {'name': 'contacts_e_row8_col6_E', 'width': 0.22, 'center': [0.86, 1.75], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col7_E': {'name': 'contacts_e_row8_col7_E', 'width': 0.22, 'center': [1.36, 1.75], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col8_E': {'name': 'contacts_e_row8_col8_E', 'width': 0.22, 'center': [1.86, 1.75], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row8_col9_E': {'name': 'contacts_e_row8_col9_E', 'width': 0.22, 'center': [2.36, 1.75], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col0_E': {'name': 'contacts_e_row7_col0_E', 'width': 0.22, 'center': [-2.14, 1.25], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col1_E': {'name': 'contacts_e_row7_col1_E', 'width': 0.22, 'center': [-1.64, 1.25], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col2_E': {'name': 'contacts_e_row7_col2_E', 'width': 0.22, 'center': [-1.14, 1.25], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col3_E': {'name': 'contacts_e_row7_col3_E', 'width': 0.22, 'center': [-0.64, 1.25], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col4_E': {'name': 'contacts_e_row7_col4_E', 'width': 0.22, 'center': [-0.14, 1.25], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col5_E': {'name': 'contacts_e_row7_col5_E', 'width': 0.22, 'center': [0.36, 1.25], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col6_E': {'name': 'contacts_e_row7_col6_E', 'width': 0.22, 'center': [0.86, 1.25], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col7_E': {'name': 'contacts_e_row7_col7_E', 'width': 0.22, 'center': [1.36, 1.25], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col8_E': {'name': 'contacts_e_row7_col8_E', 'width': 0.22, 'center': [1.86, 1.25], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row7_col9_E': {'name': 'contacts_e_row7_col9_E', 'width': 0.22, 'center': [2.36, 1.25], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col0_E': {'name': 'contacts_e_row6_col0_E', 'width': 0.22, 'center': [-2.14, 0.75], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col1_E': {'name': 'contacts_e_row6_col1_E', 'width': 0.22, 'center': [-1.64, 0.75], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col2_E': {'name': 'contacts_e_row6_col2_E', 'width': 0.22, 'center': [-1.14, 0.75], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col3_E': {'name': 'contacts_e_row6_col3_E', 'width': 0.22, 'center': [-0.64, 0.75], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col4_E': {'name': 'contacts_e_row6_col4_E', 'width': 0.22, 'center': [-0.14, 0.75], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_e_row6_col5_E': {'name': 'contacts_e_row6_col5_E', 'width': 0.22, 'center': [0.36, 0.75], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
# ...
#  'contacts_c_contacts_W_row3_col0_E': {'name': 'contacts_c_contacts_W_row3_col0_E', 'width': 0.22, 'center': [-3.66, -2.35], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_E_row2_col0_E': {'name': 'contacts_c_contacts_E_row2_col0_E', 'width': 0.22, 'center': [3.88, -2.82], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_W_row2_col0_E': {'name': 'contacts_c_contacts_W_row2_col0_E', 'width': 0.22, 'center': [-3.66, -2.82], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_E_row1_col0_E': {'name': 'contacts_c_contacts_E_row1_col0_E', 'width': 0.22, 'center': [3.88, -3.29], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_W_row1_col0_E': {'name': 'contacts_c_contacts_W_row1_col0_E', 'width': 0.22, 'center': [-3.66, -3.29], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_E_row0_col0_E': {'name': 'contacts_c_contacts_E_row0_col0_E', 'width': 0.22, 'center': [3.88, -3.76], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_W_row0_col0_E': {'name': 'contacts_c_contacts_W_row0_col0_E', 'width': 0.22, 'center': [-3.66, -3.76], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col0_E': {'name': 'contacts_c_contacts_S_row0_col0_E', 'width': 0.22, 'center': [-2.945, -3.77], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col1_E': {'name': 'contacts_c_contacts_S_row0_col1_E', 'width': 0.22, 'center': [-2.475, -3.77], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col2_E': {'name': 'contacts_c_contacts_S_row0_col2_E', 'width': 0.22, 'center': [-2.005, -3.77], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col3_E': {'name': 'contacts_c_contacts_S_row0_col3_E', 'width': 0.22, 'center': [-1.535, -3.77], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col4_E': {'name': 'contacts_c_contacts_S_row0_col4_E', 'width': 0.22, 'center': [-1.065, -3.77], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col5_E': {'name': 'contacts_c_contacts_S_row0_col5_E', 'width': 0.22, 'center': [-0.595, -3.77], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col6_E': {'name': 'contacts_c_contacts_S_row0_col6_E', 'width': 0.22, 'center': [-0.125, -3.77], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col7_E': {'name': 'contacts_c_contacts_S_row0_col7_E', 'width': 0.22, 'center': [0.345, -3.77], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col8_E': {'name': 'contacts_c_contacts_S_row0_col8_E', 'width': 0.22, 'center': [0.815, -3.77], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col9_E': {'name': 'contacts_c_contacts_S_row0_col9_E', 'width': 0.22, 'center': [1.285, -3.77], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col10_E': {'name': 'contacts_c_contacts_S_row0_col10_E', 'width': 0.22, 'center': [1.755, -3.77], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col11_E': {'name': 'contacts_c_contacts_S_row0_col11_E', 'width': 0.22, 'center': [2.225, -3.77], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col12_E': {'name': 'contacts_c_contacts_S_row0_col12_E', 'width': 0.22, 'center': [2.695, -3.77], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col13_E': {'name': 'contacts_c_contacts_S_row0_col13_E', 'width': 0.22, 'center': [3.165, -3.77], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_E_row0_col0_S': {'name': 'contacts_c_contacts_E_row0_col0_S', 'width': 0.22, 'center': [3.77, -3.87], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_E_row1_col0_S': {'name': 'contacts_c_contacts_E_row1_col0_S', 'width': 0.22, 'center': [3.77, -3.4], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_E_row2_col0_S': {'name': 'contacts_c_contacts_E_row2_col0_S', 'width': 0.22, 'center': [3.77, -2.93], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_E_row3_col0_S': {'name': 'contacts_c_contacts_E_row3_col0_S', 'width': 0.22, 'center': [3.77, -2.46], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_E_row4_col0_S': {'name': 'contacts_c_contacts_E_row4_col0_S', 'width': 0.22, 'center': [3.77, -1.99], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_E_row5_col0_S': {'name': 'contacts_c_contacts_E_row5_col0_S', 'width': 0.22, 'center': [3.77, -1.52], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_E_row6_col0_S': {'name': 'contacts_c_contacts_E_row6_col0_S', 'width': 0.22, 'center': [3.77, -1.05], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_E_row7_col0_S': {'name': 'contacts_c_contacts_E_row7_col0_S', 'width': 0.22, 'center': [3.77, -0.58], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_E_row8_col0_S': {'name': 'contacts_c_contacts_E_row8_col0_S', 'width': 0.22, 'center': [3.77, -0.11], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_E_row9_col0_S': {'name': 'contacts_c_contacts_E_row9_col0_S', 'width': 0.22, 'center': [3.77, 0.36], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_E_row10_col0_S': {'name': 'contacts_c_contacts_E_row10_col0_S', 'width': 0.22, 'center': [3.77, 0.83], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_E_row11_col0_S': {'name': 'contacts_c_contacts_E_row11_col0_S', 'width': 0.22, 'center': [3.77, 1.3], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_E_row12_col0_S': {'name': 'contacts_c_contacts_E_row12_col0_S', 'width': 0.22, 'center': [3.77, 1.77], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_E_row13_col0_S': {'name': 'contacts_c_contacts_E_row13_col0_S', 'width': 0.22, 'center': [3.77, 2.24], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_E_row14_col0_S': {'name': 'contacts_c_contacts_E_row14_col0_S', 'width': 0.22, 'center': [3.77, 2.71], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_E_row15_col0_S': {'name': 'contacts_c_contacts_E_row15_col0_S', 'width': 0.22, 'center': [3.77, 3.18], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_E_row16_col0_S': {'name': 'contacts_c_contacts_E_row16_col0_S', 'width': 0.22, 'center': [3.77, 3.65], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_N_row0_col13_S': {'name': 'contacts_c_contacts_N_row0_col13_S', 'width': 0.22, 'center': [3.055, 3.66], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col13_S': {'name': 'contacts_c_contacts_S_row0_col13_S', 'width': 0.22, 'center': [3.055, -3.88], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_N_row0_col12_S': {'name': 'contacts_c_contacts_N_row0_col12_S', 'width': 0.22, 'center': [2.585, 3.66], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col12_S': {'name': 'contacts_c_contacts_S_row0_col12_S', 'width': 0.22, 'center': [2.585, -3.88], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_N_row0_col11_S': {'name': 'contacts_c_contacts_N_row0_col11_S', 'width': 0.22, 'center': [2.115, 3.66], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col11_S': {'name': 'contacts_c_contacts_S_row0_col11_S', 'width': 0.22, 'center': [2.115, -3.88], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_N_row0_col10_S': {'name': 'contacts_c_contacts_N_row0_col10_S', 'width': 0.22, 'center': [1.645, 3.66], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col10_S': {'name': 'contacts_c_contacts_S_row0_col10_S', 'width': 0.22, 'center': [1.645, -3.88], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_N_row0_col9_S': {'name': 'contacts_c_contacts_N_row0_col9_S', 'width': 0.22, 'center': [1.175, 3.66], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col9_S': {'name': 'contacts_c_contacts_S_row0_col9_S', 'width': 0.22, 'center': [1.175, -3.88], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_N_row0_col8_S': {'name': 'contacts_c_contacts_N_row0_col8_S', 'width': 0.22, 'center': [0.705, 3.66], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col8_S': {'name': 'contacts_c_contacts_S_row0_col8_S', 'width': 0.22, 'center': [0.705, -3.88], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_N_row0_col7_S': {'name': 'contacts_c_contacts_N_row0_col7_S', 'width': 0.22, 'center': [0.235, 3.66], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col7_S': {'name': 'contacts_c_contacts_S_row0_col7_S', 'width': 0.22, 'center': [0.235, -3.88], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_N_row0_col6_S': {'name': 'contacts_c_contacts_N_row0_col6_S', 'width': 0.22, 'center': [-0.235, 3.66], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col6_S': {'name': 'contacts_c_contacts_S_row0_col6_S', 'width': 0.22, 'center': [-0.235, -3.88], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_N_row0_col5_S': {'name': 'contacts_c_contacts_N_row0_col5_S', 'width': 0.22, 'center': [-0.705, 3.66], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col5_S': {'name': 'contacts_c_contacts_S_row0_col5_S', 'width': 0.22, 'center': [-0.705, -3.88], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_N_row0_col4_S': {'name': 'contacts_c_contacts_N_row0_col4_S', 'width': 0.22, 'center': [-1.175, 3.66], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col4_S': {'name': 'contacts_c_contacts_S_row0_col4_S', 'width': 0.22, 'center': [-1.175, -3.88], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_N_row0_col3_S': {'name': 'contacts_c_contacts_N_row0_col3_S', 'width': 0.22, 'center': [-1.645, 3.66], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col3_S': {'name': 'contacts_c_contacts_S_row0_col3_S', 'width': 0.22, 'center': [-1.645, -3.88], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_N_row0_col2_S': {'name': 'contacts_c_contacts_N_row0_col2_S', 'width': 0.22, 'center': [-2.115, 3.66], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col2_S': {'name': 'contacts_c_contacts_S_row0_col2_S', 'width': 0.22, 'center': [-2.115, -3.88], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_N_row0_col1_S': {'name': 'contacts_c_contacts_N_row0_col1_S', 'width': 0.22, 'center': [-2.585, 3.66], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col1_S': {'name': 'contacts_c_contacts_S_row0_col1_S', 'width': 0.22, 'center': [-2.585, -3.88], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_N_row0_col0_S': {'name': 'contacts_c_contacts_N_row0_col0_S', 'width': 0.22, 'center': [-3.055, 3.66], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_S_row0_col0_S': {'name': 'contacts_c_contacts_S_row0_col0_S', 'width': 0.22, 'center': [-3.055, -3.88], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_W_row0_col0_S': {'name': 'contacts_c_contacts_W_row0_col0_S', 'width': 0.22, 'center': [-3.77, -3.87], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_W_row1_col0_S': {'name': 'contacts_c_contacts_W_row1_col0_S', 'width': 0.22, 'center': [-3.77, -3.4], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_W_row2_col0_S': {'name': 'contacts_c_contacts_W_row2_col0_S', 'width': 0.22, 'center': [-3.77, -2.93], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_W_row3_col0_S': {'name': 'contacts_c_contacts_W_row3_col0_S', 'width': 0.22, 'center': [-3.77, -2.46], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_W_row4_col0_S': {'name': 'contacts_c_contacts_W_row4_col0_S', 'width': 0.22, 'center': [-3.77, -1.99], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_W_row5_col0_S': {'name': 'contacts_c_contacts_W_row5_col0_S', 'width': 0.22, 'center': [-3.77, -1.52], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_W_row6_col0_S': {'name': 'contacts_c_contacts_W_row6_col0_S', 'width': 0.22, 'center': [-3.77, -1.05], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_W_row7_col0_S': {'name': 'contacts_c_contacts_W_row7_col0_S', 'width': 0.22, 'center': [-3.77, -0.58], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_W_row8_col0_S': {'name': 'contacts_c_contacts_W_row8_col0_S', 'width': 0.22, 'center': [-3.77, -0.11], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_W_row9_col0_S': {'name': 'contacts_c_contacts_W_row9_col0_S', 'width': 0.22, 'center': [-3.77, 0.36], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_W_row10_col0_S': {'name': 'contacts_c_contacts_W_row10_col0_S', 'width': 0.22, 'center': [-3.77, 0.83], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_W_row11_col0_S': {'name': 'contacts_c_contacts_W_row11_col0_S', 'width': 0.22, 'center': [-3.77, 1.3], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_W_row12_col0_S': {'name': 'contacts_c_contacts_W_row12_col0_S', 'width': 0.22, 'center': [-3.77, 1.77], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_W_row13_col0_S': {'name': 'contacts_c_contacts_W_row13_col0_S', 'width': 0.22, 'center': [-3.77, 2.24], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_W_row14_col0_S': {'name': 'contacts_c_contacts_W_row14_col0_S', 'width': 0.22, 'center': [-3.77, 2.71], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_W_row15_col0_S': {'name': 'contacts_c_contacts_W_row15_col0_S', 'width': 0.22, 'center': [-3.77, 3.18], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'contacts_c_contacts_W_row16_col0_S': {'name': 'contacts_c_contacts_W_row16_col0_S', 'width': 0.22, 'center': [-3.77, 3.65], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'}}

# %%
from glayout.primitives.bjt import multiplier, __mult_array_macro

# %%
bjt=__mult_array_macro(pdk=pdk,active_area=(5,5),bjt_type="pnp",bc_rmult=2,multipliers=5)

# %%
bjt.show()
# Out:
# /headless/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/show.py:40: UserWarning: Unnamed cells, 1 in 'Unnamed_6db8cc0b$1'
#   gdspath = component.write_gds(
# 2025-09-02 07:07:49.730 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.3.3", "klayout_version": "0.30.2", "type": "open", "file": "/tmp/gdsfactory/Unnamed_6db8cc0b$1.gds"}

# %%
bjt.center
# Out:
# array([0., 0.])

# %%
bjt.pprint_ports()
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ name                                         ┃ width ┃ center             ┃ orientation ┃ layer    ┃ port_type  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ multiplier_0_C_metal_S_W                     │ 0.42  │ [-3.98, -21.265]   │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [-3.165, -21.265]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [-2.695, -21.265]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [-2.225, -21.265]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [-1.755, -21.265]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [-1.285, -21.265]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [-0.815, -21.265]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [-0.345, -21.265]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [0.125, -21.265]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [0.595, -21.265]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [1.065, -21.265]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [1.535, -21.265]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [2.005, -21.265]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [2.475, -21.265]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [2.945, -21.265]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_C_metal_S_W             │ 0.42  │ [-12.66, -21.265]  │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-11.845, -21.265] │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-11.375, -21.265] │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-10.905, -21.265] │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-10.435, -21.265] │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-9.965, -21.265]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-9.495, -21.265]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-9.025, -21.265]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-8.555, -21.265]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-8.085, -21.265]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-7.615, -21.265]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-7.145, -21.265]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-6.675, -21.265]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-6.205, -21.265]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-5.735, -21.265]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_C_metal_S_W             │ 0.42  │ [4.7, -21.265]     │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [5.515, -21.265]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [5.985, -21.265]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [6.455, -21.265]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [6.925, -21.265]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [7.395, -21.265]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [7.865, -21.265]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [8.335, -21.265]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [8.805, -21.265]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [9.275, -21.265]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [9.745, -21.265]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [10.215, -21.265]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [10.685, -21.265]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [11.155, -21.265]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [11.625, -21.265]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_E_row0_col… │ 0.22  │ [3.66, -21.255]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_W_row0_col… │ 0.22  │ [-3.88, -21.255]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_E_… │ 0.22  │ [-5.02, -21.255]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.56, -21.255]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_E_… │ 0.22  │ [12.34, -21.255]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_W_… │ 0.22  │ [4.8, -21.255]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_collector_W                     │ 1.0   │ [-4.02, -21.225]   │ 180.0       │ [36, 0]  │ electrical │
# │ collector_W                                  │ 1.0   │ [-4.02, -21.225]   │ 180.0       │ [36, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_E_row1_col… │ 0.22  │ [3.66, -20.785]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_W_row1_col… │ 0.22  │ [-3.88, -20.785]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_E_… │ 0.22  │ [-5.02, -20.785]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.56, -20.785]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_E_… │ 0.22  │ [12.34, -20.785]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_W_… │ 0.22  │ [4.8, -20.785]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_B_metal_S_W                     │ 0.42  │ [-3.24, -20.525]   │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_S_row0_col… │ 0.22  │ [-2.46, -20.525]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_S_row0_col… │ 0.22  │ [-1.99, -20.525]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_S_row0_col… │ 0.22  │ [-1.52, -20.525]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_S_row0_col… │ 0.22  │ [-1.05, -20.525]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_S_row0_col… │ 0.22  │ [-0.58, -20.525]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_S_row0_col… │ 0.22  │ [-0.11, -20.525]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_S_row0_col… │ 0.22  │ [0.36, -20.525]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_S_row0_col… │ 0.22  │ [0.83, -20.525]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_S_row0_col… │ 0.22  │ [1.3, -20.525]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_S_row0_col… │ 0.22  │ [1.77, -20.525]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_S_row0_col… │ 0.22  │ [2.24, -20.525]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_B_metal_S_W             │ 0.42  │ [-11.92, -20.525]  │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-11.14, -20.525]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-10.67, -20.525]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-10.2, -20.525]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-9.73, -20.525]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-9.26, -20.525]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-8.79, -20.525]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-8.32, -20.525]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-7.85, -20.525]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-7.38, -20.525]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-6.91, -20.525]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-6.44, -20.525]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_B_metal_S_W             │ 0.42  │ [5.44, -20.525]    │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_S_… │ 0.22  │ [6.22, -20.525]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_S_… │ 0.22  │ [6.69, -20.525]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_S_… │ 0.22  │ [7.16, -20.525]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_S_… │ 0.22  │ [7.63, -20.525]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_S_… │ 0.22  │ [8.1, -20.525]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_S_… │ 0.22  │ [8.57, -20.525]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_S_… │ 0.22  │ [9.04, -20.525]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_S_… │ 0.22  │ [9.51, -20.525]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_S_… │ 0.22  │ [9.98, -20.525]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_S_… │ 0.22  │ [10.45, -20.525]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_S_… │ 0.22  │ [10.92, -20.525]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_E_row0_col… │ 0.22  │ [2.92, -20.315]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_W_row0_col… │ 0.22  │ [-3.14, -20.315]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_E_row2_col… │ 0.22  │ [3.66, -20.315]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_W_row2_col… │ 0.22  │ [-3.88, -20.315]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_E_… │ 0.22  │ [-5.76, -20.315]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.82, -20.315]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_E_… │ 0.22  │ [-5.02, -20.315]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.56, -20.315]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_E_… │ 0.22  │ [11.6, -20.315]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_W_… │ 0.22  │ [5.54, -20.315]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_E_… │ 0.22  │ [12.34, -20.315]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_W_… │ 0.22  │ [4.8, -20.315]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_E_row1_col… │ 0.22  │ [2.92, -19.845]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_W_row1_col… │ 0.22  │ [-3.14, -19.845]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_E_row3_col… │ 0.22  │ [3.66, -19.845]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_W_row3_col… │ 0.22  │ [-3.88, -19.845]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_E_… │ 0.22  │ [-5.76, -19.845]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.82, -19.845]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_E_… │ 0.22  │ [-5.02, -19.845]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.56, -19.845]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_E_… │ 0.22  │ [11.6, -19.845]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_W_… │ 0.22  │ [5.54, -19.845]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_E_… │ 0.22  │ [12.34, -19.845]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_W_… │ 0.22  │ [4.8, -19.845]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row0_col0_W          │ 0.22  │ [-2.36, -19.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row0_col1_W          │ 0.22  │ [-1.86, -19.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row0_col2_W          │ 0.22  │ [-1.36, -19.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row0_col3_W          │ 0.22  │ [-0.86, -19.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row0_col4_W          │ 0.22  │ [-0.36, -19.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row0_col5_W          │ 0.22  │ [0.14, -19.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row0_col6_W          │ 0.22  │ [0.64, -19.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row0_col7_W          │ 0.22  │ [1.14, -19.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row0_col8_W          │ 0.22  │ [1.64, -19.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row0_col9_W          │ 0.22  │ [2.14, -19.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row0_col0_W  │ 0.22  │ [-11.04, -19.745]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row0_col1_W  │ 0.22  │ [-10.54, -19.745]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row0_col2_W  │ 0.22  │ [-10.04, -19.745]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row0_col3_W  │ 0.22  │ [-9.54, -19.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row0_col4_W  │ 0.22  │ [-9.04, -19.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row0_col5_W  │ 0.22  │ [-8.54, -19.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row0_col6_W  │ 0.22  │ [-8.04, -19.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row0_col7_W  │ 0.22  │ [-7.54, -19.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row0_col8_W  │ 0.22  │ [-7.04, -19.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row0_col9_W  │ 0.22  │ [-6.54, -19.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row0_col0_W  │ 0.22  │ [6.32, -19.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row0_col1_W  │ 0.22  │ [6.82, -19.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row0_col2_W  │ 0.22  │ [7.32, -19.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row0_col3_W  │ 0.22  │ [7.82, -19.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row0_col4_W  │ 0.22  │ [8.32, -19.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row0_col5_W  │ 0.22  │ [8.82, -19.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row0_col6_W  │ 0.22  │ [9.32, -19.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row0_col7_W  │ 0.22  │ [9.82, -19.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row0_col8_W  │ 0.22  │ [10.32, -19.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row0_col9_W  │ 0.22  │ [10.82, -19.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_E_row2_col… │ 0.22  │ [2.92, -19.375]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_W_row2_col… │ 0.22  │ [-3.14, -19.375]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_E_row4_col… │ 0.22  │ [3.66, -19.375]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_W_row4_col… │ 0.22  │ [-3.88, -19.375]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_E_… │ 0.22  │ [-5.76, -19.375]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.82, -19.375]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_E_… │ 0.22  │ [-5.02, -19.375]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.56, -19.375]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_E_… │ 0.22  │ [11.6, -19.375]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_W_… │ 0.22  │ [5.54, -19.375]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_E_… │ 0.22  │ [12.34, -19.375]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_W_… │ 0.22  │ [4.8, -19.375]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row1_col0_W          │ 0.22  │ [-2.36, -19.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row1_col1_W          │ 0.22  │ [-1.86, -19.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row1_col2_W          │ 0.22  │ [-1.36, -19.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row1_col3_W          │ 0.22  │ [-0.86, -19.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row1_col4_W          │ 0.22  │ [-0.36, -19.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row1_col5_W          │ 0.22  │ [0.14, -19.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row1_col6_W          │ 0.22  │ [0.64, -19.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row1_col7_W          │ 0.22  │ [1.14, -19.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row1_col8_W          │ 0.22  │ [1.64, -19.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row1_col9_W          │ 0.22  │ [2.14, -19.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row1_col0_W  │ 0.22  │ [-11.04, -19.245]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row1_col1_W  │ 0.22  │ [-10.54, -19.245]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row1_col2_W  │ 0.22  │ [-10.04, -19.245]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row1_col3_W  │ 0.22  │ [-9.54, -19.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row1_col4_W  │ 0.22  │ [-9.04, -19.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row1_col5_W  │ 0.22  │ [-8.54, -19.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row1_col6_W  │ 0.22  │ [-8.04, -19.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row1_col7_W  │ 0.22  │ [-7.54, -19.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row1_col8_W  │ 0.22  │ [-7.04, -19.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row1_col9_W  │ 0.22  │ [-6.54, -19.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row1_col0_W  │ 0.22  │ [6.32, -19.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row1_col1_W  │ 0.22  │ [6.82, -19.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row1_col2_W  │ 0.22  │ [7.32, -19.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row1_col3_W  │ 0.22  │ [7.82, -19.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row1_col4_W  │ 0.22  │ [8.32, -19.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row1_col5_W  │ 0.22  │ [8.82, -19.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row1_col6_W  │ 0.22  │ [9.32, -19.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row1_col7_W  │ 0.22  │ [9.82, -19.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row1_col8_W  │ 0.22  │ [10.32, -19.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row1_col9_W  │ 0.22  │ [10.82, -19.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_E_row3_col… │ 0.22  │ [2.92, -18.905]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_W_row3_col… │ 0.22  │ [-3.14, -18.905]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_E_row5_col… │ 0.22  │ [3.66, -18.905]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_W_row5_col… │ 0.22  │ [-3.88, -18.905]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_E_… │ 0.22  │ [-5.76, -18.905]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.82, -18.905]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_E_… │ 0.22  │ [-5.02, -18.905]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.56, -18.905]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_E_… │ 0.22  │ [11.6, -18.905]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_W_… │ 0.22  │ [5.54, -18.905]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_E_… │ 0.22  │ [12.34, -18.905]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_W_… │ 0.22  │ [4.8, -18.905]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row2_col0_W          │ 0.22  │ [-2.36, -18.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row2_col1_W          │ 0.22  │ [-1.86, -18.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row2_col2_W          │ 0.22  │ [-1.36, -18.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row2_col3_W          │ 0.22  │ [-0.86, -18.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row2_col4_W          │ 0.22  │ [-0.36, -18.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row2_col5_W          │ 0.22  │ [0.14, -18.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row2_col6_W          │ 0.22  │ [0.64, -18.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row2_col7_W          │ 0.22  │ [1.14, -18.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row2_col8_W          │ 0.22  │ [1.64, -18.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row2_col9_W          │ 0.22  │ [2.14, -18.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row2_col0_W  │ 0.22  │ [-11.04, -18.745]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row2_col1_W  │ 0.22  │ [-10.54, -18.745]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row2_col2_W  │ 0.22  │ [-10.04, -18.745]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row2_col3_W  │ 0.22  │ [-9.54, -18.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row2_col4_W  │ 0.22  │ [-9.04, -18.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row2_col5_W  │ 0.22  │ [-8.54, -18.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row2_col6_W  │ 0.22  │ [-8.04, -18.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row2_col7_W  │ 0.22  │ [-7.54, -18.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row2_col8_W  │ 0.22  │ [-7.04, -18.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row2_col9_W  │ 0.22  │ [-6.54, -18.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row2_col0_W  │ 0.22  │ [6.32, -18.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row2_col1_W  │ 0.22  │ [6.82, -18.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row2_col2_W  │ 0.22  │ [7.32, -18.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row2_col3_W  │ 0.22  │ [7.82, -18.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row2_col4_W  │ 0.22  │ [8.32, -18.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row2_col5_W  │ 0.22  │ [8.82, -18.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row2_col6_W  │ 0.22  │ [9.32, -18.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row2_col7_W  │ 0.22  │ [9.82, -18.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row2_col8_W  │ 0.22  │ [10.32, -18.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row2_col9_W  │ 0.22  │ [10.82, -18.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_E_row4_col… │ 0.22  │ [2.92, -18.435]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_W_row4_col… │ 0.22  │ [-3.14, -18.435]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_E_row6_col… │ 0.22  │ [3.66, -18.435]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_W_row6_col… │ 0.22  │ [-3.88, -18.435]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_E_… │ 0.22  │ [-5.76, -18.435]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.82, -18.435]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_E_… │ 0.22  │ [-5.02, -18.435]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.56, -18.435]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_E_… │ 0.22  │ [11.6, -18.435]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_W_… │ 0.22  │ [5.54, -18.435]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_E_… │ 0.22  │ [12.34, -18.435]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_W_… │ 0.22  │ [4.8, -18.435]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row3_col0_W          │ 0.22  │ [-2.36, -18.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row3_col1_W          │ 0.22  │ [-1.86, -18.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row3_col2_W          │ 0.22  │ [-1.36, -18.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row3_col3_W          │ 0.22  │ [-0.86, -18.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row3_col4_W          │ 0.22  │ [-0.36, -18.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row3_col5_W          │ 0.22  │ [0.14, -18.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row3_col6_W          │ 0.22  │ [0.64, -18.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row3_col7_W          │ 0.22  │ [1.14, -18.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row3_col8_W          │ 0.22  │ [1.64, -18.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row3_col9_W          │ 0.22  │ [2.14, -18.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row3_col0_W  │ 0.22  │ [-11.04, -18.245]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row3_col1_W  │ 0.22  │ [-10.54, -18.245]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row3_col2_W  │ 0.22  │ [-10.04, -18.245]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row3_col3_W  │ 0.22  │ [-9.54, -18.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row3_col4_W  │ 0.22  │ [-9.04, -18.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row3_col5_W  │ 0.22  │ [-8.54, -18.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row3_col6_W  │ 0.22  │ [-8.04, -18.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row3_col7_W  │ 0.22  │ [-7.54, -18.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row3_col8_W  │ 0.22  │ [-7.04, -18.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row3_col9_W  │ 0.22  │ [-6.54, -18.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row3_col0_W  │ 0.22  │ [6.32, -18.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row3_col1_W  │ 0.22  │ [6.82, -18.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row3_col2_W  │ 0.22  │ [7.32, -18.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row3_col3_W  │ 0.22  │ [7.82, -18.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row3_col4_W  │ 0.22  │ [8.32, -18.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row3_col5_W  │ 0.22  │ [8.82, -18.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row3_col6_W  │ 0.22  │ [9.32, -18.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row3_col7_W  │ 0.22  │ [9.82, -18.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row3_col8_W  │ 0.22  │ [10.32, -18.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row3_col9_W  │ 0.22  │ [10.82, -18.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_E_row5_col… │ 0.22  │ [2.92, -17.965]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_W_row5_col… │ 0.22  │ [-3.14, -17.965]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_E_row7_col… │ 0.22  │ [3.66, -17.965]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_W_row7_col… │ 0.22  │ [-3.88, -17.965]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_E_… │ 0.22  │ [-5.76, -17.965]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.82, -17.965]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_E_… │ 0.22  │ [-5.02, -17.965]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.56, -17.965]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_E_… │ 0.22  │ [11.6, -17.965]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_W_… │ 0.22  │ [5.54, -17.965]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_E_… │ 0.22  │ [12.34, -17.965]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_W_… │ 0.22  │ [4.8, -17.965]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row4_col0_W          │ 0.22  │ [-2.36, -17.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row4_col1_W          │ 0.22  │ [-1.86, -17.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row4_col2_W          │ 0.22  │ [-1.36, -17.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row4_col3_W          │ 0.22  │ [-0.86, -17.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row4_col4_W          │ 0.22  │ [-0.36, -17.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row4_col5_W          │ 0.22  │ [0.14, -17.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row4_col6_W          │ 0.22  │ [0.64, -17.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row4_col7_W          │ 0.22  │ [1.14, -17.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row4_col8_W          │ 0.22  │ [1.64, -17.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row4_col9_W          │ 0.22  │ [2.14, -17.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row4_col0_W  │ 0.22  │ [-11.04, -17.745]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row4_col1_W  │ 0.22  │ [-10.54, -17.745]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row4_col2_W  │ 0.22  │ [-10.04, -17.745]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row4_col3_W  │ 0.22  │ [-9.54, -17.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row4_col4_W  │ 0.22  │ [-9.04, -17.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row4_col5_W  │ 0.22  │ [-8.54, -17.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row4_col6_W  │ 0.22  │ [-8.04, -17.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row4_col7_W  │ 0.22  │ [-7.54, -17.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row4_col8_W  │ 0.22  │ [-7.04, -17.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row4_col9_W  │ 0.22  │ [-6.54, -17.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row4_col0_W  │ 0.22  │ [6.32, -17.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row4_col1_W  │ 0.22  │ [6.82, -17.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row4_col2_W  │ 0.22  │ [7.32, -17.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row4_col3_W  │ 0.22  │ [7.82, -17.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row4_col4_W  │ 0.22  │ [8.32, -17.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row4_col5_W  │ 0.22  │ [8.82, -17.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row4_col6_W  │ 0.22  │ [9.32, -17.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row4_col7_W  │ 0.22  │ [9.82, -17.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row4_col8_W  │ 0.22  │ [10.32, -17.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row4_col9_W  │ 0.22  │ [10.82, -17.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_diff_e_W                        │ 5.32  │ [-2.66, -17.495]   │ 180.0       │ [31, 0]  │ electrical │
# │ multiplier_0_tap_e_W                         │ 5.0   │ [-2.5, -17.495]    │ 180.0       │ [22, 0]  │ electrical │
# │ multiplier_0_well_W                          │ 6.8   │ [-3.4, -17.495]    │ 180.0       │ [21, 0]  │ electrical │
# │ multiplier_0_lvs_W                           │ 5.0   │ [-2.5, -17.495]    │ 180.0       │ [118, 5] │ electrical │
# │ multiplier_0_drc_W                           │ 8.28  │ [-4.14, -17.495]   │ 180.0       │ [127, 5] │ electrical │
# │ multiplier_0_E_W                             │ 5.0   │ [-2.5, -17.495]    │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_B_metal_E_W                     │ 6.48  │ [2.82, -17.495]    │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_B_metal_W_W                     │ 6.48  │ [-3.24, -17.495]   │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_C_metal_E_W                     │ 7.96  │ [3.56, -17.495]    │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_C_metal_W_W                     │ 7.96  │ [-3.98, -17.495]   │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_E_row6_col… │ 0.22  │ [2.92, -17.495]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_W_row6_col… │ 0.22  │ [-3.14, -17.495]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_E_row8_col… │ 0.22  │ [3.66, -17.495]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_W_row8_col… │ 0.22  │ [-3.88, -17.495]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_emitter_W                       │ 0.5   │ [-0.25, -17.495]   │ 180.0       │ [36, 0]  │ electrical │
# │ multiplier_0_dummy_L_diff_e_W                │ 5.32  │ [-11.34, -17.495]  │ 180.0       │ [31, 0]  │ electrical │
# │ multiplier_0_dummy_L_tap_e_W                 │ 5.0   │ [-11.18, -17.495]  │ 180.0       │ [22, 0]  │ electrical │
# │ multiplier_0_dummy_L_well_W                  │ 6.8   │ [-12.08, -17.495]  │ 180.0       │ [21, 0]  │ electrical │
# │ multiplier_0_dummy_L_lvs_W                   │ 5.0   │ [-11.18, -17.495]  │ 180.0       │ [118, 5] │ electrical │
# │ multiplier_0_dummy_L_drc_W                   │ 8.28  │ [-12.82, -17.495]  │ 180.0       │ [127, 5] │ electrical │
# │ multiplier_0_dummy_L_E_W                     │ 5.0   │ [-11.18, -17.495]  │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_L_B_metal_E_W             │ 6.48  │ [-5.86, -17.495]   │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_L_B_metal_W_W             │ 6.48  │ [-11.92, -17.495]  │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_L_C_metal_E_W             │ 7.96  │ [-5.12, -17.495]   │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_L_C_metal_W_W             │ 7.96  │ [-12.66, -17.495]  │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_E_… │ 0.22  │ [-5.76, -17.495]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.82, -17.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_E_… │ 0.22  │ [-5.02, -17.495]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.56, -17.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_diff_e_W                │ 5.32  │ [6.02, -17.495]    │ 180.0       │ [31, 0]  │ electrical │
# │ multiplier_0_dummy_R_tap_e_W                 │ 5.0   │ [6.18, -17.495]    │ 180.0       │ [22, 0]  │ electrical │
# │ multiplier_0_dummy_R_well_W                  │ 6.8   │ [5.28, -17.495]    │ 180.0       │ [21, 0]  │ electrical │
# │ multiplier_0_dummy_R_lvs_W                   │ 5.0   │ [6.18, -17.495]    │ 180.0       │ [118, 5] │ electrical │
# │ multiplier_0_dummy_R_drc_W                   │ 8.28  │ [4.54, -17.495]    │ 180.0       │ [127, 5] │ electrical │
# │ multiplier_0_dummy_R_E_W                     │ 5.0   │ [6.18, -17.495]    │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_R_B_metal_E_W             │ 6.48  │ [11.5, -17.495]    │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_R_B_metal_W_W             │ 6.48  │ [5.44, -17.495]    │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_R_C_metal_E_W             │ 7.96  │ [12.24, -17.495]   │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_R_C_metal_W_W             │ 7.96  │ [4.7, -17.495]     │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_E_… │ 0.22  │ [11.6, -17.495]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_W_… │ 0.22  │ [5.54, -17.495]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_E_… │ 0.22  │ [12.34, -17.495]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_W_… │ 0.22  │ [4.8, -17.495]     │ 180.0       │ [33, 0]  │ electrical │
# │ emitter_W                                    │ 0.5   │ [-0.25, -17.495]   │ 180.0       │ [36, 0]  │ electrical │
# │ multiplier_0_contacts_e_row5_col0_W          │ 0.22  │ [-2.36, -17.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row5_col1_W          │ 0.22  │ [-1.86, -17.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row5_col2_W          │ 0.22  │ [-1.36, -17.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row5_col3_W          │ 0.22  │ [-0.86, -17.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row5_col4_W          │ 0.22  │ [-0.36, -17.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row5_col5_W          │ 0.22  │ [0.14, -17.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row5_col6_W          │ 0.22  │ [0.64, -17.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row5_col7_W          │ 0.22  │ [1.14, -17.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row5_col8_W          │ 0.22  │ [1.64, -17.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row5_col9_W          │ 0.22  │ [2.14, -17.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row5_col0_W  │ 0.22  │ [-11.04, -17.245]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row5_col1_W  │ 0.22  │ [-10.54, -17.245]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row5_col2_W  │ 0.22  │ [-10.04, -17.245]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row5_col3_W  │ 0.22  │ [-9.54, -17.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row5_col4_W  │ 0.22  │ [-9.04, -17.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row5_col5_W  │ 0.22  │ [-8.54, -17.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row5_col6_W  │ 0.22  │ [-8.04, -17.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row5_col7_W  │ 0.22  │ [-7.54, -17.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row5_col8_W  │ 0.22  │ [-7.04, -17.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row5_col9_W  │ 0.22  │ [-6.54, -17.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row5_col0_W  │ 0.22  │ [6.32, -17.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row5_col1_W  │ 0.22  │ [6.82, -17.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row5_col2_W  │ 0.22  │ [7.32, -17.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row5_col3_W  │ 0.22  │ [7.82, -17.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row5_col4_W  │ 0.22  │ [8.32, -17.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row5_col5_W  │ 0.22  │ [8.82, -17.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row5_col6_W  │ 0.22  │ [9.32, -17.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row5_col7_W  │ 0.22  │ [9.82, -17.245]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row5_col8_W  │ 0.22  │ [10.32, -17.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row5_col9_W  │ 0.22  │ [10.82, -17.245]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_E_row7_col… │ 0.22  │ [2.92, -17.025]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_W_row7_col… │ 0.22  │ [-3.14, -17.025]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_E_row9_col… │ 0.22  │ [3.66, -17.025]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_W_row9_col… │ 0.22  │ [-3.88, -17.025]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_E_… │ 0.22  │ [-5.76, -17.025]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.82, -17.025]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_E_… │ 0.22  │ [-5.02, -17.025]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.56, -17.025]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_E_… │ 0.22  │ [11.6, -17.025]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_W_… │ 0.22  │ [5.54, -17.025]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_E_… │ 0.22  │ [12.34, -17.025]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_W_… │ 0.22  │ [4.8, -17.025]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row6_col0_W          │ 0.22  │ [-2.36, -16.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row6_col1_W          │ 0.22  │ [-1.86, -16.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row6_col2_W          │ 0.22  │ [-1.36, -16.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row6_col3_W          │ 0.22  │ [-0.86, -16.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row6_col4_W          │ 0.22  │ [-0.36, -16.745]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row6_col5_W          │ 0.22  │ [0.14, -16.745]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row6_col6_W          │ 0.22  │ [0.64, -16.745]    │ 180.0       │ [33, 0]  │ electrical │
# ...
# │ multiplier_2_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, -0.535]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, -0.065]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 0.405]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 0.875]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 1.345]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 1.815]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 2.285]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 2.755]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_B_metal_W_S             │ 0.42  │ [-11.71, 5.575]    │ 270.0       │ [34, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 5.885]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 6.355]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 6.825]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 7.295]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 7.765]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 8.235]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 8.705]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 9.175]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 9.645]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 10.115]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 10.585]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 11.055]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 11.525]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_B_metal_W_S             │ 0.42  │ [-11.71, 14.345]   │ 270.0       │ [34, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 14.655]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 15.125]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 15.595]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 16.065]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 16.535]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 17.005]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 17.475]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 17.945]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 18.415]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 18.885]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 19.355]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 19.825]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 20.295]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_N_… │ 0.22  │ [-11.735, -13.835] │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-11.735, -21.375] │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_N_… │ 0.22  │ [-11.735, -5.065]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-11.735, -12.605] │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_N_… │ 0.22  │ [-11.735, 3.705]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-11.735, -3.835]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_c_contacts_N_… │ 0.22  │ [-11.735, 12.475]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-11.735, 4.935]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_c_contacts_N_… │ 0.22  │ [-11.735, 21.245]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-11.735, 13.705]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_C_metal_W_S             │ 0.42  │ [-12.45, -21.475]  │ 270.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -21.365]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -20.895]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -20.425]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -19.955]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -19.485]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -19.015]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -18.545]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -18.075]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -17.605]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -17.135]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -16.665]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -16.195]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -15.725]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -15.255]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -14.785]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -14.315]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -13.845]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_C_metal_W_S             │ 0.42  │ [-12.45, -12.705]  │ 270.0       │ [34, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -12.595]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -12.125]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -11.655]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -11.185]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -10.715]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -10.245]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -9.775]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -9.305]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -8.835]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -8.365]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -7.895]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -7.425]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -6.955]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -6.485]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -6.015]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -5.545]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -5.075]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_C_metal_W_S             │ 0.42  │ [-12.45, -3.935]   │ 270.0       │ [34, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -3.825]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -3.355]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -2.885]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -2.415]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -1.945]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -1.475]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -1.005]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -0.535]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -0.065]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 0.405]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 0.875]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 1.345]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 1.815]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 2.285]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 2.755]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 3.225]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 3.695]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_C_metal_W_S             │ 0.42  │ [-12.45, 4.835]    │ 270.0       │ [34, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 4.945]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 5.415]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 5.885]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 6.355]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 6.825]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 7.295]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 7.765]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 8.235]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 8.705]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 9.175]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 9.645]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 10.115]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 10.585]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 11.055]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 11.525]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 11.995]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_3_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 12.465]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_C_metal_W_S             │ 0.42  │ [-12.45, 13.605]   │ 270.0       │ [34, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 13.715]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 14.185]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 14.655]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 15.125]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 15.595]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 16.065]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 16.535]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 17.005]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 17.475]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 17.945]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 18.415]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 18.885]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 19.355]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 19.825]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 20.295]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 20.765]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_4_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 21.235]   │ 270.0       │ [33, 0]  │ electrical │
# └──────────────────────────────────────────────┴───────┴────────────────────┴─────────────┴──────────┴────────────┘

# %%
from glayout.primitives.bjt import pnp, npn

# %%
bjt_pnp=pnp(pdk=pdk,active_area=(5,5),bc_rmult=2,multipliers=5)

# %%
bjt_pnp.show()
# Out:
# /headless/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/show.py:40: UserWarning: Unnamed cells, 1 in 'Unnamed_f13b9971'
#   gdspath = component.write_gds(
# 2025-09-02 07:08:26.062 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.3.3", "klayout_version": "0.30.2", "type": "open", "file": "/tmp/gdsfactory/Unnamed_f13b9971.gds"}

# %%
bjt_npn=npn(pdk=pdk,active_area=(5,5),bc_rmult=2,multipliers=5, with_dummy=(False,False))

# %%
bjt_npn.show()
# Out:
# /headless/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/show.py:40: UserWarning: Unnamed cells, 1 in 'Unnamed_4a048f52'
#   gdspath = component.write_gds(
# 2025-09-02 07:08:33.786 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.3.3", "klayout_version": "0.30.2", "type": "open", "file": "/tmp/gdsfactory/Unnamed_4a048f52.gds"}

# %%
from pathlib import Path
import os
import subprocess
import tempfile
magicrc_file = Path(os.environ['PDKPATH']) / "libs.tech" / "magic" / f"{os.environ['PDK']}.magicrc"
magicrc_file
# Out:
# PosixPath('/foss/pdks/gf180mcuD/libs.tech/magic/gf180mcuD.magicrc')

# %%
def extract_pex(design, path_to_dir):
    design_name=design.name
    if not path_to_dir.exists():
        path_to_dir.mkdir(parents=True, exist_ok=False)
    
    pex_path = path_to_dir / f"{design_name}_pex.spice"
    gds_path = path_to_dir / f"{design_name}.gds"
    
    design.write_gds(str(gds_path))
        
    magic_script_content = f"""
    drc off            
    gds flatglob *\\$\\$*
    gds read {gds_path}
    
    flatten {design_name}
    load {design_name}
    select top cell
    extract do local
    extract all
    ext2sim labels on
    ext2sim
    extresist tolerance 10
    extresist
    ext2spice lvs
    ext2spice cthresh 0
    ext2spice extresist on
    ext2spice -o {str(pex_path)}
    exit
    """
    
    with tempfile.NamedTemporaryFile(mode='w', delete=False) as magic_script_file:
        magic_script_file.write(magic_script_content)
        magic_script_path = magic_script_file.name
        
    magic_cmd = f"bash -c 'magic -rcfile {magicrc_file} -noconsole -dnull < {magic_script_path}'",
    magic_subproc = subprocess.run(
        magic_cmd, 
        shell=True,
        check=True,
        capture_output=True
    )
    
    magic_subproc_code = magic_subproc.returncode
    magic_subproc_out = magic_subproc.stdout.decode('utf-8')
    print(magic_subproc_out)

# %%
path_to_dir = Path("/foss/designs/gLayout/tutorial").resolve() / "ext" / bjt_pnp.name
extract_pex(bjt_pnp, path_to_dir)
# Out:
# /tmp/ipykernel_34071/1276761136.py:9: UserWarning: Unnamed cells, 1 in 'Unnamed_f13b9971'
#   design.write_gds(str(gds_path))
# 2025-09-02 07:10:20.696 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/foss/designs/gLayout/tutorial/ext/Unnamed_f13b9971/Unnamed_f13b9971.gds'
# Magic 8.3 revision 528 - Compiled on Wed Jun 18 09:45:25 PM CEST 2025.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=4096]
# Using NULL graphics device.
# Processing system .magicrc file
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Using technology "gf180mcuD", version 1.0.525-0-gf2e289d
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "Unnamed_f13b9971".
# Moving label "E" from metal1 to via1 in cell Unnamed_f13b9971.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_f13b9971.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_f13b9971.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_f13b9971.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_f13b9971.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_f13b9971.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_f13b9971.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_f13b9971.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_f13b9971.
# Moving label "E" from metal1 to via1 in cell Unnamed_f13b9971.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_f13b9971.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_f13b9971.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_f13b9971.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_f13b9971.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_f13b9971.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_f13b9971.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_f13b9971.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_f13b9971.
# Moving label "E" from metal1 to via1 in cell Unnamed_f13b9971.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_f13b9971.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_f13b9971.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_f13b9971.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_f13b9971.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_f13b9971.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_f13b9971.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_f13b9971.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_f13b9971.
# Moving label "E" from metal1 to via1 in cell Unnamed_f13b9971.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_f13b9971.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_f13b9971.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_f13b9971.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_f13b9971.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_f13b9971.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_f13b9971.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_f13b9971.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_f13b9971.
# Moving label "E" from metal1 to via1 in cell Unnamed_f13b9971.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_f13b9971.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_f13b9971.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_f13b9971.
# Moving label "C" from metal1 to psubdiffcont in cell Unnamed_f13b9971.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_f13b9971.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_f13b9971.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_f13b9971.
# Moving label "B" from metal1 to nsubdiffcont in cell Unnamed_f13b9971.
# Extracting Unnamed_f13b9971 into Unnamed_f13b9971.ext:
# exttosim finished.
# Adding  E; Tnew = 0.04ns, Told = 0.00ns
# Total Nets: 5
# Nets extracted: 2 (0.400000)
# Nets output: 1 (0.200000)
# exttospice finished.

# %%
path_to_dir = Path("/foss/designs/gLayout/tutorial").resolve() / "ext" / bjt_npn.name
extract_pex(bjt_npn, path_to_dir)
# Out:
# /tmp/ipykernel_34071/1276761136.py:9: UserWarning: Unnamed cells, 1 in 'Unnamed_4a048f52'
#   design.write_gds(str(gds_path))
# 2025-09-02 07:10:27.260 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/foss/designs/gLayout/tutorial/ext/Unnamed_4a048f52/Unnamed_4a048f52.gds'
# Magic 8.3 revision 528 - Compiled on Wed Jun 18 09:45:25 PM CEST 2025.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=4096]
# Using NULL graphics device.
# Processing system .magicrc file
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Using technology "gf180mcuD", version 1.0.525-0-gf2e289d
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "Unnamed_4a048f52".
# Moving label "E" from metal1 to via1 in cell Unnamed_4a048f52.
# Moving label "C" from metal1 to nsubdiffcont in cell Unnamed_4a048f52.
# Moving label "C" from metal1 to nsubdiffcont in cell Unnamed_4a048f52.
# Moving label "C" from metal1 to nsubdiffcont in cell Unnamed_4a048f52.
# Moving label "C" from metal1 to nsubdiffcont in cell Unnamed_4a048f52.
# Moving label "B" from metal1 to psubdiffcont in cell Unnamed_4a048f52.
# Moving label "B" from metal1 to psubdiffcont in cell Unnamed_4a048f52.
# Moving label "B" from metal1 to psubdiffcont in cell Unnamed_4a048f52.
# Moving label "B" from metal1 to psubdiffcont in cell Unnamed_4a048f52.
# Moving label "E" from metal1 to via1 in cell Unnamed_4a048f52.
# Moving label "C" from metal1 to nsubdiffcont in cell Unnamed_4a048f52.
# Moving label "C" from metal1 to nsubdiffcont in cell Unnamed_4a048f52.
# Moving label "C" from metal1 to nsubdiffcont in cell Unnamed_4a048f52.
# Moving label "C" from metal1 to nsubdiffcont in cell Unnamed_4a048f52.
# Moving label "B" from metal1 to psubdiffcont in cell Unnamed_4a048f52.
# Moving label "B" from metal1 to psubdiffcont in cell Unnamed_4a048f52.
# Moving label "B" from metal1 to psubdiffcont in cell Unnamed_4a048f52.
# Moving label "B" from metal1 to psubdiffcont in cell Unnamed_4a048f52.
# Moving label "E" from metal1 to via1 in cell Unnamed_4a048f52.
# Moving label "C" from metal1 to nsubdiffcont in cell Unnamed_4a048f52.
# Moving label "C" from metal1 to nsubdiffcont in cell Unnamed_4a048f52.
# Moving label "C" from metal1 to nsubdiffcont in cell Unnamed_4a048f52.
# Moving label "C" from metal1 to nsubdiffcont in cell Unnamed_4a048f52.
# Moving label "B" from metal1 to psubdiffcont in cell Unnamed_4a048f52.
# Moving label "B" from metal1 to psubdiffcont in cell Unnamed_4a048f52.
# Moving label "B" from metal1 to psubdiffcont in cell Unnamed_4a048f52.
# Moving label "B" from metal1 to psubdiffcont in cell Unnamed_4a048f52.
# Moving label "E" from metal1 to via1 in cell Unnamed_4a048f52.
# Moving label "C" from metal1 to nsubdiffcont in cell Unnamed_4a048f52.
# Moving label "C" from metal1 to nsubdiffcont in cell Unnamed_4a048f52.
# Moving label "C" from metal1 to nsubdiffcont in cell Unnamed_4a048f52.
# Moving label "C" from metal1 to nsubdiffcont in cell Unnamed_4a048f52.
# Moving label "B" from metal1 to psubdiffcont in cell Unnamed_4a048f52.
# Moving label "B" from metal1 to psubdiffcont in cell Unnamed_4a048f52.
# Moving label "B" from metal1 to psubdiffcont in cell Unnamed_4a048f52.
# Moving label "B" from metal1 to psubdiffcont in cell Unnamed_4a048f52.
# Moving label "E" from metal1 to via1 in cell Unnamed_4a048f52.
# Moving label "C" from metal1 to nsubdiffcont in cell Unnamed_4a048f52.
# Moving label "C" from metal1 to nsubdiffcont in cell Unnamed_4a048f52.
# Moving label "C" from metal1 to nsubdiffcont in cell Unnamed_4a048f52.
# Moving label "C" from metal1 to nsubdiffcont in cell Unnamed_4a048f52.
# Moving label "B" from metal1 to psubdiffcont in cell Unnamed_4a048f52.
# Moving label "B" from metal1 to psubdiffcont in cell Unnamed_4a048f52.
# Moving label "B" from metal1 to psubdiffcont in cell Unnamed_4a048f52.
# Moving label "B" from metal1 to psubdiffcont in cell Unnamed_4a048f52.
# Extracting Unnamed_4a048f52 into Unnamed_4a048f52.ext:
# exttosim finished.
# Adding  E; Tnew = 0.01ns, Told = 0.00ns
# Total Nets: 8
# Nets extracted: 3 (0.375000)
# Nets output: 1 (0.125000)
# exttospice finished.
